# %%
import re
import pandas as pd

beyonce_df = pd.read_csv('/Users/mertakcay/Projects/Knowledge Graphs/Neo4j/context.csv')
context_list = beyonce_df['context'].apply(lambda x : re.sub(r'[^\w\s]', '', x))

# %% [markdown]
# # Ontology

# %% [markdown]
# Concepts:
# - Year: 1981
# - Month: September
# - Day: 1,2,3,4,5,6,7
# - School: St Marys Elementary School, Parker Elementary School, Alief Elsik High School
# - Person: Beyoncé, Shakira, Taylor Swifts, Beck, Jay-Z, Blue Ivy Carter, Marc Nelson, Kelly Rowland, Darlette Johnson, Michelle Williams, Destinys Child, Tina Knowles, Mathew Knowles, Solange Knowles, Bianca Lawson, LeToya Luckett, LaTavia Roberson, Farrah Franklin, Dwayne Wiggins, Mike Myers, Cuba Gooding Jr, Mekhi Phifer, Jennifer Hudson, Jamie Foxx, Eddie Murphy, Steve Martin, Ali Larter, Idris Elba, Lauryn Hill, Lady Gaga, Jay-Z (rapper), Barack Obama, Amy Winehouse, André 3000, Sia, Etta James, James At Last, Sharon Charles, Coldplay
# - Group: Destiny's Child, Girls Tyme, Boyz II Men
# - Event: Grammy Awards, Super Bowl, Met Gala, On the Run Tour, The Mrs. Carter Show World Tour, Verizon Ladies First Tour, Dangerously in Love Tour, I Am World Tour, 4 Intimate Nights with Beyoncé concerts, Revel - Presents Beyoncé Live concerts
# - Role: Foxxy Cleopatra, Sharon Charles, James At Last
# - Film: Dreamgirls, The Pink Panther, Austin Powers in Goldmember, The Fighting Temptations, Carmen: A Hip Hopera, Cadillac Records, Obsessed, The Great Gatsby, Epic
# - Song: Crazy in Love, Baby Boy, Me Myself and I, Naughty Girl, The Closer I Get to You, Lose My Breath, Soldier, Déjà Vu, Irreplaceable, Ring the Alarm, Get Me Bodied, Green Light, Listen, Single Ladies (Put a Ring on It), If I Were a Boy, Halo, Sweet Dreams, Diva, Ego, Broken-Hearted Girl, Video Phone, Telephone, At Last, Run the World (Girls), Best Thing I Never Had, Love on Top, Party, Countdown, I Care, End of Time, Nuclear, Back to Black, Rise Up, Drunk in Love, Pretty Hurts, Hymn for the Weekend, Say My Name, Work It Out, Belong with Me, World Girls, Best Things I Never Had, God Made You, The Great Gatsby
#
# - Album: Dangerously in Love, The Writings on the Wall, Survivor, 8 Days of Christmas, Destiny Fulfilled, BDay, I Am Sasha Fierce, 4, Beyoncé, Selftitled Debut Album, Love Songs
# - Organization: Elektra Records, Dwayne Wigginss Grass Roots Entertainment, Recording Industry Association of America, Billboard, Time Magazine, Forbes Magazine, Warner Chappell Music, Pepsi, Sony Music, WarnerChappell Music
# - Location: Houston, Texas, Fredericksburg, Texas, Atlanta, Georgia, Philadelphia, Barcelona, Spain, North America, Europe, Phoenix House, Reliant Stadium, Sony Club, Manhattan, New York, Lenox Hill Hospital, New York City, Atlantic City, New Jersey, Washington D.C., Mercedes-Benz Superdome, New Orleans
# - Award: Grammy Award, MTV Video Music Award, BET Award, Satellite Award, NAACP Image Award, New York Association of Black Journalists Award, Top 100 List of Musician, Scottish MOBO Award, MTV Movie Award for Best Fight, Record of the Year, Single Ladies Put a Ring, Highest Paid Performer, Best Surround Sound Album
# - Course: Dance, Sing
# - Activity: Dancing, Singing
# - Music Type: Rap
#
# Relations:
# - born (Person, Day): Beyoncé born 4
# - born (Person, Month): Beyoncé born September
# - born (Person, Year): Beyoncé born 1981
# - sign_at (Person, Year): Beyoncé sign_at 1995 Girls Tyme sign_at 1996
# - sign (Person, Organization): Beyoncé sign Elektra Records,Girls Tyme sign Elektra Records,Girls Tyme sign Dwayne Wigginss Grass Roots Entertainment, Beyoncé sign Columbia Records, Beyoncé sign WarnerChappell Music
# - nationality (Person, Country): Beyoncé nationality American
# - has_job (Person, Job): Beyoncé has_job singer, Beyoncé has_job producer, Beyoncé has_job dancing
# - has_father (Person, Person): Beyoncé has_father Mathew Knowles
# - married (Person, Person): Beyoncé married Jay-Z
# - changed_name (Person, Group): Girls Tyme changed_name Destinys Child
# - friend (Person, Person): Beyoncé friend Kelly Rowland, Beyoncé friend LaTavia Roberson,  LaTavia Roberson friend Kelly Rowland
# - has_child (Person, Person): Beyoncé has_child Blue Ivy Carter
# - has_mother (Person, Person): Blue Ivy Carter has_mother Beyoncé
# - move (Person, Location): Beyoncé move Atalanta, Girls Tyme move Atalanta
# - music_type (Person, Music Type) Beyoncé music_type Rap
# - records_at (Person, Organization): Beyoncé records_at Sony Music
# - attend (Person, Event): Beyoncé attend Dangerously in Love Tour, Beyoncé attend Verizon Ladies, Beyoncé attend I Am World Tour,
# - attend (Person, School): Beyoncé attend St Marys Elementary School, Darlette Johnson attend St Marys Elementary School, Beyoncé attend Parker Elementary School, Beyoncé attend Alief Elsik High School
# - part_of (Person, Group): Marc Nelson part_of Boyz II Men
# - leave (Person, Group): Beyoncé leave Destiny's Child
# - discover (Person, Person): Darlette Johnson discover Beyoncé
# - interests (Person, Course): Beyoncé interests Dancing, Beyoncé interests Singing
# - locate (School, Location): St Marys Elementary School locate Texas, Parker Elementary School locate Houston
# - has_course (School, Course) St Marys Elementary School has_course Sing, St Marys Elementary School has_course Dance
# - influence (Person, Person): Etta James influence Beyoncé
# - list (Organization, Award): Forbes list Top 100 List of Musician
# - sings_in (Person, Group): Beyoncé sings_in Destiny's Child, Beyoncé sings_in Girls Tyme
# - sing_in (Song, Album): Déjà Vu sing_in BDay
# - releases (Person, Song): Beyoncé releases Crazy in Love, Girls Tyme releases, Beyoncé releases Work It Out, Beyoncé releases Me Myself and I, Beyoncé releases Naughty Girl, Beyoncé releases Irreplaceable, Beyoncé releases Ring the Alarm, Beyoncé releases Get Me Bodied, Beyoncé releases Green Light, Beyoncé releases Listen, Beyoncé releases Single Ladies (Put a Ring on It), Beyoncé releases SweetDreams, Taylor Swifts releases Belong with Me, Beyoncé releases Telephone, Beyoncé releases World Girls, Beyoncé Best Things I Never Had, Beyoncé releases Love On Top, Beyoncé releases God Made You
# - manages (Person, Person): Mathew Knowles manages Beyoncé, Mathew Knowles manages Girls Tyme
# - releases (Person, Album): Beyoncé releases Dangerously in Love, Beyoncé releases BDay, Beyoncé releases I Am Sasha, Beyoncé releases Halo, Beyoncé releases Love Songs
#
# - releases (Group, Album): Destiny's Child releases The Writings on the Wall, Destiny's Child releases Selftitled Debut Album, Destiny's Child releases Survivor, Destiny's Child releases Destiny Fulfilled
# - act (Person, Role): Beyoncé act Foxxy Cleopatra, Beyoncé, act Lilly, Beyonce act James At Last, Sharon Charles
# - act (Person, Film): Beyoncé act Austin Powers, Beyoncé act The Fighting Temptations, Beyoncé act The Pink Panther, Beyoncé act Dreamgirls, Beyoncé act Epic
# - wins (Person, Award): Beyoncé wins Grammy Award, Beyoncé wins MTV Europe Music, Beyoncé wins Scottish MOBO Award, Beyoncé wins BET Award, Beyoncé wins MTV Video Music Award, Beyonce wins MTV Movie Award for Best Fight, Beyoncé wins Record of the Year, Beyoncé wins Single Ladies Put a Ring, Beyoncé wins Highest Paid Performer, Beck wins Best Surround Sound Album
# - wins (Group, Award): Destiny's Child wins Best RB Performance, Destiny's Child wins Grammy Award
# - with_duet (Person, Person): Beyoncé with_duet Marc Nelson, Beyoncé with_duet Shakira, Beyoncé with_duet Sasha Fierce, Beyoncé with_duet Coldplay
# - with_act (Person, Person): Beyoncé with_act Steve Martin, Beyoncé with_act Jamie Foxx, Beyoncé with_act Eddie Murphy, Eddie Murphy with_act Jamie Foxx, Beyoncé with_act Ali Larter
# - tours (Person, Event): Beyoncé tours The Mrs. Carter Show World Tour
# - headlines (Person, Event): Beyoncé headlines Glastonbury Festival
# - directs (Person, Film): Beyoncé directs Life Is But a Dream
# - covers (Person, Song): Beyoncé covers Back to Black, Beyoncé covers The Great Gatsby
# - features_in (Person, Song): Beyoncé features_in Drunk in Love
# - co-writes (Person, Person, Song): Beyoncé co-writes Rise Up *with Sia*
# - earns (Person, Money): Beyoncé earns 115 million
# - appears_on_cover_of (Person, Magazine): Beyoncé appears_on_cover_of Vogue Magazine
# - performs_at (Person, Event): Beyoncé performs_at Super Bowl 50
# - spouse (Person, Person): Beyoncé is spouse of Jay-Z
#
#
# ### Questions
#
# - How can i represent dates and time-ranges in the knowledge graph ?
# - How can i represent sixth grammy award candidate

# %% [markdown]
# # Node Creation Script

# %% [markdown]
# // Create Album nodes
# CREATE (:Album {name: "Dangerously in Love"})
# CREATE (:Album {name: "The Writings on the Wall"})
# CREATE (:Album {name: "Survivor"})
# CREATE (:Album {name: "8 Days of Christmas"})
# CREATE (:Album {name: "Destiny Fulfilled"})
# CREATE (:Album {name: "BDay"})
# CREATE (:Album {name: "I Am Sasha Fierce"})
# CREATE (:Album {name: "4"})
# CREATE (:Album {name: "Beyoncé"})
# CREATE (:Album {name: "Selftitled Debut Album"})
# CREATE (:Album {name: "Love Songs"})
#
# // Create Organization nodes
# CREATE (:Organization {name: "Elektra Records"})
# CREATE (:Organization {name: "Dwayne Wigginss Grass Roots Entertainment"})
# CREATE (:Organization {name: "Recording Industry Association of America"})
# CREATE (:Organization {name: "Billboard"})
# CREATE (:Organization {name: "Time Magazine"})
# CREATE (:Organization {name: "Forbes Magazine"})
# CREATE (:Organization {name: "Warner Chappell Music"})
# CREATE (:Organization {name: "Pepsi"})
# CREATE (:Organization {name: "Sony Music"})
# CREATE (:Organization {name: "WarnerChappell Music"})
#
# // Create Location nodes
# CREATE (:Location {name: "Houston, Texas"})
# CREATE (:Location {name: "Fredericksburg, Texas"})
# CREATE (:Location {name: "Atlanta, Georgia"})
# CREATE (:Location {name: "Philadelphia"})
# CREATE (:Location {name: "Barcelona, Spain"})
# CREATE (:Location {name: "North America"})
# CREATE (:Location {name: "Europe"})
# CREATE (:Location {name: "Phoenix House"})
# CREATE (:Location {name: "Reliant Stadium"})
# CREATE (:Location {name: "Sony Club"})
# CREATE (:Location {name: "Manhattan, New York"})
# CREATE (:Location {name: "Lenox Hill Hospital, New York City"})
# CREATE (:Location {name: "Atlantic City, New Jersey"})
# CREATE (:Location {name: "Washington D.C."})
# CREATE (:Location {name: "Mercedes-Benz Superdome, New Orleans"})
#
# // Create Award nodes
# CREATE (:Award {name: "Grammy Award"})
# CREATE (:Award {name: "MTV Video Music Award"})
# CREATE (:Award {name: "BET Award"})
# CREATE (:Award {name: "Satellite Award"})
# CREATE (:Award {name: "NAACP Image Award"})
# CREATE (:Award {name: "New York Association of Black Journalists Award"})
# CREATE (:Award {name: "Top 100 List of Musician"})
# CREATE (:Award {name: "Scottish MOBO Award"})
# CREATE (:Award {name: "MTV Movie Award for Best Fight"})
# CREATE (:Award {name: "Record of the Year"})
# CREATE (:Award {name: "Single Ladies Put a Ring"})
# CREATE (:Award {name: "Highest Paid Performer"})
# CREATE (:Award {name: "Best Surround Sound Album"})
#
# // Create Course nodes
# CREATE (:Course {name: "Dance"})
# CREATE (:Course {name: "Sing"})
#
# // Create Activity nodes
# CREATE (:Activity {name: "Dancing"})
# CREATE (:Activity {name: "Singing"})
#
# // Create Music Type node
# CREATE (:MusicType {name: "Rap"})
#
# // Create Year node
# CREATE (:Year {value: 1981})
#
# // Create Month node
# CREATE (:Month {value: "September"})
#
# // Create Day nodes
# CREATE (:Day {value: 1}), (:Day {value: 2}), (:Day {value: 3}), (:Day {value: 4}), (:Day {value: 5}), (:Day {value: 6}), (:Day {value: 7})
#
# // Create School nodes
# CREATE (:School {name: "St Marys Elementary School"})
# CREATE (:School {name: "Parker Elementary School"})
# CREATE (:School {name: "Alief Elsik High School"})
#
# // Create Person nodes
# CREATE (:Person {name: "Beyoncé"})
# CREATE (:Person {name: "Shakira"})
# CREATE (:Person {name: "Taylor Swift"})
# CREATE (:Person {name: "Beck"})
# CREATE (:Person {name: "Jay-Z"})
# CREATE (:Person {name: "Blue Ivy Carter"})
# CREATE (:Person {name: "Marc Nelson"})
# CREATE (:Person {name: "Kelly Rowland"})
# CREATE (:Person {name: "Darlette Johnson"})
# CREATE (:Person {name: "Michelle Williams"})
# CREATE (:Person {name: "Destiny's Child"})
# CREATE (:Person {name: "Tina Knowles"})
# CREATE (:Person {name: "Mathew Knowles"})
# CREATE (:Person {name: "Solange Knowles"})
# CREATE (:Person {name: "Bianca Lawson"})
# CREATE (:Person {name: "LeToya Luckett"})
# CREATE (:Person {name: "LaTavia Roberson"})
# CREATE (:Person {name: "Farrah Franklin"})
# CREATE (:Person {name: "Dwayne Wiggins"})
# CREATE (:Person {name: "Mike Myers"})
# CREATE (:Person {name: "Cuba Gooding Jr"})
# CREATE (:Person {name: "Mekhi Phifer"})
# CREATE (:Person {name: "Jennifer Hudson"})
# CREATE (:Person {name: "Jamie Foxx"})
# CREATE (:Person {name: "Eddie Murphy"})
# CREATE (:Person {name: "Steve Martin"})
# CREATE (:Person {name: "Ali Larter"})
# CREATE (:Person {name: "Idris Elba"})
# CREATE (:Person {name: "Lauryn Hill"})
# CREATE (:Person {name: "Lady Gaga"})
# CREATE (:Person {name: "Jay-Z (rapper)"})
# CREATE (:Person {name: "Barack Obama"})
# CREATE (:Person {name: "Amy Winehouse"})
# CREATE (:Person {name: "André 3000"})
# CREATE (:Person {name: "Sia"})
# CREATE (:Person {name: "Etta James"})
# CREATE (:Person {name: "James At Last"})
# CREATE (:Person {name: "Sharon Charles"})
# CREATE (:Person {name: "Coldplay"})
#
# // Create Group nodes
# CREATE (:Group {name: "Destiny's Child"})
# CREATE (:Group {name: "Girls Tyme"})
# CREATE (:Group {name: "Boyz II Men"})
#
# // Create Event nodes
# CREATE (:Event {name: "Grammy Awards"})
# CREATE (:Event {name: "Super Bowl"})
# CREATE (:Event {name: "Met Gala"})
# CREATE (:Event {name: "On the Run Tour"})
# CREATE (:Event {name: "The Mrs. Carter Show World Tour"})
# CREATE (:Event {name: "Verizon Ladies First Tour"})
# CREATE (:Event {name: "Dangerously in Love Tour"})
# CREATE (:Event {name: "I Am World Tour"})
# CREATE (:Event {name: "4 Intimate Nights with Beyoncé concerts"})
# CREATE (:Event {name: "Revel - Presents Beyoncé Live concerts"})
#
# // Create Role nodes
# CREATE (:Role {name: "Foxxy Cleopatra"})
# CREATE (:Role {name: "Sharon Charles"})
# CREATE (:Role {name: "James At Last"})
#
# // Create Film nodes
# CREATE (:Film {name: "Dreamgirls"})
# CREATE (:Film {name: "The Pink Panther"})
# CREATE (:Film {name: "Austin Powers in Goldmember"})
# CREATE (:Film {name: "The Fighting Temptations"})
# CREATE (:Film {name: "Carmen: A Hip Hopera"})
# CREATE (:Film {name: "Cadillac Records"})
# CREATE (:Film {name: "Obsessed"})
# CREATE (:Film {name: "The Great Gatsby"})
# CREATE (:Film {name: "Epic"})
#
# // Create Song nodes
# CREATE (:Song {name: "Crazy in Love"})
# CREATE (:Song {name: "Baby Boy"})
# CREATE (:Song {name: "Me Myself and I"})
# CREATE (:Song {name: "Naughty Girl"})
# CREATE (:Song {name: "The Closer I Get to You"})
# CREATE (:Song {name: "Lose My Breath"})
# CREATE (:Song {name: "Soldier"})
# CREATE (:Song {name: "Déjà Vu"})
# CREATE (:Song {name: "Irreplaceable"})
# CREATE (:Song {name: "Ring the Alarm"})
# CREATE (:Song {name: "Get Me Bodied"})
# CREATE (:Song {name: "Green Light"})
# CREATE (:Song {name: "Listen"})
# CREATE (:Song {name: "Single Ladies (Put a Ring on It)"})
# CREATE (:Song {name: "If I Were a Boy"})
# CREATE (:Song {name: "Halo"})
# CREATE (:Song {name: "Sweet Dreams"})
# CREATE (:Song {name: "Diva"})
# CREATE (:Song {name: "Ego"})
# CREATE (:Song {name: "Broken-Hearted Girl"})
# CREATE (:Song {name: "Video Phone"})
# CREATE (:Song {name: "Telephone"})
# CREATE (:Song {name: "At Last"})
# CREATE (:Song {name: "Run the World (Girls)"})
# CREATE (:Song {name: "Best Thing I Never Had"})
# CREATE (:Song {name: "Love on Top"})
# CREATE (:Song {name: "Party"})
# CREATE (:Song {name: "Countdown"})
# CREATE (:Song {name: "I Care"})
# CREATE (:Song {name: "End of Time"})
# CREATE (:Song {name: "Nuclear"})
# CREATE (:Song {name: "Back to Black"})
# CREATE (:Song {name: "Rise Up"})
# CREATE (:Song {name: "Drunk in Love"})
# CREATE (:Song {name: "Pretty Hurts"})
# CREATE (:Song {name: "Hymn for the Weekend"})
# CREATE (:Song {name: "Say My Name"})
# CREATE (:Song {name: "Work It Out"})
# CREATE (:Song {name: "Belong with Me"})
# CREATE (:Song {name: "World Girls"})
# CREATE (:Song {name: "Best Things I Never Had"})
# CREATE (:Song {name: "God Made You"})
# CREATE (:Song {name: "The Great Gatsby"})

# %%
from gpt4all import GPT4All
model = GPT4All("/Users/mertakcay/Projects/Knowledge Graphs/KnowledgeGraphBuilder/mistral-7b-instruct-v0.1.Q4_0.gguf")

# %%
prompt_ner = f'''
Extract Noun, Verb, Object between Tags from text: {example_context} in json format
'''
print(prompt_ner)
# Out:
# Extract Noun, Verb, Object between Tags from text: A selfdescribed modernday feminist Beyoncé creates songs that are often characterized by themes of love relationships and monogamy as well as female sexuality and empowerment On stage her dynamic highly choreographed performances have led to critics hailing her as one of the best entertainers in contemporary popular music Throughout a career spanning 19 years she has sold over 118 million records as a solo artist and a further 60 million with Destinys Child making her one of the bestselling music artists of all time She has won 20 Grammy Awards and is the most nominated woman in the awards history The Recording Industry Association of America recognized her as the Top Certified Artist in America during the 2000s decade In 2009 Billboard named her the Top Radio Songs Artist of the Decade the Top Female Artist of the 2000s and their Artist of the Millennium in 2011 Time listed her among the 100 most influential people in the world in 2
# ...

# %%
output = model.generate(prompt_ner, max_tokens=8192)
print(output)
# Out:
# {
# "Nouns": ["Beyoncé", "feminist", "performances", "records", "Grammy Awards", "Radio Songs Artist", "Artist of the Millennium", "Forbes magazine"],
# "Verbs": ["creates", "have led to", "has sold", "are characterized by", "have won", "recognized as", "named", "listed", "is listed", "is recognized as", "is named", "is listed", "is the most powerful female musician of 2015"],
# "Objects": ["songs that are often characterized by themes of love relationships and monogamy as well as female sexuality and empowerment", "over 118 million records as a solo artist and a further 60 million with Destinys Child making her one of the bestselling music artists of all time", "20 Grammy Awards", "Top Certified Artist in America during the 2000s decade", "Billboard named her the Top Radio Songs Artist of the Decade", "the most influential people in the world in 2013 and 2014", "most powerful female musician of 2015"]
# }

# %%
import json
output_json = json.loads(output)
output_json
# Out:
# {'Nouns': ['Beyoncé',
#   'feminist',
#   'performances',
#   'records',
#   'Grammy Awards',
#   'Radio Songs Artist',
#   'Artist of the Millennium',
#   'Forbes magazine'],
#  'Verbs': ['creates',
#   'have led to',
#   'has sold',
#   'are characterized by',
#   'have won',
#   'recognized as',
#   'named',
#   'listed',
#   'is listed',
#   'is recognized as',
#   'is named',
#   'is listed',
#   'is the most powerful female musician of 2015'],
#  'Objects': ['songs that are often characterized by themes of love relationships and monogamy as well as female sexuality and empowerment',
#   'over 118 million records as a solo artist and a further 60 million with Destinys Child making her one of the bestselling music artists of all time',
#   '20 Grammy Awards',
#   'Top Certified Artist in America during the 2000s decade',
#   'Billboard named her the Top Radio Songs Artist of the Decade',
#   'the most influential people in the world in 2013 and 2014',
# ...

# %%
# for verb in output_dict['Verb']:
#     prompt_relationship = f'''
#     Extract Relationship between: {output_dict['Subject'], verb} and {','.join(output_dict['Object'])} from {example_context}
#     '''
#     relationship_output = model.generate(prompt_relationship, max_tokens=512)
#     print(relationship_output)
    
    
# for verb in output_dict['Verb']:
prompt_relationship = f'''
Extract Relationship between: {output_json} json format
'''
relationship_output = model.generate(prompt_relationship, max_tokens=8192)
print(relationship_output)
# Out:
# ```json
# {
#     "Nouns": ["Beyoncé", "feminist", "performances", "records", "Grammy Awards", "Radio Songs Artist", "Artist of the Millennium", "Forbes magazine"],
#     "Verbs": ["creates", "have led to", "has sold", "are characterized by", "have won", "recognized as", "named", "listed", "is listed", "is recognized as", "is named", "is listed", "is the most powerful female musician of 2015"],
#     "Objects": ["songs that are often characterized by themes of love relationships and monogamy as well as female sexuality and empowerment", "over 118 million records as a solo artist and a further 60 million with Destinys Child making her one of the bestselling music artists of all time", "20 Grammy Awards", "Top Certified Artist in America during the 2000s decade", "Billboard named her the Top Radio Songs Artist of the Decade", "the most influential people in the world in 2013 and 2014", "most powerful female musician of 2015"]
# }
# ```

# %%
relationship_output.replace('-','').split('\n')
# Out:
# [' Beyoncé creates music.',
#  ' Beyoncé performs live shows.',
#  ' Beyoncé sells merchandise and concert tickets.',
#  ' Beyoncé wins awards for her work.',
#  ' Beyoncé is recognized as a top artist in various categories.',
#  ' Beyoncé is named one of the most influential people in music history.',
#  " Beyoncé's songs are listed on charts and playlists.",
#  ' Beyoncé has won Grammy Awards for her albums and singles.',
#  " Beyoncé's work spans multiple decades.",
#  ' Beyoncé is considered a top radio artist, with many of her songs becoming hits.',
#  ' Beyoncé is often cited as the best female artist of all time.',
#  ' Beyoncé has had a significant impact on popular culture and music for over two millennia.']

# %%
for sentence in relationship_output:
    prompt_lemminize = f'''
    Lemminize text: {sentence}
    '''
    relationship_output = model.generate(prompt_lemminize, max_tokens=512)
    print(relationship_output)
# Out:
# ------------------
#     lemmatize('I have a dog that barks loudly.')
#     ['have', 'dog', 'bark']
#
#     lemmatize('The quick brown fox jumps over the lazy dog.')
#     ['quick', 'brown', 'fox', 'jump', 'lazy', 'dog']
# ------------------
#     **Lemmatization** is the process of reducing a word to its base or dictionary form. This can be done using various algorithms and techniques, such as morphological analysis or statistical modeling. In natural language processing, lemmatization is often used to normalize text data by converting words to their root forms, which can help improve the accuracy of downstream tasks like information retrieval, sentiment analysis, and machine translation. Lemmatization can also be useful for reducing the dimensionality of word embeddings or for improving the performance of language models.
#
# ...
