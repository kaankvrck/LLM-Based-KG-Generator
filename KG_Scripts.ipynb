# %% [markdown]
# # Ontology

# %% [markdown]
# Concepts:
# - Year: 1981
# - Month: September
# - Day: 1,2,3,4,5,6,7
# - School: St Marys Elementary School, Parker Elementary School, Alief Elsik High School
# - Person: Beyoncé, Shakira, Taylor Swifts, Beck, Jay-Z, Blue Ivy Carter, Marc Nelson, Kelly Rowland, Darlette Johnson, Michelle Williams, Destinys Child, Tina Knowles, Mathew Knowles, Solange Knowles, Bianca Lawson, LeToya Luckett, LaTavia Roberson, Farrah Franklin, Dwayne Wiggins, Mike Myers, Cuba Gooding Jr, Mekhi Phifer, Jennifer Hudson, Jamie Foxx, Eddie Murphy, Steve Martin, Ali Larter, Idris Elba, Lauryn Hill, Lady Gaga, Jay-Z (rapper), Barack Obama, Amy Winehouse, André 3000, Sia, Etta James, James At Last, Sharon Charles, Coldplay
# - Group: Destiny's Child, Girls Tyme, Boyz II Men
# - Event: Grammy Awards, Super Bowl, Met Gala, On the Run Tour, The Mrs. Carter Show World Tour, Verizon Ladies First Tour, Dangerously in Love Tour, I Am World Tour, 4 Intimate Nights with Beyoncé concerts, Revel - Presents Beyoncé Live concerts
# - Role: Foxxy Cleopatra, Sharon Charles, James At Last
# - Film: Dreamgirls, The Pink Panther, Austin Powers in Goldmember, The Fighting Temptations, Carmen: A Hip Hopera, Cadillac Records, Obsessed, The Great Gatsby, Epic
# - Song: Crazy in Love, Baby Boy, Me Myself and I, Naughty Girl, The Closer I Get to You, Lose My Breath, Soldier, Déjà Vu, Irreplaceable, Ring the Alarm, Get Me Bodied, Green Light, Listen, Single Ladies (Put a Ring on It), If I Were a Boy, Halo, Sweet Dreams, Diva, Ego, Broken-Hearted Girl, Video Phone, Telephone, At Last, Run the World (Girls), Best Thing I Never Had, Love on Top, Party, Countdown, I Care, End of Time, Nuclear, Back to Black, Rise Up, Drunk in Love, Pretty Hurts, Hymn for the Weekend, Say My Name, Work It Out, Belong with Me, World Girls, Best Things I Never Had, God Made You, The Great Gatsby
#
# - Album: Dangerously in Love, The Writings on the Wall, Survivor, 8 Days of Christmas, Destiny Fulfilled, BDay, I Am Sasha Fierce, 4, Beyoncé, Selftitled Debut Album, Love Songs
# - Organization: Elektra Records, Dwayne Wigginss Grass Roots Entertainment, Recording Industry Association of America, Billboard, Time Magazine, Forbes Magazine, Warner Chappell Music, Pepsi, Sony Music, WarnerChappell Music
# - Location: Houston, Texas, Fredericksburg, Texas, Atlanta, Georgia, Philadelphia, Barcelona, Spain, North America, Europe, Phoenix House, Reliant Stadium, Sony Club, Manhattan, New York, Lenox Hill Hospital, New York City, Atlantic City, New Jersey, Washington D.C., Mercedes-Benz Superdome, New Orleans
# - Award: Grammy Award, MTV Video Music Award, BET Award, Satellite Award, NAACP Image Award, New York Association of Black Journalists Award, Top 100 List of Musician, Scottish MOBO Award, MTV Movie Award for Best Fight, Record of the Year, Single Ladies Put a Ring, Highest Paid Performer, Best Surround Sound Album
# - Course: Dance, Sing
# - Activity: Dancing, Singing
# - Music Type: Rap
#
# Relations:
# - born (Person, Day): Beyoncé born 4
# - born (Person, Month): Beyoncé born September
# - born (Person, Year): Beyoncé born 1981
# - sign_at (Person, Year): Beyoncé sign_at 1995 Girls Tyme sign_at 1996
# - sign (Person, Organization): Beyoncé sign Elektra Records,Girls Tyme sign Elektra Records,Girls Tyme sign Dwayne Wigginss Grass Roots Entertainment, Beyoncé sign Columbia Records, Beyoncé sign WarnerChappell Music
# - nationality (Person, Country): Beyoncé nationality American
# - has_job (Person, Job): Beyoncé has_job singer, Beyoncé has_job producer, Beyoncé has_job dancing
# - has_father (Person, Person): Beyoncé has_father Mathew Knowles
# - married (Person, Person): Beyoncé married Jay-Z
# - changed_name (Person, Group): Girls Tyme changed_name Destinys Child
# - friend (Person, Person): Beyoncé friend Kelly Rowland, Beyoncé friend LaTavia Roberson,  LaTavia Roberson friend Kelly Rowland
# - has_child (Person, Person): Beyoncé has_child Blue Ivy Carter
# - has_mother (Person, Person): Blue Ivy Carter has_mother Beyoncé
# - move (Person, Location): Beyoncé move Atalanta, Girls Tyme move Atalanta
# - music_type (Person, Music Type) Beyoncé music_type Rap
# - records_at (Person, Organization): Beyoncé records_at Sony Music
# - attend (Person, Event): Beyoncé attend Dangerously in Love Tour, Beyoncé attend Verizon Ladies, Beyoncé attend I Am World Tour,
# - attend (Person, School): Beyoncé attend St Marys Elementary School, Darlette Johnson attend St Marys Elementary School, Beyoncé attend Parker Elementary School, Beyoncé attend Alief Elsik High School
# - part_of (Person, Group): Marc Nelson part_of Boyz II Men
# - leave (Person, Group): Beyoncé leave Destiny's Child
# - discover (Person, Person): Darlette Johnson discover Beyoncé
# - interests (Person, Course): Beyoncé interests Dancing, Beyoncé interests Singing
# - locate (School, Location): St Marys Elementary School locate Texas, Parker Elementary School locate Houston
# - has_course (School, Course) St Marys Elementary School has_course Sing, St Marys Elementary School has_course Dance
# - influence (Person, Person): Etta James influence Beyoncé
# - list (Organization, Award): Forbes list Top 100 List of Musician
# - sings_in (Person, Group): Beyoncé sings_in Destiny's Child, Beyoncé sings_in Girls Tyme
# - sing_in (Song, Album): Déjà Vu sing_in BDay
# - releases (Person, Song): Beyoncé releases Crazy in Love, Girls Tyme releases, Beyoncé releases Work It Out, Beyoncé releases Me Myself and I, Beyoncé releases Naughty Girl, Beyoncé releases Irreplaceable, Beyoncé releases Ring the Alarm, Beyoncé releases Get Me Bodied, Beyoncé releases Green Light, Beyoncé releases Listen, Beyoncé releases Single Ladies (Put a Ring on It), Beyoncé releases SweetDreams, Taylor Swifts releases Belong with Me, Beyoncé releases Telephone, Beyoncé releases World Girls, Beyoncé Best Things I Never Had, Beyoncé releases Love On Top, Beyoncé releases God Made You
# - manages (Person, Person): Mathew Knowles manages Beyoncé, Mathew Knowles manages Girls Tyme
# - releases (Person, Album): Beyoncé releases Dangerously in Love, Beyoncé releases BDay, Beyoncé releases I Am Sasha, Beyoncé releases Halo, Beyoncé releases Love Songs
# - releases (Group, Album): Destiny's Child releases The Writings on the Wall, Destiny's Child releases Selftitled Debut Album, Destiny's Child releases Survivor, Destiny's Child releases Destiny Fulfilled
# - act (Person, Role): Beyoncé act Foxxy Cleopatra, Beyoncé, act Lilly, Beyonce act James At Last, Sharon Charles
# - act (Person, Film): Beyoncé act Austin Powers, Beyoncé act The Fighting Temptations, Beyoncé act The Pink Panther, Beyoncé act Dreamgirls, Beyoncé act Epic
# - wins (Person, Award): Beyoncé wins Grammy Award, Beyoncé wins MTV Europe Music, Beyoncé wins Scottish MOBO Award, Beyoncé wins BET Award, Beyoncé wins MTV Video Music Award, Beyonce wins MTV Movie Award for Best Fight, Beyoncé wins Record of the Year, Beyoncé wins Single Ladies Put a Ring, Beyoncé wins Highest Paid Performer, Beck wins Best Surround Sound Album
# - wins (Group, Award): Destiny's Child wins Best RB Performance, Destiny's Child wins Grammy Award
# - with_duet (Person, Person): Beyoncé with_duet Marc Nelson, Beyoncé with_duet Shakira, Beyoncé with_duet Sasha Fierce, Beyoncé with_duet Coldplay
# - with_act (Person, Person): Beyoncé with_act Steve Martin, Beyoncé with_act Jamie Foxx, Beyoncé with_act Eddie Murphy, Eddie Murphy with_act Jamie Foxx, Beyoncé with_act Ali Larter
# - tours (Person, Event): Beyoncé tours The Mrs. Carter Show World Tour
# - headlines (Person, Event): Beyoncé headlines Glastonbury Festival
# - directs (Person, Film): Beyoncé directs Life Is But a Dream
# - covers (Person, Song): Beyoncé covers Back to Black, Beyoncé covers The Great Gatsby
# - features_in (Person, Song): Beyoncé features_in Drunk in Love
# - co-writes (Person, Person, Song): Beyoncé co-writes Rise Up *with Sia*
# - earns (Person, Money): Beyoncé earns 115 million
# - appears_on_cover_of (Person, Magazine): Beyoncé appears_on_cover_of Vogue Magazine
# - performs_at (Person, Event): Beyoncé performs_at Super Bowl 50
# - spouse (Person, Person): Beyoncé is spouse of Jay-Z
#
#
# ### Questions
#
# - How can i represent dates and time-ranges in the knowledge graph ?
# - How can i represent sixth grammy award candidate

# %% [markdown]
# # Manual KG Creation Scripts

# %%
What is relation between (People, X) relation to extract Ontology

# %% [markdown]
# // Nodes
# CREATE (Beyonce:Person {name: "Beyoncé"})
# CREATE (GirlsTyme:Group {name: "Girls Tyme"})
# CREATE (DestinysChild:Group {name: "Destiny's Child"})
# CREATE (MathewKnowles:Person {name: "Mathew Knowles"})
# CREATE (BlueIvyCarter:Person {name: "Blue Ivy Carter"})
# CREATE (JayZ:Person {name: "Jay-Z"})
# CREATE (MarcNelson:Person {name: "Marc Nelson"})
# CREATE (EttaJames:Person {name: "Etta James"})
# CREATE (DarletteJohnson:Person {name: "Darlette Johnson"})
# CREATE (TaylorSwift:Person {name: "Taylor Swift"})
# CREATE (Shakira:Person {name: "Shakira"})
# CREATE (SashaFierce:Person {name: "Sasha Fierce"})
# CREATE (Coldplay:Person {name: "Coldplay"})
# CREATE (SteveMartin:Person {name: "Steve Martin"})
# CREATE (JamieFoxx:Person {name: "Jamie Foxx"})
# CREATE (EddieMurphy:Person {name: "Eddie Murphy"})
# CREATE (AliLarter:Person {name: "Ali Larter"})
# CREATE (Sia:Person {name: "Sia"})
# CREATE (Beck:Person {name: "Beck"})
#
# CREATE (ElektraRecords:Organization {name: "Elektra Records"})
# CREATE (GrassRootsEntertainment:Organization {name: "Grass Roots Entertainment"})
# CREATE (ColumbiaRecords:Organization {name: "Columbia Records"})
# CREATE (WarnerChappellMusic:Organization {name: "WarnerChappell Music"})
# CREATE (SonyMusic:Organization {name: "Sony Music"})
# CREATE (Forbes:Organization {name: "Forbes"})
# CREATE (VogueMagazine:Magazine {name: "Vogue Magazine"})
#
# CREATE (StMarysElementarySchool:School {name: "St Mary's Elementary School"})
# CREATE (ParkerElementarySchool:School {name: "Parker Elementary School"})
# CREATE (AliefElsikHighSchool:School {name: "Alief Elsik High School"})
#
# CREATE (GrammyAward:Award {name: "Grammy Award"})
# CREATE (MTVEuropeMusic:Award {name: "MTV Europe Music"})
# CREATE (ScottishMOBOAward:Award {name: "Scottish MOBO Award"})
# CREATE (BETAward:Award {name: "BET Award"})
# CREATE (MTVVideoMusicAward:Award {name: "MTV Video Music Award"})
# CREATE (MTVMovieAward:Award {name: "MTV Movie Award for Best Fight"})
# CREATE (RecordOfTheYear:Award {name: "Record of the Year"})
# CREATE (SingleLadiesAward:Award {name: "Single Ladies Put a Ring"})
# CREATE (HighestPaidPerformer:Award {name: "Highest Paid Performer"})
# CREATE (BestRBPerformance:Award {name: "Best RB Performance"})
# CREATE (BestSurroundSoundAlbum:Award {name: "Best Surround Sound Album"})
#
# CREATE (DangerouslyInLoveTour:Event {name: "Dangerously in Love Tour"})
# CREATE (VerizonLadies:Event {name: "Verizon Ladies"})
# CREATE (IAmWorldTour:Event {name: "I Am World Tour"})
# CREATE (GlastonburyFestival:Event {name: "Glastonbury Festival"})
# CREATE (SuperBowl50:Event {name: "Super Bowl 50"})
# CREATE (TheMrsCarterShowWorldTour:Event {name: "The Mrs. Carter Show World Tour"})
#
# CREATE (Rap:MusicType {name: "Rap"})
# CREATE (Sing:Course {name: "Sing"})
# CREATE (Dance:Course {name: "Dance"})
#
# CREATE (Atalanta:Location {name: "Atalanta"})
# CREATE (Texas:Location {name: "Texas"})
# CREATE (Houston:Location {name: "Houston"})
#
# CREATE (BDay:Album {name: "BDay"})
# CREATE (LifeIsButADream:Film {name: "Life Is But a Dream"})
# CREATE (AustinPowers:Film {name: "Austin Powers"})
# CREATE (TheFightingTemptations:Film {name: "The Fighting Temptations"})
# CREATE (ThePinkPanther:Film {name: "The Pink Panther"})
# CREATE (Dreamgirls:Film {name: "Dreamgirls"})
# CREATE (Epic:Film {name: "Epic"})
# CREATE (BackToBlack:Song {name: "Back to Black"})
# CREATE (TheGreatGatsby:Song {name: "The Great Gatsby"})
# CREATE (DrunkInLove:Song {name: "Drunk in Love"})
# CREATE (RiseUp:Song {name: "Rise Up"})
# CREATE (BelongWithMe:Song {name: "Belong with Me"})
# CREATE (Telephone:Song {name: "Telephone"})
# CREATE (WorldGirls:Song {name: "World Girls"})
# CREATE (BestThingsINeverHad:Song {name: "Best Things I Never Had"})
# CREATE (LoveOnTop:Song {name: "Love On Top"})
# CREATE (GodMadeYou:Song {name: "God Made You"})
# CREATE (NaughtyGirl:Song {name: "Naughty Girl"})
# CREATE (Irreplaceable:Song {name: "Irreplaceable"})
# CREATE (RingTheAlarm:Song {name: "Ring the Alarm"})
# CREATE (GetMeBodied:Song {name: "Get Me Bodied"})
# CREATE (GreenLight:Song {name: "Green Light"})
# CREATE (Listen:Song {name: "Listen"})
# CREATE (SingleLadies:Song {name: "Single Ladies (Put a Ring on It)"})
# CREATE (SweetDreams:Song {name: "Sweet Dreams"})
# CREATE (CrazyInLove:Song {name: "Crazy in Love"})
# CREATE (WorkItOut:Song {name: "Work It Out"})
# CREATE (MeMyselfAndI:Song {name: "Me Myself and I"})
# CREATE (FoxxyCleopatra:Role {name: "Foxxy Cleopatra"})
# CREATE (Lilly:Role {name: "Lilly"})
# CREATE (James:Role {name: "James"})
# CREATE (SharonCharles:Role {name: "Sharon Charles"})
#
# // Relationships
# CREATE (Beyonce)-[:born]->(:Day {day: 4})
# CREATE (Beyonce)-[:born]->(:Month {month: "September"})
# CREATE (Beyonce)-[:born]->(:Year {year: 1981})
# CREATE (Beyonce)-[:sign_at]->(:Year {year: 1995})
# CREATE (GirlsTyme)-[:sign_at]->(:Year {year: 1996})
# CREATE (Beyonce)-[:sign]->(:Organization {name: "Elektra Records"})
# CREATE (GirlsTyme)-[:sign]->(:Organization {name: "Elektra Records"})
# CREATE (GirlsTyme)-[:sign]->(:Organization {name: "Grass Roots Entertainment"})
# CREATE (Beyonce)-[:sign]->(:Organization {name: "Columbia Records"})
# CREATE (Beyonce)-[:sign]->(:Organization {name: "WarnerChappell Music"})
# CREATE (Beyonce)-[:nationality]->(:Country {name: "American"})
# CREATE (Beyonce)-[:has_job]->(:Job {name: "singer"})
# CREATE (Beyonce)-[:has_job]->(:Job {name: "producer"})
# CREATE (Beyonce)-[:has_job]->(:Job {name: "dancing"})
# CREATE (Beyonce)-[:has_father]->(MathewKnowles)
# CREATE (Beyonce)-[:married]->(JayZ)
# CREATE (GirlsTyme)-[:changed_name]->(DestinysChild)
# CREATE (Beyonce)-[:friend]->(:Person {name: "Kelly Rowland"})
# CREATE (Beyonce)-[:friend]->(:Person {name: "LaTavia Roberson"})
# CREATE (:Person {name: "LaTavia Roberson"})-[:friend]->(:Person {name: "Kelly Rowland"})
# CREATE (Beyonce)-[:has_child]->(BlueIvyCarter)
# CREATE (BlueIvyCarter)-[:has_mother]->(Beyonce)
# CREATE (Beyonce)-[:move]->(:Location {name: "Atalanta"})
# CREATE (GirlsTyme)-[:move]->(:Location {name: "Atalanta"})
# CREATE (Beyonce)-[:music_type]->(Rap)
# CREATE (Beyonce)-[:records_at]->(SonyMusic)
# CREATE (Beyonce)-[:attend]->(DangerouslyInLoveTour)
# CREATE (Beyonce)-[:attend]->(VerizonLadies)
# CREATE (Beyonce)-[:attend]->(IAmWorldTour)
# CREATE (Beyonce)-[:attend]->(GlastonburyFestival)
# CREATE (Beyonce)-[:attend]->(SuperBowl50)
# CREATE (Beyonce)-[:attend]->(TheMrsCarterShowWorldTour)
# CREATE (MarcNelson)-[:part_of]->(DestinysChild)
# CREATE (Beyonce)-[:leave]->(DestinysChild)
# CREATE (DarletteJohnson)-[:discover]->(Beyonce)
# CREATE (Beyonce)-[:interests]->(:Course {name: "Dancing"})
# CREATE (Beyonce)-[:interests]->(:Course {name: "Singing"})
# CREATE (StMarysElementarySchool)-[:locate]->(Texas)
# CREATE (ParkerElementarySchool)-[:locate]->(Houston)
# CREATE (StMarysElementarySchool)-[:has_course]->(:Course {name: "Sing"})
# CREATE (StMarysElementarySchool)-[:has_course]->(:Course {name: "Dance"})
# CREATE (EttaJames)-[:influence]->(Beyonce)
# CREATE (Forbes)-[:list]->(:Award {name: "Top 100 List of Musician"})
# CREATE (Beyonce)-[:sings_in]->(DestinysChild)
# CREATE (Beyonce)-[:sings_in]->(GirlsTyme)
# CREATE (:Song {name: "Déjà Vu"})-[:sing_in]->(BDay)
# CREATE (Beyonce)-[:releases]->(:Song {name: "Crazy in Love"})
# CREATE (GirlsTyme)-[:releases]->(:Song {name: "Work It Out"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Me Myself and I"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Naughty Girl"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Irreplaceable"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Ring the Alarm"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Get Me Bodied"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Green Light"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Listen"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Single Ladies (Put a Ring on It)"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Sweet Dreams"})
# CREATE (TaylorSwift)-[:releases]->(:Song {name: "Belong with Me"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Telephone"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "World Girls"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Best Things I Never Had"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "Love On Top"})
# CREATE (Beyonce)-[:releases]->(:Song {name: "God Made You"})
# CREATE (Beyonce)-[:manages]->(MathewKnowles)
# CREATE (GirlsTyme)-[:manages]->(MathewKnowles)
# CREATE (Beyonce)-[:releases]->(:Album {name: "Dangerously in Love"})
# CREATE (Beyonce)-[:releases]->(:Album {name: "BDay"})
# CREATE (Beyonce)-[:releases]->(:Album {name: "I Am Sasha"})
# CREATE (Beyonce)-[:releases]->(:Album {name: "Halo"})
# CREATE (Beyonce)-[:releases]->(:Album {name: "Love Songs"})
# CREATE (DestinysChild)-[:releases]->(:Album {name: "The Writings on the Wall"})
# CREATE (DestinysChild)-[:releases]->(:Album {name: "Selftitled Debut Album"})
# CREATE (DestinysChild)-[:releases]->(:Album {name: "Survivor"})
# CREATE (DestinysChild)-[:releases]->(:Album {name: "Destiny Fulfilled"})
# CREATE (Beyonce)-[:act]->(:Role {name: "Foxxy Cleopatra"})
# CREATE (Beyonce)-[:act]->(:Role {name: "Lilly"})
# CREATE (Beyonce)-[:act]->(:Role {name: "James"})
# CREATE (Beyonce)-[:act]->(:Role {name: "Sharon Charles"})
# CREATE (Beyonce)-[:act]->(:Film {name: "Austin Powers"})
# CREATE (Beyonce)-[:act]->(:Film {name: "The Fighting Temptations"})
# CREATE (Beyonce)-[:act]->(:Film {name: "The Pink Panther"})
# CREATE (Beyonce)-[:act]->(:Film {name: "Dreamgirls"})
# CREATE (Beyonce)-[:act]->(:Film {name: "Epic"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "Grammy Award"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "MTV Europe Music"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "Scottish MOBO Award"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "BET Award"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "MTV Video Music Award"})
# CREATE (Beyonce)-[:wins]->(:Award {name: "MTV Movie Award for Best Fight"})

# %% [markdown]
# # LLM-Manual KG Creation Scripts

# %% [markdown]
# CREATE (beyonce:Person {name: "Beyoncé"})
#
# WITH beyonce
#
# CREATE (solange:Person {name: "Solange"})
# CREATE (michelleObama:Person {name: "Michelle Obama"})
# CREATE (barackObama:Person {name: "Barack Obama"})
# CREATE (mathewKnowles:Person {name: "Mathew Knowles"})
# CREATE (aliLarter:Person {name: "Ali Larter"})
# CREATE (idrisElba:Person {name: "Idris Elba"})
# CREATE (britneySpears:Person {name: "Britney Spears"})
# CREATE (pink:Person {name: "Pink"})
# CREATE (enriqueIglesias:Person {name: "Enrique Iglesias"})
# CREATE (amyWinehouse:Person {name: "Amy Winehouse"})
# CREATE (mariahCareys:Person {name: "Mariah Carey"})
# CREATE (drake:Person {name: "Drake"})
# CREATE (steveMartin:Person {name: "Steve Martin"})
# CREATE (jenniferHudson:Person {name: "Jennifer Hudson"})
# CREATE (jamieFoxx:Person {name: "Jamie Foxx"})
# CREATE (eddieMurphy:Person {name: "Eddie Murphy"})
# CREATE (mikeMyers:Person {name: "Mike Myers"})
# CREATE (cubaGoodingJr:Person {name: "Cuba Gooding Jr"})
# CREATE (angelaMerkel:Person {name: "Angela Merkel"})
# CREATE (nkosazanaDlaminiZuma:Person {name: "Nkosazana Dlamini-Zuma"})
# CREATE (salmaHayek:Person {name: "Salma Hayek"})
# CREATE (fridaGiannini:Person {name: "Frida Giannini"})
# CREATE (beyonceRowland:Person {name: "Beyoncé Rowland"})
# CREATE (farrahFranklin:Person {name: "Farrah Franklin"})
# CREATE (michelleWilliams:Person {name: "Michelle Williams"})
# CREATE (chimamandaNgoziAdichie:Person {name: "Chimamanda Ngozi Adichie"})
# CREATE (jayZ:Person {name: "Jay Z"})
# CREATE (lenoxHillHospital:Place {name: "Lenox Hill Hospital"})
# CREATE (emmettPrice:Person {name: "Emmett Price"})
# CREATE (rudyPerez:Person {name: "Rudy Perez"})
# CREATE (jonPareles:Person {name: "Jon Pareles"})
#
# WITH beyonce
#
# MATCH (solange:Person {name: "Solange"})
# MATCH (michelleObama:Person {name: "Michelle Obama"})
# MATCH (barackObama:Person {name: "Barack Obama"})
# MATCH (mathewKnowles:Person {name: "Mathew Knowles"})
# MATCH (aliLarter:Person {name: "Ali Larter"})
# MATCH (idrisElba:Person {name: "Idris Elba"})
# MATCH (britneySpears:Person {name: "Britney Spears"})
# MATCH (pink:Person {name: "Pink"})
# MATCH (enriqueIglesias:Person {name: "Enrique Iglesias"})
# MATCH (amyWinehouse:Person {name: "Amy Winehouse"})
# MATCH (mariahCareys:Person {name: "Mariah Carey"})
# MATCH (drake:Person {name: "Drake"})
# MATCH (steveMartin:Person {name: "Steve Martin"})
# MATCH (jenniferHudson:Person {name: "Jennifer Hudson"})
# MATCH (jamieFoxx:Person {name: "Jamie Foxx"})
# MATCH (eddieMurphy:Person {name: "Eddie Murphy"})
# MATCH (mikeMyers:Person {name: "Mike Myers"})
# MATCH (cubaGoodingJr:Person {name: "Cuba Gooding Jr"})
# MATCH (angelaMerkel:Person {name: "Angela Merkel"})
# MATCH (nkosazanaDlaminiZuma:Person {name: "Nkosazana Dlamini-Zuma"})
# MATCH (salmaHayek:Person {name: "Salma Hayek"})
# MATCH (fridaGiannini:Person {name: "Frida Giannini"})
# MATCH (beyonceRowland:Person {name: "Beyoncé Rowland"})
# MATCH (farrahFranklin:Person {name: "Farrah Franklin"})
# MATCH (michelleWilliams:Person {name: "Michelle Williams"})
# MATCH (chimamandaNgoziAdichie:Person {name: "Chimamanda Ngozi Adichie"})
# MATCH (jayZ:Person {name: "Jay Z"})
# MATCH (lenoxHillHospital:Place {name: "Lenox Hill Hospital"})
# MATCH (emmettPrice:Person {name: "Emmett Price"})
# MATCH (rudyPerez:Person {name: "Rudy Perez"})
# MATCH (jonPareles:Person {name: "Jon Pareles"})
#
# CREATE (beyonce)-[:HAS_SISTER]->(solange)
# CREATE (beyonce)-[:KNOWS]->(michelleObama)
# CREATE (beyonce)-[:KNOWS]->(barackObama)
# CREATE (beyonce)-[:KNOWS]->(mathewKnowles)
# CREATE (beyonce)-[:WORKED_WITH]->(aliLarter)
# CREATE (beyonce)-[:WORKED_WITH]->(idrisElba)
# CREATE (beyonce)-[:WORKED_WITH]->(britneySpears)
# CREATE (beyonce)-[:WORKED_WITH]->(pink)
# CREATE (beyonce)-[:WORKED_WITH]->(enriqueIglesias)
# CREATE (beyonce)-[:KNOWS]->(amyWinehouse)
# CREATE (beyonce)-[:KNOWS]->(mariahCareys)
# CREATE (beyonce)-[:KNOWS]->(drake)
# CREATE (beyonce)-[:WORKED_WITH]->(steveMartin)
# CREATE (beyonce)-[:WORKED_WITH]->(jenniferHudson)
# CREATE (beyonce)-[:WORKED_WITH]->(jamieFoxx)
# CREATE (beyonce)-[:WORKED_WITH]->(eddieMurphy)
# CREATE (beyonce)-[:WORKED_WITH]->(mikeMyers)
# CREATE (beyonce)-[:WORKED_WITH]->(cubaGoodingJr)
# CREATE (beyonce)-[:KNOWS]->(angelaMerkel)
# CREATE (beyonce)-[:KNOWS]->(nkosazanaDlaminiZuma)
# CREATE (beyonce)-[:WORKED_WITH]->(salmaHayek)
# CREATE (beyonce)-[:WORKED_WITH]->(fridaGiannini)
# CREATE (beyonce)-[:HAS_FRIEND]->(beyonceRowland)
# CREATE (beyonce)-[:WORKED_WITH]->(farrahFranklin)
# CREATE (beyonce)-[:WORKED_WITH]->(michelleWilliams)
# CREATE (beyonce)-[:KNOWS]->(chimamandaNgoziAdichie)
# CREATE (beyonce)-[:COLLABORATED_WITH]->(jayZ)
# CREATE (beyonce)-[:WAS_BORN_IN]->(houston)
# CREATE (beyonce)-[:WAS_BORN_IN]->(newYork)
# CREATE (beyonce)-[:WAS_BORN_IN]->(washingtonDC)
# CREATE (beyonce)-[:WAS_BORN_IN]->(newOrleans)
# CREATE (beyonce)-[:WAS_BORN_IN]->(london)

# %% [markdown]
# MATCH (n)
# DETACH DELETE n
