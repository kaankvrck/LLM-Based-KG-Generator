# %%
from langchain_community.llms import Ollama
from langchain_core.output_parsers import JsonOutputParser
from langchain.output_parsers import YamlOutputParser

import pandas as pd 
import numpy as np

# %%
llm = Ollama(model="gemma:7b")

# %%
from langchain_core.prompts import ChatPromptTemplate
import re

def extract_cypher_scripts(text):
    cypher_list = list()
    for line in text.split("\n"):
        if 'CREATE' in line or 'MATCH' in line or 'CONNECT' in line:
            cypher_list.append(line)
            
    return cypher_list

# %% [markdown]
# ## Extract Term List from Plain Text

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a ontologist. You build knowledge graph from plain input. \nExtract Entites from plain text."),
    ("system", "The format should be python list"),    
    ("user", "{input}")
])
chain = prompt | llm
entity_context_list = list()

contexts = pd.read_csv('/Users/mertakcay/Projects/KnowledgeGraphBuilder/context.csv')
for context in contexts['context'].values:
    entity_list = list()
    entities = chain.invoke({"input": context})
    for sample in entities.split('\n'):
        if '-' in sample:
            entity_list.append(sample.replace('- ',''))
    entity_context_list.append(entity_list)
    print('----')
# Out:
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %%
entity_context_list
# Out:
# [['Beyoncé Giselle Knowles-Carter',
#   'Houston',
#   'Texas',
#   "Destiny's Child",
#   'Mathew Knowles',
#   'R&B',
#   'Grammy Awards'],
#  ['Beyoncé',
#   "Destiny's Child",
#   "B'Day (2006)",
#   'Déjà Vu',
#   'Irreplaceable',
#   'Beautiful Liar',
#   'Dreamgirls (2006)',
#   'The Pink Panther (2006)',
#   'Obsessed (2009)',
#   'Cadillac Records (2008)',
#   'I Am... Sasha Fierce (2008)',
#   'Single Ladies (Put a Ring on It)',
#   '4 (2011)',
#   'Beyoncé (2013)'],
#  ['Beyoncé',
#   'Love',
#   'Relationships',
#   'Monogamy',
#   'Female sexuality',
#   'Empowerment',
#   'Contemporary popular music',
#   "Destiny's Child",
#   'Music artists',
#   'Grammy Awards',
#   'Top Certified Artist',
#   'Top Radio Songs Artist',
#   'Top Female Artist',
#   'Artist of the Millennium',
#   'Time',
#   'Forbes'],
#  ['Beyoncé',
#   "St. Mary's Elementary School",
#   'Fredericksburg, Texas',
#   'Darlette Johnson',
#   'John Lennon',
#   'Parker Elementary School',
#   'High School for the Performing and Visual Arts',
#   'Alief Elsik High School',
#   "St. John's United Methodist Church"],
#  ['Beyoncé',
#   'Kelly Rowland',
#   'LaTavia Roberson',
#   "Girl's Tyme",
#   'R&B producer Arne Frager',
#   'Star Search',
#   'Northern California',
#   'Houston',
#   'Elektra Records',
#   'Atlanta Records',
#   'Dwayne Wiggins'],
#  ["Destiny's Child",
#   'Book of Isaiah',
#   'Men in Black',
#   'No, No, No',
#   "The Writing's on the Wall",
#   'Bills, Bills, Bills',
#   "Jumpin Jumpin'",
#   'Say My Name',
#   'Grammy Awards',
#   'Beyoncé',
#   'Boyz II Men',
#   'After All Is Said and Done'],
#  ['LeToya Luckett',
#   'Roberson',
#   'Farrah Franklin',
#   'Michelle Williams',
#   'Beyoncé',
#   'Mathew',
#   "Destiny's Child"],
#  ["Destiny's Child",
#   'Beyoncé',
#   'Luckett',
#   'Roberson',
#   "Charlie's Angels",
#   'U.S. Billboard Hot 100 chart',
#   '2000 film',
#   'Carmen: A Hip Hopera',
#   'Georges Bizet',
#   'Survivor',
#   '8 Days of Christmas'],
#  ['Beyoncé',
#   'Foxxy Cleopatra',
#   'Austin Powers in Goldmember',
#   'US box office',
#   '$73 million',
#   'Work It Out',
#   'UK',
#   'Norway',
#   'Belgium',
#   'The Fighting Temptations',
#   'Cuba Gooding, Jr.',
#   'Lilly',
#   'The Fighting Temptations soundtrack album',
#   'Fighting Temptation',
#   'Missy Elliott',
#   'MC Lyte',
#   'Free'],
#  ['Beyoncé',
#   'Jay Z',
#   '03 Bonnie & Clyde',
#   'U.S. Billboard Hot 100 chart',
#   'Dangerously in Love',
#   'Michelle Williams',
#   'Kelly Rowland'],
#  ['Beyoncé',
#   'Dangerously in Love Tour',
#   'Europe',
#   'North America',
#   'Super Bowl XXXVIII',
#   'Reliant Stadium',
#   'Houston',
#   'Texas',
#   'Destiny Fulfilled',
#   "Destiny's Child",
#   "Number 1's"],
#  ['Beyoncé',
#   "B'Day",
#   'US',
#   'Billboard 200',
#   'Billboard Hot 100',
#   'Déjà Vu',
#   'Jay Z',
#   'Australia',
#   'Hungary',
#   'Ireland',
#   'New Zealand'],
#  ['Beyoncé',
#   'The Pink Panther',
#   'Steve Martin',
#   'Dreamgirls',
#   'The Supremes',
#   'Diana Ross',
#   'Listen',
#   'The Beyoncé Experience',
#   "St. John's",
#   "America's Second Harvest"],
#  ['Beyoncé',
#   'Jay Z',
#   'I Am... Sasha Fierce',
#   'Manhattan',
#   'Sony Club',
#   'United States',
#   'Sasha Fierce',
#   'Billboard 200',
#   'Single Ladies (Put a Ring on It)',
#   'If I Were a Boy',
#   'Halo',
#   'Sweet Dreams',
#   'Diva',
#   'Ego',
#   'Broken-Hearted Girl',
#   'Video Phone'],
#  ['Beyoncé',
#   'Etta James',
#   'Cadillac Records',
#   'Phoenix House',
#   'At Last',
#   'Obsessed',
#   'Ali Larter',
#   'Idris Elba',
#   'Sharon Charles'],
#  ['Beyoncé',
#   'Lauryn Hill',
#   '52nd Annual Grammy Awards',
#   'I Am... Sasha Fierce',
#   'Halo',
#   'Single Ladies (Put a Ring on It)',
#   'Telephone',
#   'Lady Gaga',
#   'US Pop Songs',
#   'Mariah Carey'],
#  ['Beyoncé',
#   'Music career',
#   'January 2010',
#   'Mother',
#   'Great Wall of China',
#   'Egyptian pyramids',
#   'Australia',
#   'English music festivals',
#   'Museums',
#   'Ballet performances'],
#  ['Beyoncé',
#   'Muammar Gaddafi',
#   'WikiLeaks',
#   'Rolling Stone',
#   'The Huffington Post',
#   'Clinton Bush Haiti Fund',
#   'Glastonbury Festival'],
#  ['Beyoncé',
#   'Studio album 4',
#   'US',
#   'Billboard 200 chart',
#   'Run the World (Girls)',
#   'Best Thing I Never Had',
#   'Love on Top',
#   'Party',
#   'Countdown',
#   'I Care',
#   'End of Time',
#   'Eat, Play, Love'],
#  [],
#  ["Destiny's Child",
#   'Love Songs',
#   'Beyoncé',
#   'President Obama',
#   'Washington, D.C.',
#   'Super Bowl XLVII',
#   'Mercedes-Benz Superdome',
#   'New Orleans',
#   '55th Annual Grammy Awards',
#   'Life Is But a Dream',
#   'HBO',
#   'Blue Ivy',
#   'Warner/Chappell Music'],
#  ['Beyoncé',
#   'The Mrs. Carter Show World Tour',
#   'Belgrade',
#   'Serbia',
#   '132',
#   'March 2014',
#   'Amy Winehouse',
#   'The Great Gatsby soundtrack',
#   'André 3000',
#   '2013 Met Gala',
#   'Queen Tara',
#   'Epic',
#   '20th Century Fox'],
#  ['Beyoncé',
#   'Studio album',
#   'Billboard 200 chart',
#   'Electro-R&B album',
#   'The New York Times',
#   'Postnatal depression',
#   'The On Run Tour',
#   'MTV Video Music Awards',
#   'Forbes'],
#  ['Beyoncé',
#   '57th Annual Grammy Awards',
#   'Best R&B Performance',
#   'Best R&B Song',
#   'Best Surround Sound Album',
#   'Album of the Year',
#   'Beck',
#   'Morning Phase album',
#   'Vogue magazine',
#   'Made in America festival',
#   'Global Citizen Festival',
#   'Coldplay',
#   'A Head Full of Dreams (2015)',
#   'Super Bowl 50']]

# %% [markdown]
# ## Group Entities

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Group ALL entities according to semantic meaning of entity. \nThe output MUST be dictionary format."),
    ("user", "{entities}"),        
])
chain = prompt | llm

context_tags_list = list()
for entit_sample in entity_context_list:
    tags = chain.invoke({"entities": entit_sample})
    context_tags_list.append(tags)

# %% [markdown]
# ## Extract Properties of terms

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Extract properties of each entities from plain input. \nThe output MUST be YAML format."),
    ("system", "{entities}"),        
    ("user", "{input}")
])

chain = prompt | llm 

properties_list = list()
for context_entity, context in zip(entity_context_list, contexts['context'].values):
    properties = chain.invoke({"input": context,"entities": context_entity})
    properties_list.append(properties)

properties_list
# Out:
# ["```yaml\n**system:**\n- Beyoncé Giselle Knowles-Carter\n- Houston\n- Texas\n- Destiny's Child\n- Mathew Knowles\n- R&B\n- Grammy Awards\n\n**human:**\n- Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say)\n- Born September 4, 1981\n- American singer, songwriter, record producer and actress\n- Born and raised in Houston, Texas\n- Performed in various singing and dancing competitions as a child\n- Rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child\n- Managed by her father, Mathew Knowles\n- Group became one of the world's best-selling girl groups of all time\n- Hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003)\n- Established her as a solo artist worldwide\n- Earned five Grammy Awards\n- Featured the Billboard Hot 100 number-one singles 'Crazy in Love' and 'Baby Boy'",
#  "## Extracted Properties of Each Entity in YAML Format\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - Attributes:\n      - Name: Beyoncé\n      - Solo Albums:\n        - B'Day (2006)\n        - I Am... Sasha Fierce (2008)\n        - 4 (2011)\n        - Beyoncé (2013)\n      - Hits:\n        - Déjà Vu\n        - Irreplaceable\n        - Beautiful Liar\n      - Acting Roles:\n        - Dreamgirls (2006)\n        - The Pink Panther (2006)\n        - Obsessed (2009)\n      - Personal Achievements:\n        - Record-setting six Grammy Awards in 2010\n        - Song of the Year for 'Single Ladies (Put a Ring on It)'\n        - Mellower tone, exploring 1970s funk, 1980s pop, and 1990s soul\n  - **Destiny's Child:**\n    - Attributes:\n      - Name: Destiny's Child\n      - Disbandment: June 2005\n```",
#  "```yaml\nsystem:\n  - Beyoncé\n  - Love\n  - Relationships\n  - Monogamy\n  - Female sexuality\n  - Empowerment\n  - Contemporary popular music\n  - Destiny's Child\n  - Music artists\n  - Grammy Awards\n  - Top Certified Artist\n  - Top Radio Songs Artist\n  - Top Female Artist\n  - Artist of the Millennium\n  - Time\n  - Forbes\n\nhuman:\n  - Self-described 'modern-day feminist'\n  - Creates songs that are often characterized by themes of love, relationships, and monogamy\n  - Dynamic, highly choreographed performances\n  - Critics hailing her as one of the best entertainers in contemporary popular music\n  - Sold over 118 million records as a solo artist\n  - Won 20 Grammy Awards\n  - Top Certified Artist in America during the 2000s decade\n  - Top Radio Songs Artist of the Decade\n  - Top Female Artist of the 2000s\n  - Artist of the Millennium in 2011\n  - Listed among the 100 most influential people in the world in 2013 and 2014\n  - Listed as the most powerful female musician of 2015",
#  "## Extracted Properties of Each Entity in YAML Format:\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - **School:**\n      - St. Mary's Elementary School\n      - Parker Elementary School\n      - High School for the Performing and Visual Arts\n      - Alief Elsik High School\n    - **Location:**\n      - Fredericksburg, Texas\n    - **Other:**\n      - Singing talent discovered\n      - Church membership\n  - **St. Mary's Elementary School:**\n    - Location: Fredericksburg, Texas\n  - **Fredericksburg, Texas:**\n    - Location: Unknown\n  - **Darlette Johnson:**\n    - Role: Dance instructor\n  - **John Lennon:**\n    - Song: 'Imagine'\n  - **Parker Elementary School:**\n    - Location: Houston\n    - Choir membership\n  - **High School for the Performing and Visual Arts:**\n    - Location: Unknown\n  - **Alief Elsik High School:**\n    - Location: Unknown\n  - **St. John's United Methodist Church:**\n    - Location: Unknown\n    - Choir membership\n```",
#  "## Extracted Properties of Each Entity in YAML Format:\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - Age at the time: Unknown\n    - Relationship to other entities:\n      - Childhood friend of Kelly Rowland\n      - Member of Girl's Tyme\n      - Subject of song later said to be not good\n      - Daughter whose father resigned to manage the group\n  - **Kelly Rowland:**\n    - Age at the time: Unknown\n    - Relationship to other entities:\n      - Childhood friend of Beyoncé\n      - Member of Girl's Tyme\n  - **LaTavia Roberson:**\n    - Age at the time: Unknown\n    - Relationship to other entities:\n      - Member of Girl's Tyme\n  - **Girl's Tyme:**\n    - Group members: LaTavia Roberson, Beyoncé, Kelly Rowland, Unknown fourth member\n    - Activities: Rap and dance on the talent show circuit in Houston\n    - Outcome: Failure to win\n  - **R&B producer Arne Frager:**\n    - Relationship to Girl's Tyme: Brought them to his studio and placed them in Star Search\n  - **Star Search:**\n    - Description: Largest talent show on national TV at the time\n    - Connection to Girl's Tyme: Placements of Girl's Tyme\n  - **Northern California:**\n    - Connection to Girl's Tyme: Studio location\n  - **Houston:**\n    - Connection to Girl's Tyme: Location of talent show circuit appearances\n  - **Elektra Records:**\n    - Connection to Girl's Tyme: Signing of the group\n  - **Atlanta Records:**\n    - Connection to Girl's Tyme: Brief work on first recording\n  - **Dwayne Wiggins:**\n    - Company: Grass Roots Entertainment\n    - Connection to Girl's Tyme: Signing of the group\n```",
#  "## Extracted Properties of Each Entity in YAML format:\n\n```yaml\nentities:\n  - **Destiny's Child:**\n    - Name: Destiny's Child\n    - Year of Formation: Unknown\n    - Major Label Debut Song: 'Killing Time'\n    - Major Label Debut Album: Self-titled debut album\n    - Major Hit Song: 'No, No, No'\n    - Awards:\n      - Soul Train Lady of Soul Award for Best R&B/Soul Album of the Year\n      - Soul Train Lady of Soul Award for Best R&B/Soul or Rap New Artist\n      - Soul Train Lady of Soul Award for Best R&B/Soul Single for 'No, No, No'\n\n  - **Book of Isaiah:**\n    - Name: Book of Isaiah\n    - Passage quoted in text: Unknown\n    - Significance: Unknown\n\n  - **Men in Black:**\n    - Name: Men in Black\n    - Year of Release: 1997\n    - Soundtrack Song: 'Killing Time'\n\n  - **No, No, No:**\n    - Name: No, No, No\n    - Year of Release: Unknown\n    - Significance: First major hit song by Destiny's Child\n\n  - **The Writing's on the Wall:**\n    - Name: The Writing's on the Wall\n    - Year of Release: 1999\n    - Sales: Unknown\n    - Signature Songs:\n      - Bills, Bills, Bills\n      - Jumpin Jumpin'\n      - Say My Name\n\n  - **Grammy Awards:**\n    - Name: Grammy Awards\n    - Award Won by 'Say My Name':\n      - Best R&B Performance by a Duo or Group with Vocals\n      - Best R&B Song\n\n  - **Beyoncé:**\n    - Name: Beyoncé\n    - Collaboration: Duet with Marc Nelson on 'After All Is Said and Done'\n    - Significance: Unknown\n\n  - **Boyz II Men:**\n    - Name: Boyz II Men\n    - Original Member: Marc Nelson\n\n```",
#  "## YAML output:\n\n```yaml\nsystem:\n  - LeToya Luckett\n  - Roberson\n  - Farrah Franklin\n  - Michelle Williams\n  - Beyoncé\n  - Mathew\n  - Destiny's Child\n\nhuman:\n  - LeToya Luckett and Roberson became unhappy with Mathew's managing of the band and were eventually replaced by Farrah Franklin and Michelle Williams.\n  - Beyoncé experienced depression following the split with Luckett and Roberson after being publicly blamed by the media, critics, and blogs for its cause.\n  - Her long-standing boyfriend left her at this time.\n  - The depression was so severe it lasted for a couple of years, during which she occasionally kept herself in her bedroom for days and refused to eat anything.\n  - Beyoncé stated that she struggled to speak about her depression because Destiny's Child had just won their first Grammy Award and she feared no one would take her seriously.\n  - Beyoncé would later speak of her mother as the person who helped her fight it.\n  - Franklin was dismissed, leaving just Beyoncé, Rowland, and Williams.\n```",
#  "## YAML Output:\n\n```yaml\nsystem:\n  - Destiny's Child\n  - Beyoncé\n  - Luckett\n  - Roberson\n  - Charlie's Angels\n  - U.S. Billboard Hot 100 chart\n  - 2000 film\n  - Carmen: A Hip Hopera\n  - Georges Bizet\n  - Survivor\n  - 8 Days of Christmas\n\nhuman:\n  - The remaining band members recorded 'Independent Women Part I'\n  - It became their best-charting single, topping the U.S. Billboard Hot 100 chart for eleven consecutive weeks\n  - In early 2001, while Destiny's Child was completing their third album, Beyoncé landed a major role in the MTV made-for-television film, Carmen: A Hip Hopera\n  - Set in Philadelphia, the film is a modern interpretation of the 19th century opera Carmen by French composer Georges Bizet\n  - When the third album Survivor was released in May 2001, Luckett and Roberson filed a lawsuit claiming that the songs were aimed at them\n  - The album debuted at number one on the U.S. Billboard 200, with first-week sales of 663,000 copies sold\n  - The album spawned other number-one hits, 'Bootylicious' and the title track, 'Survivor'\n  - The latter of which earned the group a Grammy Award for Best R&B Performance by a Duo or Group with Vocals\n  - After releasing their holiday album 8 Days of Christmas in October 2001, the group announced a hiatus to further pursue solo careers\n```",
#  '**YAML Output:**\n\n```yaml\nentities:\n  - Beyoncé\n  - Foxxy Cleopatra\n  - Austin Powers in Goldmember\n  - US box office\n  - UK\n  - Norway\n  - Belgium\n  - The Fighting Temptations\n  - Cuba Gooding, Jr.\n  - Lilly\n  - The Fighting Temptations soundtrack album\n  - Fighting Temptation\n  - Missy Elliott\n  - MC Lyte\n  - Free\n\nproperties:\n  - US box office: $73 million\n  - UK: Top ten\n  - Norway: Top ten\n  - Belgium: Top ten\n  - Fighting Temptation soundtrack album: Top ten\n  - Fighting Temptation: $30 million\n```',
#  "```yaml\n**System:**\n- Beyoncé\n- Jay Z\n- 03 Bonnie & Clyde\n- U.S. Billboard Hot 100 chart\n- Dangerously in Love\n- Michelle Williams\n- Kelly Rowland\n\n**Human:**\n- Beyoncé's first solo recording was a feature on Jay Z's '03 Bonnie & Clyde' that was released in October 2002, peaking at number four on the U.S. Billboard Hot 100 chart.\n- Her first solo album Dangerously in Love was released on June 24, 2003, after Michelle Williams and Kelly Rowland had released their solo efforts.\n- The album sold 317,000 copies in its first week, debuted atop the Billboard 200, and has since sold 11 million copies worldwide.\n- The album's lead single, 'Crazy in Love', featuring Jay Z, became Beyoncé's first number-one single as a solo artist in the US.\n- The single 'Baby Boy' also reached number one, and singles, 'Me, Myself and I' and 'Naughty Girl', both reached the top-five.\n- The album earned Beyoncé a then record-tying five awards at the 46th Annual Grammy Awards.",
#  "## YAML Output\n\n```yaml\n**System:**\n- Name: Beyoncé\n- Tour: Dangerously in Love Tour\n- Location: Europe\n- Location2: North America\n- Event: Super Bowl XXXVIII\n- Venue: Reliant Stadium\n- City: Houston\n- State: Texas\n\n**Human:**\n- Name: Beyoncé\n- Tour: Dangerously in Love Tour\n- Location: Europe\n- Tour2: Verizon Ladies First Tour\n- Date: November 2003\n- Event2: Super Bowl XXXVIII\n- Date2: February 1, 2004\n- Location3: Reliant Stadium\n- City2: Houston\n- State2: Texas\n- Album: Destiny Fulfilled\n- Single: 'Lose My Breath'\n- Single2: 'Soldier'\n- Tour3: Destiny Fulfilled... and Lovin' It\n- Date3: June 11, 2005\n- Disbandment: Following the North American leg of the tour\n- Album2: Number 1's\n```",
#  "```yaml\n**Entities:**\n- **Beyoncé:**\n  - Properties:\n    - Name: Beyoncé\n    - Nationality: US\n    - Album: B'Day\n    - Number-one albums: 2\n    - Single: Déjà Vu\n    - Single sales: 541,000\n- **B'Day:**\n  - Properties:\n    - Name: B'Day\n    - Release date: September 5, 2006\n    - Sales: 541,000\n    - Singles:\n      - Déjà Vu\n      - Irreplaceable\n      - Ring the Alarm\n      - Get Me Bodied\n      - Green Light\n- **US:**\n  - Properties:\n    - Nationality: US\n    - Location: US\n- **Billboard 200:**\n  - Properties:\n    - Name: Billboard 200\n    - Top-selling album: B'Day\n- **Billboard Hot 100:**\n  - Properties:\n    - Name: Billboard Hot 100\n    - Single: Déjà Vu\n    - Top-five single: Déjà Vu\n- **Déjà Vu:**\n  - Properties:\n    - Name: Déjà Vu\n    - Single sales: Unknown\n    - Chart position: Top five\n- **Jay Z:**\n  - Properties:\n    - Name: Jay Z\n    - Collaboration: Déjà Vu\n- **Australia:**\n  - Properties:\n    - Country: Australia\n    - Single top-number-one: Irreplaceable\n- **Hungary:**\n  - Properties:\n    - Country: Hungary\n    - Single top-number-one: Irreplaceable\n- **Ireland:**\n  - Properties:\n    - Country: Ireland\n    - Single top-number-one: Irreplaceable\n- **New Zealand:**\n  - Properties:\n    - Country: New Zealand\n    - Single top-number-one: Irreplaceable",
#  "Sure, here is the extracted YAML data:\n\n```yaml\nsystem:\n  - Beyoncé\n  - The Pink Panther\n  - Steve Martin\n  - Dreamgirls\n  - The Supremes\n  - Diana Ross\n  - Listen\n  - The Beyoncé Experience\n  - St. John's\n  - America's Second Harvest\n\nhuman:\n  - First acting role of 2006 in The Pink Panther starring opposite Steve Martin and grossing $158.8 million worldwide\n  - Second film Dreamgirls, the film version of the 1981 Broadway musical loosely based on The Supremes, received acclaim from critics and grossed $154 million internationally\n  - Starred opposite Jennifer Hudson, Jamie Foxx, and Eddie Murphy playing a pop singer based on Diana Ross\n  - Released 'Listen' as the lead single from the soundtrack album\n  - Embarked on The Beyoncé Experience, her first worldwide concert tour, visiting 97 venues and grossed over $24 million\n  - Conducted pre-concert food donation drives during six major stops in conjunction with her pastor at St. John's and America's Second Harvest\n  - Re-released B'Day with five additional songs, including her duet with Shakira 'Beautiful Liar'\n```",
#  "## Extracted Properties of Entities in the Text:\n\n**Humans:**\n\n* **Beyoncé:**\n    * Properties:\n        * Name\n        * Marriage to Jay Z\n        * Publicly revealed marriage in video montage for I Am... Sasha Fierce\n        * Release of I Am... Sasha Fierce\n        * Introduction of alter ego Sasha Fierce\n        * Sales of I Am... Sasha Fierce\n        * Number-one songs on Billboard 200\n        * Longest-running Hot 100 single in career\n        * Top-ten singles on Billboard 200\n        * Music video for 'Single Ladies'\n        * World Tour\n\n* **Jay Z:**\n    * Properties:\n        * Name\n        * Marriage to Beyoncé\n\n**Places:**\n\n* **Manhattan:**\n    * Properties:\n        * Location\n        * Sony Club\n\n* **United States:**\n    * Properties:\n        * Location\n        * Release of I Am... Sasha Fierce\n\n**Other Entities:**\n\n* **I Am... Sasha Fierce:**\n    * Properties:\n        * Name\n        * Release date\n        * Sales\n        * Billboard 200 debut\n        * Number-one song\n        * Top-five songs\n\n* **Billboard 200:**\n    * Properties:\n        * Name\n        * Top-ten songs by Beyoncé\n\n* **Single Ladies (Put a Ring on It):**\n    * Properties:\n        * Name\n        * Number-one song\n\n* **Halo:**\n    * Properties:\n        * Name\n        * Number-one song\n\n* **Sweet Dreams:**\n    * Properties:\n        * Name\n        * Top-five song\n\n* **Diva:**\n    * Properties:\n        * Name\n        * Song\n\n* **Ego:**\n    * Properties:\n        * Name\n        * Song\n\n* **Broken-Hearted Girl:**\n    * Properties:\n        * Name\n        * Song\n\n* **Video Phone:**\n    * Properties:\n        * Name\n        * Song",
#  "**YAML Output:**\n\n```yaml\nentities:\n  - Beyoncé:\n    - Further expanded her acting career\n    - Starred as blues singer Etta James in the 2008 musical biopic, Cadillac Records\n    - Donated her entire salary from the film to Phoenix House\n    - Performed James' 'At Last' at the First Couple's first inaugural ball\n    - Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed\n    - Played Sharon Charles, a mother and wife who learns of a woman's obsessive behavior over her husband\n  - Etta James:\n    - Blues singer\n    - Starred in the 2008 musical biopic, Cadillac Records\n  - Cadillac Records:\n    - Musical biopic\n    - Received praise from critics\n  - Phoenix House:\n    - Organization of rehabilitation centers for heroin addicts\n  - Obsessed:\n    - Thriller\n    - Received negative reviews from critics\n    - Did well at the US box office\n  - Ali Larter:\n    - Stared opposite Beyoncé in Obsessed\n    - Won the 2010 MTV Movie Award for Best Fight\n  - Idris Elba:\n    - Stared opposite Beyoncé in Obsessed\n  - Sharon Charles:\n    - Mother and wife who learns of a woman's obsessive behavior over her husband\n```",
#  "## Extracted Properties of Entities in Plain Text:\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - Properties:\n      - Name: Beyoncé\n      - Awards:\n        - 10 nominations at the 52nd Annual Grammy Awards\n        - Album of the Year for I Am... Sasha Fierce\n        - Record of the Year for 'Halo'\n        - Song of the Year for 'Single Ladies (Put a Ring on It)'\n      - Other achievements:\n        - Tied with Lauryn Hill for most Grammy nominations in a single year by a female artist\n        - Featured on Lady Gaga's single 'Telephone'\n        - Song 'Telephone' topped the US Pop Songs chart\n  - **Lauryn Hill:**\n    - Properties:\n      - Name: Lauryn Hill\n      - Grammy nominations:\n        - Tied with Beyoncé for most nominations in a single year by a female artist\n  - **52nd Annual Grammy Awards:**\n    - Properties:\n      - Name: 52nd Annual Grammy Awards\n      - Location: Unknown\n      - Date: Unknown\n  - **I Am... Sasha Fierce:**\n    - Properties:\n      - Name: I Am... Sasha Fierce\n      - Award category: Album of the Year\n  - **Halo:**\n    - Properties:\n      - Name: Halo\n      - Award category: Record of the Year\n  - **Single Ladies (Put a Ring on It):**\n    - Properties:\n      - Name: Single Ladies (Put a Ring on It)\n      - Award category: Song of the Year\n  - **Lady Gaga:**\n    - Properties:\n      - Name: Lady Gaga\n      - Collaboration:\n        - Featured on Beyoncé's single 'Telephone'\n      - Awards:\n        - Grammy nomination for Best Pop Collaboration with Vocals for 'Telephone'\n  - **Mariah Carey:**\n    - Properties:\n      - Name: Mariah Carey\n      - Number-ones:\n        - Tied with Beyoncé and Gaga for most number-ones since the Nielsen Top 40 airplay chart launched in 1992\n```",
#  '```yaml\n**entities:**\n\n- **Beyoncé:**\n  - **Music career:** Announced hiatus in January 2010.\n  - **Mother:** Advised to live life and be inspired.\n  - **Other:** Musical break lasted nine months, visit of multiple European cities, including the Great Wall of China, the Egyptian pyramids, Australia, and English music festivals, and participation in museums and ballet performances.\n\n- **Great Wall of China:**\n  - **Location:** Unknown.\n\n- **Egyptian pyramids:**\n  - **Location:** Unknown.\n\n- **Australia:**\n  - **Location:** Unknown.\n\n- **English music festivals:**\n  - **Location:** Unknown.\n\n- **Museums:**\n  - **Purpose:** Unknown.\n\n- **Ballet performances:**\n  - **Purpose:** Unknown.',
#  '## Extracted Properties of Each Entity in YAML format:\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - nationality: Unknown\n    - occupation: Singer\n    - achievements:\n      - First solo female artist to headline the main Pyramid stage at the 2011 Glastonbury Festival\n      - Highest-paid performer in the world per minute\n    - other_information:\n      - Donations to the Clinton Bush Haiti Fund\n  - **Muammar Gaddafi:**\n    - nationality: Libyan\n    - occupation: Ruler\n    - family: Unknown\n  - **WikiLeaks:**\n    - nature: Document leak organization\n    - significance: Revealed information about Beyoncé\'s performance for Gaddafi\'s family\n  - **Rolling Stone:**\n    - occupation: Music magazine\n    - significance: Reported the music industry urging artists to return money earned for Gaddafi\'s family\n  - **The Huffington Post:**\n    - occupation: News website\n    - significance: Confirmed Beyoncé\'s donation to the Clinton Bush Haiti Fund\n  - **Clinton Bush Haiti Fund:**\n    - purpose: Unknown\n    - beneficiaries: Unknown\n    - significance: Received donations from Beyoncé\n  - **Glastonbury Festival:**\n    - location: Unknown\n    - significance: Beyoncé\'s performance there in 2011\n```\n\n**Please note:**\n\n* This YAML output includes extracted properties of each entity from the text, including their nationality, occupation, achievements, and other relevant information.\n* Some properties, such as "nationality" and "occupation," may not be accurate or complete, as the text does not provide enough information to fill them in precisely.\n* The "other_information" section includes additional details about each entity that are not directly related to their properties.\n* The "achievements" and "other_information" sections are not exhaustive and can be expanded upon based on the available text or additional information.',
#  '```yaml\n**Entities:**\n- **Beyoncé:**\n  - Properties:\n    - Name: Beyoncé\n    - Nationality: US\n    - Number-one albums in US: 4\n    - Writing award: Won for the cover story "Eat, Play, Love" written for Essence.\n\n- **Studio album 4:**\n  - Properties:\n    - Name: 4\n    - Release date: June 28, 2011\n    - Sales: 310,000 copies in first week\n    - Chart debut: Top of Billboard 200 chart\n    - Singles:\n      - Run the World (Girls)\n      - Best Thing I Never Had\n      - Love on Top\n      - Party\n      - Countdown\n      - I Care\n      - End of Time\n\n- **Billboard 200 chart:**\n  - Properties:\n    - Name: Billboard 200 chart\n    - Significance: Given Beyoncé her fourth consecutive number-one album in the US.',
#  '## Extracted Properties of Entities in the Text:\n\n```yaml\nsystem:\n  - None\n\nhuman:\n  - Name: Beyoncé\n    - Date of Birth: January 7, 2012\n    - Child\'s Name: Blue Ivy Carter\n    - Child\'s Gender: Daughter\n    - Place of Birth: Lenox Hill Hospital, New York\n    - Performance Date: Unknown\n    - Performance Location: Revel Atlantic City\'s Ovation Hall\n    - Performance Reason: Celebrating the resort\'s opening\n    - Post-Birth Performances: 4 nights\n```\n\n**Notes:**\n\n* The text does not specify the performance date or reason for the performance, therefore the fields for those properties are left as "Unknown" and "None" respectively.\n* The text mentions "her first performances since giving birth to Blue Ivy" but does not specify the number of performances, therefore the field "Post-Birth Performances" is filled with "4 nights".',
#  "**YAML Output:**\n\n```yaml\n- **Name:** Destiny's Child\n  - **Type:** Group\n- **Name:** Love Songs\n  - **Type:** Album\n- **Name:** Beyoncé\n  - **Type:** Artist\n- **Name:** President Obama\n  - **Type:** Politician\n- **Name:** Washington, D.C.\n  - **Type:** City\n- **Name:** Super Bowl XLVII\n  - **Type:** Event\n- **Name:** Mercedes-Benz Superdome\n  - **Type:** Stadium\n- **Name:** New Orleans\n  - **Type:** City\n- **Name:** 55th Annual Grammy Awards\n  - **Type:** Event\n- **Name:** Life Is But a Dream\n  - **Type:** Documentary\n- **Name:** HBO\n  - **Type:** Network\n- **Name:** Blue Ivy\n  - **Type:** Child\n- **Name:** Warner/Chappell Music\n  - **Type:** Music Company\n```",
#  "## Extracted Properties in YAML format:\n\n```yaml\nsystem:\n  - name: Beyoncé\n  - tour: The Mrs. Carter Show World Tour\n  - location: Belgrade, Serbia\n  - dates: 132\n  - date: March 2014\n\n  - soundtrack: The Great Gatsby soundtrack\n  - artist: Amy Winehouse\n  - song: 'Back to Black'\n  - artist_collaboration: André 3000\n\n  - event: 2013 Met Gala\n  - honorary_chair: True\n\n  - movie: Epic\n  - voice_role: Queen Tara\n  - studio: 20th Century Fox\n  - song: 'Rise Up'\n```\n\nThis YAML output includes extracted properties for each entity in the text, including:\n\n* **System:**\n    * Name\n    * Tour\n    * Location\n    * Dates\n    * Date\n    * Soundtrack\n    * Artist\n    * Song\n    * Artist Collaboration\n    * Event\n    * Honorary Chair\n    * Movie\n    * Voice Role\n    * Studio\n    * Song",
#  "## Extracted Properties of Entities in the Text:\n\n```yaml\n- **Beyoncé:**\n  - Occupation: Singer\n  - Gender: Female\n  - Awards:\n    - Video Vanguard Award\n    - Best Video with a Social Message\n    - Best Cinematography for 'Pretty Hurts'\n    - Best Collaboration for 'Drunk in Love'\n  - Albums:\n    - Eponymous fifth studio album\n    - Electro-R&B album\n    - Number-one albums in US: 5\n    - First woman to have first five studio albums debut at number one\n\n- **Studio album:**\n  - Name: Eponymous fifth studio album\n  - Genre: Electro-R&B\n  - Themes: Darker themes previously unexplored in her work\n  - Sales: One million digital copies worldwide in six days\n\n- **Billboard 200 chart:**\n  - Debut: Top of the chart\n  - Number-one albums in US: 5\n\n- **The New York Times:**\n  - Recognition: Noted the album's unconventional release as significant\n\n- **Postnatal depression:**\n  - Theme explored in the album\n\n- **The On Run Tour:**\n  - Name: On the Run Tour\n  - Co-headlining stadium tour with Jay Z\n\n- **MTV Video Music Awards:**\n  - Award received: Video Vanguard Award\n\n- **Forbes:**\n  - Top-earning woman in music in 2013 and 2014\n  - Earnings in 2013: $115 million",
#  "```yaml\n**entities:**\n\n- **Beyoncé:**\n  - Awards won:\n    - Best R&B Performance\n    - Best R&B Song\n    - Best Surround Sound Album\n  - Other accomplishments:\n    - First African-American artist to cover the September issue of Vogue magazine\n    - Headlined the 2015 Made in America festival\n    - Headlined the Global Citizen Festival\n    - Made an uncredited featured appearance on the track 'Hymn for the Weekend' by Coldplay\n\n- **57th Annual Grammy Awards:**\n  - Date: February 2015\n\n- **Best R&B Performance:**\n\n- **Best R&B Song:**\n\n- **Best Surround Sound Album:**\n\n- **Album of the Year:**\n\n- **Beck:**\n  - Won Album of the Year for his Morning Phase album\n\n- **Vogue magazine:**\n\n- **Made in America festival:**\n\n- **Global Citizen Festival:**\n\n- **Coldplay:**\n  - Seventh studio album: A Head Full of Dreams (2015)\n\n- **Super Bowl 50:**"]

# %%
properties_list[0]
# Out:
# "```yaml\n**system:**\n- Beyoncé Giselle Knowles-Carter\n- Houston\n- Texas\n- Destiny's Child\n- Mathew Knowles\n- R&B\n- Grammy Awards\n\n**human:**\n- Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say)\n- Born September 4, 1981\n- American singer, songwriter, record producer and actress\n- Born and raised in Houston, Texas\n- Performed in various singing and dancing competitions as a child\n- Rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child\n- Managed by her father, Mathew Knowles\n- Group became one of the world's best-selling girl groups of all time\n- Hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003)\n- Established her as a solo artist worldwide\n- Earned five Grammy Awards\n- Featured the Billboard Hot 100 number-one singles 'Crazy in Love' and 'Baby Boy'"

# %% [markdown]
# ## Extract relationships between terms

# %%
from langchain.output_parsers import ResponseSchema, StructuredOutputParser
from langchain.prompts import PromptTemplate

response_schemas = [
    ResponseSchema(name="first entity", description="first entity of relationship between entities"),
    ResponseSchema(name="relationship", description="relationship between two entity semantically"),
    ResponseSchema(name="second entity", description="second entity of relationship between entities"),
]
relationship_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# %%
relationship_instructions = relationship_parser.get_format_instructions()
prompt = PromptTemplate(
    template="Create relationship between entities from plain text.\n{relationship_instructions}\n{entities}\n{proporties}\n{group}\n{input}",
    input_variables=["entities","proporties","term_list","input"],
    partial_variables={"relationship_instructions": relationship_instructions},
)
chain = prompt | llm  
relationships_list = list()
for context_idx in range(len(contexts)):
    relationships = chain.invoke({"input": contexts['context'].iloc[context_idx],"entities": entity_context_list[context_idx], 'proporties':properties_list[context_idx], 'group':context_tags_list[context_idx]})
    print(relationships)
    relationships_list.append(relationships)
# Out:
# ```json
# {
# 	"first entity": "Beyoncé Giselle Knowles-Carter",
# 	"relationship": "Born and raised in",
# 	"second entity": "Houston, Texas"
# }
#
# {
# 	"first entity": "Destiny's Child",
# 	"relationship": "Girl-group of which Beyoncé was lead singer",
# 	"second entity": "R&B"
# }
#
# {
# 	"first entity": "Mathew Knowles",
# 	"relationship": "Manager of",
# 	"second entity": "Destiny's Child"
# }
#
# {
# 	"first entity": "Grammy Awards",
# 	"relationship": "Won by Beyoncé",
# 	"second entity": "Beyoncé Giselle Knowles-Carter"
# }
# ```
#
# This code snippet represents the relationship between entities in the text, formatted according to the requested schema. It includes the leading and trailing "```json" and "```" as requested, and utilizes the provided text to identify the entities and their relationships.
# ```json
# {
# 	"Beyoncé": {
# 		"relationship": "Solo Artist",
# 		"second entity": null
# 	},
# 	"Destiny's Child": {
# 		"relationship": "Band",
# 		"second entity": null
# 	}
# }
# ```
#
# **Explanation:**
#
# * The relationship between Beyoncé and Destiny's Child is "Solo Artist" and "Band", respectively.
# * There is no second entity for both Beyoncé and Destiny's Child in this text.
# ```json
# {
# 	"Beyoncé": "Artist of the Millennium",
# 	"Relationships": "Monogamy",
# 	"Love": "Theme of songs"
# }
# ```
#
# **Explanation:**
#
# * **Entities:**
#     * Beyoncé: Artist of the Millennium, Top Female Artist, Top Certified Artist, Music artists
#     * Relationships: Monogamy
#     * Love: Theme of songs
#
# * **Relationships:**
#     * Beyoncé's songs are often characterized by themes of love and relationships.
#     * Beyoncé's dynamic, highly choreographed performances have led to critics hailing her as one of the best entertainers in contemporary popular music.
#     * Beyoncé has sold over 118 million records as a solo artist and 60 million with Destiny's Child.
# ```json
# {
# 	"Beyoncé": {
# 		"School": ["St. Mary's Elementary School", "Parker Elementary School", "High School for the Performing and Visual Arts", "Alief Elsik High School"],
# 		"Location": ["Fredericksburg, Texas"],
# 		"Other": ["Singing talent discovered", "Church membership"]
# 	},
# 	"St. Mary's Elementary School": {
# 		"Location": ["Fredericksburg, Texas"]
# 	},
# 	"Fredericksburg, Texas": {
# 		"Location": ["Unknown"]
# 	},
# 	"Darlette Johnson": {
# 		"Role": ["Dance instructor"]
# 	},
# 	"John Lennon": {
# 		"Song": ["Imagine"]
# 	},
# 	"Parker Elementary School": {
# 		"Location": ["Houston"],
# 		"Choir membership": null
# 	},
# 	"High School for the Performing and Visual Arts": {
# 		"Location": ["Unknown"]
# 	},
# 	"Alief Elsik High School": {
# 		"Location": ["Unknown"]
# 	},
# 	"St. John's United Methodist Church": {
# 		"Location": ["Unknown"],
# 		"Choir membership": null
# 	}
# }
# ```
#
# **Explanation:**
#
# The text describes relationships between various entities, including individuals (Beyoncé, Darlette Johnson, John Lennon) and institutions (St. Mary's Elementary School, Fredericksburg, Texas, Parker Elementary School, High School for the Performing and Visual Arts). The text also mentions other entities such as St. John's United Methodist Church and Alief Elsik High School.
#
# The extracted information is grouped into a dictionary called `entities_grouped_by_semantic_meaning` with three keys: "Persons," "Schools," and "Places." Each key corresponds to a distinct group of entities based on their semantic relationships.
#
# The "Persons" group includes Beyoncé, Darlette Johnson, and John Lennon. The "Schools" group includes Parker Elementary School, High School for the Performing and Visual Arts, and Alief Elsik High School. The "Places" group includes Fredericksburg, Texas, St. Mary's Elementary School, and St. John's United Methodist Church.
# ```json
# {
# 	"Beyoncé": {
# 		"relationship": "Member of Girl's Tyme",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Kelly Rowland": {
# 		"relationship": "Member of Girl's Tyme",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"LaTavia Roberson": {
# 		"relationship": "Member of Girl's Tyme",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Girl's Tyme": {
# 		"relationship": "Group members",
# 		"second entity": "R&B producer Arne Frager"
# 	},
# 	"R&B producer Arne Frager": {
# 		"relationship": "Brought Girls Tyme to his studio and placed them in Star Search",
# 		"second entity": "Star Search"
# 	},
# 	"Star Search": {
# 		"relationship": "Largest talent show on national TV at the time",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Northern California": {
# 		"relationship": "Studio location",
# 		"second entity": "Star Search"
# 	},
# 	"Houston": {
# 		"relationship": "Location of talent show circuit appearances",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Elektra Records": {
# 		"relationship": "Signing of the group",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Atlanta Records": {
# 		"relationship": "Brief work on first recording",
# 		"second entity": "Girl's Tyme"
# 	},
# 	"Dwayne Wiggins": {
# 		"relationship": "Signing of the group",
# 		"second entity": "Girl's Tyme"
# 	}
# }
# ```
#
# This code snippet successfully extracted the relationships between entities in the text, grouped them by their semantic meaning, and formatted them in the requested schema.
# ```json
# {
#   "Artists": {
#     "Destiny's Child": "Destiny's Child was formed in Unknown and released their debut song 'Killing Time' in Unknown. They have won three Soul Train Lady of Soul Awards and have sold more than eight million copies worldwide.",
#     "Beyoncé": "Beyoncé collaborated with Marc Nelson on 'After All Is Said and Done' and has won multiple Grammy Awards.",
#     "Boyz II Men": "Boyz II Men was formed in Unknown and has sold more than eight million copies worldwide."
#   },
#   "Movies": {
#     "Men in Black": "Men in Black was released in 1997 and has a soundtrack song titled 'Killing Time' by Destiny's Child.",
#     "No, No, No": "No, No, No is a song by Destiny's Child and was their major label debut song.",
#     "The Writing's on the Wall": "The Writing's on the Wall was released in 1999 and has sold more than eight million copies worldwide."
#   },
#   "Awards": {
#     "Grammy Awards": "Grammy Awards have been won by 'Say My Name' and 'After All Is Said and Done'."
#   },
#   "Other": {
#     "Bills, Bills, Bills": "Bills, Bills, Bills is a song by The Writing's on the Wall.",
#     "Jumpin Jumpin'": "Jumpin Jumpin' is a song by The Writing's on the Wall.",
#     "Say My Name": "Say My Name is a song by Destiny's Child and was their most successful song at the time."
#   }
# }
# ```
# ```json
# {
#   "celebrities": ["LeToya Luckett", "Farrah Franklin", "Beyoncé", "Michelle Williams"],
#   "groups": ["Destiny's Child"]
# }
# ```
#
# **Explanation:**
#
# * The entities in the text are grouped by their semantic meaning.
# * The relationship between each entity and the other entities is also included in the dictionary.
# * The "celebrities" group includes all the celebrities mentioned in the text.
# * The "groups" group includes the group Destiny's Child.
# ```json
# {
# 	"Artists": ["Destiny's Child", 'Beyoncé', 'Luckett', 'Roberson', "Charlie's Angels"],
# 	"Charting success": ["U.S. Billboard Hot 100 chart", '2000 film', 'Carmen: A Hip Hopera'],
# 	"Musicians": ["Georges Bizet", 'Survivor'],
# 	"Christmas songs": ["8 Days of Christmas"]
# }
# ```
#
# The text describes various relationships between entities. The entities are grouped into the following categories based on their semantic meaning:
#
# * **Artists:** Destiny's Child, Beyoncé, Luckett, Roberson, Charlie's Angels
# * **Charting success:** U.S. Billboard Hot 100 chart, 2000 film, Carmen: A Hip Hopera
# * **Musicians:** Georges Bizet, Survivor
# * **Christmas songs:** 8 Days of Christmas
# ```json
# {
# 	"Beyoncé": "Actress",
# 	"Relationship": "Played",
# 	"Austin Powers in Goldmember": "Comedy film"
# }
#
# {
# 	"US box office": "$73 million",
# 	"Relationship": "Spent its first weekend atop"
# }
#
# {
# 	"UK": "Top ten",
# 	"Relationship": "Entered the top ten"
# }
#
# {
# 	"Norway": "Top ten",
# 	"Relationship": "Entered the top ten"
# }
#
# {
# 	"Belgium": "Top ten",
# 	"Relationship": "Entered the top ten"
# }
#
# {
# 	"Fighting Temptation soundtrack album": "Top ten",
# 	"Relationship": "Entered the top ten"
# }
#
# {
# 	"Fighting Temptation": "$30 million",
# 	"Relationship": "Grossed"
# }
#
# {
# 	"Missy Elliott": "Soundtrack album contribution",
# 	"Relationship": "With"
# }
#
# {
# 	"MC Lyte": "Soundtrack album contribution",
# 	"Relationship": "With"
# }
#
# {
# 	"Free": "Soundtrack album contribution",
# 	"Relationship": "With"
# }
# ```
#
# **YAML Output:**
#
# ```yaml
# entities:
#   - Beyoncé
#   - Austin Powers in Goldmember
#   - US box office
#   - UK
#   - Norway
#   - Belgium
#   - Fighting Temptation soundtrack album
#   - Fighting Temptation
#   - Missy Elliott
#   - MC Lyte
#   - Free
#
# properties:
#   - US box office: $73 million
#   - UK: Top ten
#   - Norway: Top ten
#   - Belgium: Top ten
#   - Fighting Temptation soundtrack album: Top ten
#   - Fighting Temptation: $30 million
# ```
# ```json
# {
# 	"celebrities": ["Beyoncé", "Jay Z", "03 Bonnie & Clyde", "Michelle Williams", "Kelly Rowland"],
# 	"music_tracks": ["Dangerously in Love", "U.S. Billboard Hot 100 chart"]
# }
# ```
#
# **Explanation:**
#
# * The text describes relationships between entities like celebrities and music tracks.
# * The code snippet groups entities by their semantic meaning, namely "celebrities" and "music_tracks".
# * Each group has a list of corresponding entities.
# * The relationships between entities are implicit in the text, but the code snippet makes them explicit.
# ```json
# {
# 	"Beyoncé": "String",
# 	"Relationship": "Performs at Super Bowl XXXVIII",
# 	"Reliant Stadium": "Location of Super Bowl XXXVIII"
# }
#
# {
# 	"Beyoncé": "String",
# 	"Relationship": "Touring with Destiny's Child",
# 	"Destiny Fulfilled": "Album released by Destiny's Child"
# }
#
# {
# 	"Beyoncé": "String",
# 	"Relationship": "Disbandment of Destiny's Child",
# 	"Barcelona": "Location of last stop of Destiny's Child European tour"
# }
# ```
#
# This code snippet represents the extracted relationships between entities in the text, formatted according to the provided schema.
# ```json
# {
#   "celebrities": ["Beyoncé", "Jay Z", "Déjà Vu"],
#   "places": ["US", "Australia", "Hungary", "Ireland", "New Zealand"],
#   "charts": ["Billboard 200", "Billboard Hot 100"]
# }
# ```
#
# **Relationships:**
#
# - **Beyoncé** is the artist of the album **B'Day**, which was released in the **US**.
# - **B'Day** was released atop the **Billboard 200**, which is a chart in the **US**.
# - The single **Déjà Vu**, featuring **Jay Z**, reached the top five on the **Billboard Hot 100** chart.
# - **Déjà Vu** was a commercial success worldwide, reaching number one in **Australia**, **Hungary**, **Ireland**, and **New Zealand**.
# ```json
# {
# 	"Singers": ["Beyoncé", "The Pink Panther", "Steve Martin", "Dreamgirls", "The Supremes", "Diana Ross"],
# 	"Songs": ["Listen", "The Beyoncé Experience"],
# 	"Places": ["St. John's", "America's Second Harvest"]
# }
# ```
# ```json
# {
# 	"Beyoncé": {
# 		"relationship": "Married to Jay Z",
# 		"second entity": "Jay Z"
# 	},
# 	"Jay Z": {
# 		"relationship": "Married to Beyoncé",
# 		"second entity": "Beyoncé"
# 	},
# 	"I Am... Sasha Fierce": {
# 		"relationship": "Album released by Beyoncé",
# 		"second entity": "Beyoncé"
# 	},
# 	"Manhattan": {
# 		"relationship": "Location of Sony Club",
# 		"second entity": "Sony Club"
# 	},
# 	"United States": {
# 		"relationship": "Location of I Am... Sasha Fierce release",
# 		"second entity": "I Am... Sasha Fierce"
# 	}
# }
# ```
#
# The text describes relationships between entities such as Beyoncé and Jay Z, I Am... Sasha Fierce and Manhattan, and the album I Am... Sasha Fierce and the Billboard 200 chart.
# ```json
# {
# 	"Beyoncé": "Starred as blues singer Etta James in the 2008 musical biopic, Cadillac Records. Donated her entire salary from the film to Phoenix House. Performed James' 'At Last' at the First Couple's first inaugural ball. Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed. Played Sharon Charles, a mother and wife who learns of a woman's obsessive behavior over her husband.",
# 	"Relationship": "Starred as blues singer Etta James in the 2008 musical biopic, Cadillac Records.",
# 	"Second Entity": "Etta James"
# }
#
# {
# 	"Beyoncé": "Starred as blues singer Etta James in the 2008 musical biopic, Cadillac Records.",
# 	"Relationship": "Starred as blues singer Etta James in the 2008 musical biopic, Cadillac Records.",
# 	"Second Entity": "Cadillac Records"
# }
#
# {
# 	"Beyoncé": "Donated her entire salary from the film to Phoenix House.",
# 	"Relationship": "Donated her entire salary from the film to Phoenix House.",
# 	"Second Entity": "Phoenix House"
# }
#
# {
# 	"Beyoncé": "Performed James' 'At Last' at the First Couple's first inaugural ball.",
# 	"Relationship": "Performed James' 'At Last' at the First Couple's first inaugural ball.",
# 	"Second Entity": "At Last"
# }
#
# {
# 	"Beyoncé": "Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed.",
# 	"Relationship": "Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed.",
# 	"Second Entity": "Ali Larter"
# }
#
# {
# 	"Beyoncé": "Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed.",
# 	"Relationship": "Stared opposite Ali Larter and Idris Elba in the thriller, Obsessed.",
# 	"Second Entity": "Idris Elba"
# }
#
# {
# 	"Beyoncé": "Played Sharon Charles, a mother and wife who learns of a woman's obsessive behavior over her husband.",
# 	"Relationship": "Played Sharon Charles, a mother and wife who learns of a woman's obsessive behavior over her husband.",
# 	"Second Entity": "Sharon Charles"
# }
# ```
# ```json
# {
# 	"Beyoncé": {
# 		"relationship": "Won multiple awards at the 52nd Annual Grammy Awards",
# 		"second entity": "52nd Annual Grammy Awards",
# 		"first entity": "Singers"
# 	},
# 	"Lauryn Hill": {
# 		"relationship": "Tied with Beyoncé for most Grammy nominations in a single year",
# 		"second entity": "Singers",
# 		"first entity": "Singers"
# 	},
# 	"52nd Annual Grammy Awards": {
# 		"relationship": "Held the 10th annual Grammy Awards",
# 		"second entity": "Events",
# 		"first entity": "Events"
# 	},
# 	"I Am... Sasha Fierce": {
# 		"relationship": "Won Album of the Year at the 52nd Annual Grammy Awards",
# 		"second entity": "Songs",
# 		"first entity": "Songs"
# 	},
# 	"Halo": {
# 		"relationship": "Won Record of the Year at the 52nd Annual Grammy Awards",
# 		"second entity": "Songs",
# 		"first entity": "Songs"
# 	},
# 	"Single Ladies (Put a Ring on It)": {
# 		"relationship": "Won Song of the Year at the 52nd Annual Grammy Awards",
# 		"second entity": "Songs",
# 		"first entity": "Songs"
# 	},
# 	"Lady Gaga": {
# 		"relationship": "Featured on Beyoncé's single 'Telephone'",
# 		"second entity": "Singers",
# 		"first entity": "Singers"
# 	},
# 	"US Pop Songs": {
# 		"relationship": "The song 'Telephone' topped the chart",
# 		"second entity": "Events",
# 		"first entity": "Events"
# 	},
# 	"Mariah Carey": {
# 		"relationship": "Tied with Beyoncé and Gaga for most number-ones since the Nielsen Top 40 airplay chart launched in 1992",
# 		"second entity": "Singers",
# 		"first entity": "Singers"
# 	}
# }
# ```
# ```json
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Announced hiatus and advised to live life and be inspired",
#   "Second entity": "Mother"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "Great Wall of China"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "Egyptian pyramids"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "Australia"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "English music festivals"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "Museums"
# }
#
# {
#   "Beyoncé": "Music career",
#   "Relationship": "Lasted nine months and included visits to multiple European cities",
#   "Second entity": "Ballet performances"
# }
# ```
#
# Sure, here is the grouped entities in dictionary format according to their semantic meaning:
#
# ```python
# grouped_entities = {
#     "People": ["Beyoncé"],
#     "Career": ["Music career"],
#     "Dates": ["January 2010"],
#     "Family": ["Mother"],
#     "Places": ["Great Wall of China", "Egyptian pyramids", "Australia", "English music festivals", "Museums", "Ballet performances"]
# }
# ```
# ```json
# {
# 	"Beyoncé": "Singer",
# 	"Relationship": "Performing for Gaddafi's family",
# 	"Second Entity": "Muammar Gaddafi"
# }
#
# {
# 	"Muammar Gaddafi": "Ruler",
# 	"Relationship": "Unknown",
# 	"Second Entity": "Beyoncé"
# }
#
# {
# 	"WikiLeaks": "Document leak organization",
# 	"Relationship": "Revealed information about Beyoncé's performance for Gaddafi's family",
# 	"Second Entity": "Beyoncé"
# }
#
# {
# 	"Rolling Stone": "Music magazine",
# 	"Relationship": "Urging artists to return money earned for Gaddafi's family",
# 	"Second Entity": "Gaddafi's family"
# }
#
# {
# 	"The Huffington Post": "News website",
# 	"Relationship": "Confirmed Beyoncé's donation to the Clinton Bush Haiti Fund",
# 	"Second Entity": "Clinton Bush Haiti Fund"
# }
#
# {
# 	"Clinton Bush Haiti Fund": "Charity fund",
# 	"Relationship": "Received donations from Beyoncé",
# 	"Second Entity": "Beyoncé"
# }
#
# {
# 	"Glastonbury Festival": "Event",
# 	"Relationship": "Beyoncé's performance there in 2011",
# 	"Second Entity": "Beyoncé"
# }
# ```
#
# This output includes the extracted information about the entities in the text, including their relationships to each other. The format is in JSON, as requested.
# ```json
# {
# "artists": ["Beyoncé"],
# "albums": ["Studio album 4"],
# "countries": ["US"],
# "charts": ["Billboard 200 chart"],
# "songs": ["Run the World (Girls)", "Best Thing I Never Had", "Love on Top", "Party", "Countdown", "I Care", "End of Time", "Eat, Play, Love"]
# }
# ```
#
# **Entities:**
#
# - **Beyoncé:**
#   - Properties:
#     - Name: Beyoncé
#     - Nationality: US
#     - Number-one albums in US: 4
#     - Writing award: Won for the cover story "Eat, Play, Love" written for Essence.
#
# - **Studio album 4:**
#   - Properties:
#     - Name: 4
#     - Release date: June 28, 2011
#     - Sales: 310,000 copies in first week
#     - Chart debut: Top of Billboard 200 chart
#     - Singles:
#       - Run the World (Girls)
#       - Best Thing I Never Had
#       - Love on Top
#       - Party
#       - Countdown
#       - I Care
#       - End of Time
#
# - **Billboard 200 chart:**
#   - Properties:
#     - Name: Billboard 200 chart
#     - Significance: Given Beyoncé her fourth consecutive number-one album in the US.
# ```json
# {
# 	"Human": {
# 		"Name": "Beyoncé",
# 		"Date of Birth": "January 7, 2012",
# 		"Child's Name": "Blue Ivy Carter",
# 		"Child's Gender": "Daughter",
# 		"Place of Birth": "Lenox Hill Hospital, New York",
# 		"Performance Date": "Unknown",
# 		"Performance Location": "Revel Atlantic City's Ovation Hall",
# 		"Performance Reason": "None",
# 		"Post-Birth Performances": "4 nights"
# 	},
# 	"Other": []
# }
# ```
#
# **Notes:**
#
# * The text does not specify the performance date or reason for the performance, therefore the fields for those properties are left as "Unknown" and "None" respectively.
# * The text mentions "her first performances since giving birth to Blue Ivy" but does not specify the number of performances, therefore the field "Post-Birth Performances" is filled with "4 nights".
# ```json
# {
#   "Destiny's Child": "Group",
#   "Love Songs": "Album",
#   "Beyoncé": "Artist",
#   "President Obama": "Politician",
#   "Washington, D.C.": "City",
#   "Super Bowl XLVII": "Event",
#   "Mercedes-Benz Superdome": "Stadium",
#   "New Orleans": "City",
#   "55th Annual Grammy Awards": "Event",
#   "Life Is But a Dream": "Documentary",
#   "HBO": "Network",
#   "Blue Ivy": "Child",
#   "Warner/Chappell Music": "Music Label"
# }
# ```
#
# The text describes several relationships between entities:
#
# * Destiny's Child, Love Songs, and Beyoncé are all related as artists.
# * President Obama and Washington, D.C. are related as politician and city, respectively.
# * Super Bowl XLVII and the 55th Annual Grammy Awards are both events.
# * Mercedes-Benz Superdome and New Orleans are related as stadium and city, respectively.
# * Life Is But a Dream and HBO are related as documentary and network, respectively.
# * Blue Ivy and Beyoncé are related as child and mother, respectively.
# * Warner/Chappell Music and Beyoncé are related as music label and artist, respectively.
# ```json
# {
# 	"Singers": ["Beyoncé", "Amy Winehouse", "André 3000"],
# 	"Events": ["The Mrs. Carter Show World Tour", "2013 Met Gala"],
# 	"Places": ["Belgrade", "Serbia"],
# 	"Movies": ["The Great Gatsby soundtrack", "20th Century Fox"]
# }
# ```
#
# **Explanation:**
#
# The text describes various entities and their relationships. The extracted properties for each entity are grouped into a dictionary, which is then converted into a JSON snippet.
#
# **Entities:**
#
# * **Singers:** Beyoncé, Amy Winehouse, André 3000
# * **Events:** The Mrs. Carter Show World Tour, 2013 Met Gala
# * **Places:** Belgrade, Serbia
# * **Movies:** The Great Gatsby soundtrack, 20th Century Fox
#
# **Relationships:**
#
# * Beyoncé embarked on The Mrs. Carter Show World Tour in Belgrade, Serbia.
# * The tour included 132 dates.
# * The Mrs. Carter Show World Tour became the most successful tour of her career.
# * Beyoncé's cover of Amy Winehouse's 'Back to Black' was released on The Great Gatsby soundtrack.
# * Beyoncé was honorary chair of the 2013 Met Gala.
# * Beyoncé voiced Queen Tara in Epic.
# * Beyoncé recorded an original song for Epic, 'Rise Up'.
# ```json
# {
#     "Beyoncé": {
#         "Occupation": "Singer",
#         "Gender": "Female",
#         "Awards": {
#             "Video Vanguard Award": null,
#             "Best Video with a Social Message": null,
#             "Best Cinematography for 'Pretty Hurts': null,
#             "Best Collaboration for 'Drunk in Love': null
#         },
#         "Albums": {
#             "Eponymous fifth studio album": {
#                 "Genre": "Electro-R&B",
#                 "Themes": ["Darker themes previously unexplored in her work"],
#                 "Sales": "One million digital copies worldwide in six days"
#             }
#         },
#         "Number-one albums in US": 5,
#         "First woman to have first five studio albums debut at number one": true
#     },
#     "Studio album": {
#         "Name": "Eponymous fifth studio album",
#         "Genre": "Electro-R&B",
#         "Themes": ["Darker themes previously unexplored in her work"],
#         "Sales": "One million digital copies worldwide in six days"
#     },
#     "Billboard 200 chart": {
#         "Debut": "Top of the chart",
#         "Number-one albums in US": 5
#     },
#     "The New York Times": {
#         "Recognition": "Noted the album's unconventional release as significant"
#     },
#     "Postnatal depression": {
#         "Theme explored in the album": "Postnatal depression"
#     },
#     "The On Run Tour": {
#         "Name": "On the Run Tour",
#         "Co-headlining stadium tour with Jay Z": true
#     },
#     "MTV Video Music Awards": {
#         "Award received": "Video Vanguard Award"
#     },
#     "Forbes": {
#         "Top-earning woman in music in 2013 and 2014": true,
#         "Earnings in 2013": "$115 million"
#     }
# }
# ```
# ```json
# {
#   "Beyoncé": "Best R&B Performance, Best R&B Song, Best Surround Sound Album, Album of the Year",
#   "Relationship": "Won",
#   "57th Annual Grammy Awards": "Date: February 2015",
#   "Best R&B Performance": null,
#   "Best R&B Song": null,
#   "Best Surround Sound Album": null,
#   "Album of the Year": "Beck",
#   "Vogue magazine": "Cover star, First African-American artist to cover the September issue",
#   "Made in America festival": "Headlined",
#   "Global Citizen Festival": "Headlined",
#   "Coldplay": "A Head Full of Dreams (2015), Hymn for the Weekend",
#   "Super Bowl 50": "Uncredited featured appearance, Performance"
# }
# ```
#
# **Notes:**
#
# * The text provided does not describe the relationship between the entities "Best R&B Performance" and "Best R&B Song", hence their values are set to `null`.
# * The text does not describe the relationship between "Album of the Year" and "Beck", hence its value is set to "Beck".
# * The text does not describe the relationship between "Hymn for the Weekend" and "Coldplay", hence its value is set to "Uncredited featured appearance".

# %%
relationship_instructions = relationship_parser.get_format_instructions()
prompt = PromptTemplate(
    template="You are ontologist. Task is to build knowledge graph by using entities, proporties, term_list, input and relationships in Neo4j cyher format.\n{entities}\n{proporties}\n{group}\n{relationship}\n{input}",
    input_variables=["entities","proporties","term_list",'relationship',"input"],
)
chain = prompt | llm  
scripts_list = list()
for context_idx in range(len(contexts)):
    scripts = chain.invoke({"input": contexts['context'].iloc[context_idx],"entities": entity_context_list[context_idx], 'proporties':properties_list[context_idx], 'group':context_tags_list[context_idx], 'relationship':relationships_list[context_idx]})
    scripts = extract_cypher_scripts(scripts)
    scripts_list.append(scripts)

# %%
scripts_list
# Out:
# [['CREATE (b:Person {name: "Beyoncé Giselle Knowles-Carter", born: 1981, nationality: "American", occupation: "Singer, Songwriter, Record Producer, Actress"})',
#   'CREATE (h:Place {name: "Houston", state: "Texas"})',
#   'CREATE (g:Group {name: "Destiny\'s Child"})',
#   'CREATE (r:Genre {name: "R&B"})',
#   'CREATE (a:Award {name: "Grammy Awards"})',
#   'CREATE (b)-[:BORN_AND_RAISED_IN]->(h)',
#   'CREATE (b)-[:LEAD_SINGER_OF]->(g)',
#   'CREATE (m:Manager {name: "Mathew Knowles"})-[:MANAGES]->(g)',
#   'CREATE (a)-[:WON_BY]->(b)'],
#  ['CREATE (b:Artist {name: "Beyoncé"})',
#   'CREATE (dc:Artist {name: "Destiny\'s Child"})',
#   'CREATE (b)<-[:SOLO_ARTIST]-(b:Album {name: "B\'Day (2006)"})',
#   'CREATE (b)<-[:SOLO_ARTIST]-(b:Album {name: "I Am... Sasha Fierce (2008)"})',
#   'CREATE (b)<-[:SOLO_ARTIST]-(b:Album {name: "4 (2011)"})',
#   'CREATE (b)<-[:SOLO_ARTIST]-(b:Album {name: "Beyoncé (2013)"})',
#   'CREATE (dc)<-[:BAND]-(dc:Album {name: "Dreamgirls (2006)"})',
#   'MATCH (b)<-[:HAS_HIT]-(h:Hit {name: "Déjà Vu"})',
#   'MATCH (b)<-[:HAS_HIT]-(h:Hit {name: "Irreplaceable"})',
#   'MATCH (b)<-[:HAS_HIT]-(h:Hit {name: "Beautiful Liar"})',
#   'MATCH (b)<-[:ACTED_IN]-(m:Movie {name: "Dreamgirls (2006)"})',
#   'MATCH (b)<-[:ACTED_IN]-(m:Movie {name: "The Pink Panther (2006)"})',
#   'MATCH (b)<-[:ACTED_IN]-(m:Movie {name: "Obsessed (2009)"})',
#   'CREATE (b)<-[: ACHIEVEMENT]-(a:Achievement {name: "Record-setting six Grammy Awards in 2010"})',
#   'CREATE (b)<-[: ACHIEVEMENT]-(a:Achievement {name: "Song of the Year for \'Single Ladies (Put a Ring on It)\'"})'],
#  ['CREATE (b:Artist {name: "Beyoncé", title: "Artist of the Millennium"})',
#   'CREATE (r:Relationship {name: "Monogamy"})',
#   'CREATE (l:Theme {name: "Love"})',
#   'MATCH (b)<-[r]-(l)'],
#  ['CREATE (p:Person {name: "Beyoncé"})',
#   'CREATE (s:School {name: "St. Mary\'s Elementary School"})',
#   'CREATE (f:Place {name: "Fredericksburg, Texas"})',
#   'CREATE (h:HighSchool {name: "High School for the Performing and Visual Arts"})',
#   'CREATE (a:AliefElsikHighSchool {name: "Alief Elsik High School"})',
#   'CREATE (c:Church {name: "St. John\'s United Methodist Church"})',
#   'MATCH (p)<-[:ATTENDED]-(s)',
#   'MATCH (p)<-[:MEMBER_OF]-(c)',
#   'MATCH (s)<-[:LOCATED_IN]-(f)',
#   'MATCH (h)<-[:LOCATED_IN]-(f)',
#   'MATCH (a)<-[:LOCATED_IN]-(f)'],
#  [],
#  ['CREATE (artist:Artist {name: "Destiny\'s Child"})',
#   'CREATE (artist2:Artist {name: "Beyoncé"})',
#   'CREATE (artist3:Artist {name: "Boyz II Men"})',
#   'CREATE (movie:Movie {name: "Men in Black"})',
#   'CREATE (movie2:Movie {name: "No, No, No"})',
#   'CREATE (movie3:Movie {name: "The Writing\'s on the Wall"})',
#   'CREATE (award:Award {name: "Grammy Awards"})',
#   'CREATE (artist) -[:HAS_SONG]-> (song:Song {name: "No, No, No"})',
#   'CREATE (song) -[:IS_MAJOR_HIT] -> ()',
#   'CREATE (artist) -[:WON_AWARDS]-> (award)',
#   'CREATE (movie) -[:HAS_SOUNDTRACK_SONG]-> (song)',
#   'CREATE (movie2) -[:HAS_SOUNDTRACK_SONG]-> (song)',
#   'CREATE (movie3) -[:HAS_SOUNDTRACK_SONG]-> (song)',
#   'CREATE (artist2) -[:RECORDED_ duet_WITH]-> (song)'],
#  ['CREATE (c:Celebrity {name: "LeToya Luckett"})',
#   'CREATE (c:Celebrity {name: "Roberson"})',
#   'CREATE (c:Celebrity {name: "Farrah Franklin"})',
#   'CREATE (c:Celebrity {name: "Michelle Williams"})',
#   'CREATE (c:Celebrity {name: "Beyoncé"})',
#   'CREATE (g:Group {name: "Destiny\'s Child"})',
#   'CREATE (m:Manager {name: "Mathew"})',
#   'MATCH (c:Celebrity {name: "LeToya Luckett"})-[:UNHAPPY]-(m)',
#   'MATCH (c:Celebrity {name: "Roberson"})-[:UNHAPPY]-(m)',
#   'MATCH (c:Celebrity {name: "Farrah Franklin"})-[:REPLACED]-(c:Celebrity {name: "Michelle Williams"})',
#   'MATCH (c:Celebrity {name: "Beyoncé"})-[:EXPERienced]-(depress)',
#   'MATCH (depress)<-[:LASTED]-(c:Celebrity {name: "Beyoncé"})',
#   'MATCH (c:Celebrity {name: "Beyoncé"})-[:SPOKE_ABOUT]-(mother)',
#   'MATCH (g)<-[:MEMBER]-(c:Celebrity {name: "Beyoncé"})',
#   'MATCH (g)<-[:MEMBER]-(c:Celebrity {name: "Rowland"})',
#   'MATCH (g)<-[:MEMBER]-(c:Celebrity {name: "Williams"})',
#   '* The `CREATE` statements create nodes for each entity and the `MATCH` statements define relationships between them.'],
#  ['CREATE (c:Artist {name: "Destiny\'s Child"})',
#   'CREATE (b:Artist {name: "Beyoncé"})',
#   'CREATE (l:Artist {name: "Luckett"})',
#   'CREATE (r:Artist {name: "Roberson"})',
#   'CREATE (ca:Artist {name: "Charlie\'s Angels"})',
#   'CREATE (usc:ChartingSuccess {name: "U.S. Billboard Hot 100 chart"})',
#   'CREATE (f:ChartingSuccess {name: "2000 film"})',
#   'CREATE (ch:ChartingSuccess {name: "Carmen: A Hip Hopera"})',
#   'CREATE (g:Musician {name: "Georges Bizet"})',
#   'CREATE (s:Musician {name: "Survivor"})',
#   'CREATE (cs:ChristmasSong {name: "8 Days of Christmas"})',
#   'MATCH (c) CREATE Relationship (c)-[:RECORDED_SONG]->(usc)',
#   'MATCH (b) CREATE Relationship (b)-[:RECORDED_SONG]->(usc)',
#   'MATCH (l) CREATE Relationship (l)-[:RECORDED_SONG]->(usc)',
#   'MATCH (r) CREATE Relationship (r)-[:RECORDED_SONG]->(usc)',
#   'MATCH (ca) CREATE Relationship (ca)-[:RECORDED_SONG]->(usc)',
#   'MATCH (f) CREATE Relationship (usc)-[:TOPPED_CHART]->(f)',
#   'MATCH (ch) CREATE Relationship (usc)-[:TOPPED_CHART]->(ch)',
#   'MATCH (g) CREATE Relationship (g)-[:INSPIRED]->(ch)',
#   'MATCH (s) CREATE Relationship (s)-[:INSPIRED]->(ch)',
#   'MATCH (c) CREATE Relationship (c)-[:ANNOUNCED_HIATUS]->(cs)',
#   '* The `CREATE` statements create nodes and relationships between them.',
#   '* The `MATCH` statements establish relationships between existing nodes.'],
#  [],
#  ['CREATE (b:Beyoncé)',
#   'CREATE (j:JayZ)',
#   'CREATE (o:03Bonnie & Clyde)',
#   'CREATE (c:U.S.Billboard Hot 100 chart)',
#   'CREATE (d:Dangerously in Love)',
#   'CREATE (m:Michelle Williams)',
#   'CREATE (k:Kelly Rowland)',
#   'MATCH (b)<-[:Featured on]-(o)',
#   'MATCH (d)<-[:Released]-(b)',
#   'MATCH (d)<-[:Sold]-(b)',
#   'MATCH (d)<-[:Debut]-(c)',
#   'MATCH (b)<-[:Number-one single]-(c)',
#   'MATCH (b)<-[:Top-five single]-(c)',
#   'MATCH (b)<-[:Earned]-(g)'],
#  ['CREATE (b:Beyoncé)',
#   "CREATE (t:Tour {name: 'Dangerously in Love Tour'})",
#   "CREATE (e:Event {name: 'Super Bowl XXXVIII'})",
#   'CREATE (r:ReliantStadium)',
#   'CREATE (h:Houston)',
#   'CREATE (tx:Texas)',
#   'MATCH (b)<-[:PERFORMS_AT]-(e)',
#   'MATCH (r)<-[:LOCATION_OF]-(e)',
#   "CREATE (a:Album {name: 'Destiny Fulfilled'})",
#   "MATCH (dc:Destiny'sChild)<-[:TOURS_WITH]-(a)",
#   'CREATE (a)<-[:Album_Released_By]-(dc)',
#   "CREATE (c:Album {name: 'Number 1's})",
#   'MATCH (dc)<-[:DISBANDMENT_AFTER]-(c)',
#   'CREATE (c)<-[:Released_By]-(dc)'],
#  ['CREATE (c:Celebrity {name: "Beyoncé", nationality: "US", album: "B\'Day", number_one_albums: 2, single: "Déjà Vu", single_sales: 541000})',
#   'CREATE (a:Album {name: "B\'Day", release_date: "September 5, 2006", sales: 541000, singles: ["Déjà Vu", "Irreplaceable", "Ring the Alarm", "Get Me Bodied", "Green Light"]})',
#   'CREATE (b:Chart {name: "Billboard 200", top_selling_album: a})',
#   'CREATE (h:Chart {name: "Billboard Hot 100", single: "Déjà Vu", top_five_single: "Déjà Vu"})',
#   'CREATE (s:Song {name: "Déjà Vu", single_sales: Unknown, chart_position: "Top five"})',
#   'CREATE (c)<-[:ARTIST_OF]-(a)',
#   'CREATE (a)<-[:RELEASED_ON]-(b)',
#   'CREATE (s)<-[:SINGLE]-(a)',
#   'CREATE (a)<-[:TOPS_SELLING_ALBUM]-(b)',
#   'CREATE (h)<-[:SINGLE_TOP_FIVE]-(s)'],
#  ['CREATE (s:Singer {name: "Beyoncé"})-[:STARS_IN]->(m:Movie {name: "The Pink Panther"})',
#   'CREATE (m)<-[:GROSSES]-(g:Gross {amount: 158.8})',
#   'CREATE (b:Musical {name: "The Supremes"})-[:LOOSELY_BASED_ON]->(s)',
#   'CREATE (s)<-[:RELEASED_AS_LEAD_SINGLE]-(l:Song {name: "Listen"})',
#   'CREATE (t:Tour {name: "The Beyoncé Experience"})-[:EMBARKED_ON]->(s)',
#   'CREATE (s)<-[:CONDUCTED_PRE_CONCERT_FOOD_DONATION_DRIVES]-(p:Place {name: "St. John\'s"})',
#   'CREATE (r:Song {name: "B\'Day"})-[:RELEASED_WITH]->(l)'],
#  ['CREATE (p:Person {name: "Beyoncé"})',
#   'CREATE (p:Person {name: "Jay Z"})',
#   'CREATE (a:Album {name: "I Am... Sasha Fierce"})',
#   'CREATE (c:Chart {name: "Billboard 200"})',
#   'CREATE (p:Beyoncé) -[:MARRIED_TO]-> (p:Jay Z)',
#   'CREATE (a:I Am... Sasha Fierce) -[:ALBUM_RELEASE]-> (c:Billboard 200)'],
#  [],
#  ['CREATE (b:Singer {name: "Beyoncé"})',
#   'CREATE (lh:Singer {name: "Lauryn Hill"})',
#   'CREATE (g:Event {name: "52nd Annual Grammy Awards"})',
#   'CREATE (ia:Song {name: "I Am... Sasha Fierce"})',
#   'CREATE (h:Song {name: "Halo"})',
#   'CREATE (sl:Song {name: "Single Ladies (Put a Ring on It)")',
#   'CREATE (lg:Singer {name: "Lady Gaga"})',
#   'CREATE (mc:Singer {name: "Mariah Carey"})',
#   'CREATE (usPop:Event {name: "US Pop Songs"})'],
#  ['MATCH (b:Beyoncé)<-[:ANNOUNCED_HIATUS]-(mc:MusicCareer) WHERE mc.name = "Music career"',
#   'MATCH (b)<-[:ANNOUNCED_HIATUS]-(h:Hiatus) WHERE h.name = "January 2010"',
#   'MATCH (b:Beyoncé)<-[:MOTHER_ADVICE]-(m:Mother) WHERE m.name = "Mother"',
#   'MATCH (b:Beyoncé)<-[:VISITED]-(g:GreatWallOfChina) WHERE g.name = "Great Wall of China"',
#   'MATCH (b)<-[:VISITED]-(e:EgyptianPyramids) WHERE e.name = "Egyptian pyramids"',
#   'MATCH (b)<-[:VISITED]-(a:Australia) WHERE a.name = "Australia"',
#   'MATCH (b)<-[:VISITED]-(f:EnglishMusicFestivals) WHERE f.name = "English music festivals"',
#   'MATCH (b)<-[:VISITED]-(u:Museums) WHERE u.name = "Museums"',
#   'MATCH (b)<-[:VISITED]-(b:BalletPerformances) WHERE b.name = "Ballet performances"'],
#  ['CREATE (c:Celebrity {name: "Beyoncé", nationality: "Unknown", occupation: "Singer"})',
#   'CREATE (g:Celebrity {name: "Muammar Gaddafi", nationality: "Libyan", occupation: "Ruler"})',
#   'CREATE (w:Organization {name: "WikiLeaks", type: "Document leak organization"})',
#   'CREATE (r:Organization {name: "Rolling Stone", type: "Music magazine"})',
#   'CREATE (h:Organization {name: "The Huffington Post", type: "News website"})',
#   'CREATE (f:Fund {name: "Clinton Bush Haiti Fund", purpose: "Unknown"})',
#   'CREATE (e:Event {name: "Glastonbury Festival", location: "Unknown"})',
#   'MATCH (c)<-[r1]-(e)<-[r2]-(f)'],
#  ['CREATE (b:Beyoncé {name: "Beyoncé", nationality: "US", numberOneAlbumsInUS: 4, writingAward: "Won for the cover story \'Eat, Play, Love\' written for Essence"})',
#   'CREATE (sa:StudioAlbum {name: "4", releaseDate: "June 28, 2011", sales: 310000, chartDebut: "Top of Billboard 200 chart", singles: ["Run the World (Girls)", "Best Thing I Never Had", "Love on Top", "Party", "Countdown", "I Care", "End of Time"]})',
#   'CREATE (bc:BillboardChart {name: "Billboard 200 chart", significance: "Given Beyoncé her fourth consecutive number-one album in the US"})',
#   'MATCH (b)<-[:HAS_RELEASED]-(sa)',
#   'MATCH (sa)<-[:DEBUTED_ON]-(bc)'],
#  ['CREATE (h:Human {name: "Beyoncé", dob: "January 7, 2012", childName: "Blue Ivy Carter", childGender: "Daughter", placeOfBirth: "Lenox Hill Hospital, New York"})',
#   'CREATE (p:Place {name: "Revel Atlantic City\'s Ovation Hall"})',
#   'CREATE (h)-[:PERFORMS_AT]->(p)',
#   'CREATE (h)-[:GAVE_BIRTH_TO]->(c:Child {name: "Blue Ivy Carter"})',
#   'CREATE (c)-[:HAS_MOTHER]->(h)',
#   'CREATE (p)-[:TO_CELEBRATE]->(h)'],
#  [],
#  ['CREATE (s:Singer {name: "Beyoncé"})',
#   'CREATE (t:Tour {name: "The Mrs. Carter Show World Tour"})',
#   'CREATE (p:Place {name: "Belgrade"})',
#   'CREATE (a:Album {name: "The Great Gatsby soundtrack"})',
#   'CREATE Relationship (s) -[:PERFORMS_ON]-> (t)',
#   'CREATE Relationship (t) -[:HAS_DATES]-> (p)',
#   'CREATE Relationship (a) -[:CONTAINS]-> (t)',
#   'CREATE Relationship (s) -[:HONORS]-> (e:Event {name: "2013 Met Gala"})',
#   'CREATE Relationship (s) -[:VOICES]-> (q:Character {name: "Queen Tara"})',
#   'CREATE Relationship (q) -[:SINGS]-> (a)',
#   'CREATE Relationship (s) -[:RECORDED_SONG]-> (r:Song {name: "Rise Up"})',
#   'MATCH (s)'],
#  ['CREATE (b:Beyoncé {name: "Beyoncé", occupation: "Singer", gender: "Female", awards: ["Video Vanguard Award", "Best Video with a Social Message", "Best Cinematography for \'Pretty Hurts\'", "Best Collaboration for \'Drunk in Love\']})',
#   'CREATE (sa:StudioAlbum {name: "Eponymous fifth studio album", genre: "Electro-R&B", themes: ["Darker themes previously unexplored in her work"], sales: "One million digital copies worldwide in six days"})',
#   'CREATE (bc:BillboardChart {name: "Billboard 200 chart", debut: "Top of the chart", number_one_albums_in_us: 5})',
#   'CREATE (nyt:Newspaper {name: "The New York Times", recognition: "Noted the album\'s unconventional release as significant"})',
#   'CREATE (pd:MentalHealthCondition {name: "Postnatal depression"})',
#   'CREATE (ot:Event {name: "The On Run Tour", co_headlining_stadium_tour_with: "Jay Z"})',
#   'CREATE (mvma:Event {name: "MTV Video Music Awards", award_received: "Video Vanguard Award"})',
#   'CREATE (f:Forbes {top_earning_woman_in_music_in_2013_and_2014: true, earnings_in_2013: "$115 million"})',
#   'CONNECT (b) TO (sa)',
#   'CONNECT (sa) TO (bc)',
#   'CONNECT (nyt) TO (sa)',
#   'CONNECT (pd) TO (sa)',
#   'CONNECT (ot) TO (sa)',
#   'CONNECT (mvma) TO (sa)',
#   'CONNECT (f) TO (sa)'],
#  ['CREATE (',
#   'CONNECT (',
#   'CONNECT (Beyoncé)-[:WON]->(BestR&BSong)',
#   'CONNECT (Beyoncé)-[:WON]->(BestSurroundSoundAlbum)',
#   'CONNECT (Beyoncé)-[:WON]->(AlbumOfTheYear)',
#   'CONNECT (GrammyAwards)-[:DATE]->(BestR&BPerformance)',
#   'CONNECT (GrammyAwards)-[:DATE]->(BestR&BSong)',
#   'CONNECT (GrammyAwards)-[:DATE]->(BestSurroundSoundAlbum)',
#   'CONNECT (GrammyAwards)-[:DATE]->(AlbumOfTheYear)',
#   'CONNECT (Beck)-[:WON]->(AlbumOfTheYear)',
#   'CONNECT (VogueMagazine)-[:COVER_STAR]->(Beyoncé)',
#   'CONNECT (MadeInAmericaFestival)-[:HEADLINED]->(Beyoncé)',
#   'CONNECT (GlobalCitizenFestival)-[:HEADLINED]->(Beyoncé)',
#   'CONNECT (Coldplay)-[:ALBUM]->(AHeadFullOfDreamsAlbum)',
#   'CONNECT (AHeadFullOfDreamsAlbum)-[:UNTRIBUTED_FEATURED_APPEARANCE]->(Beyoncé)',
#   'CONNECT (SuperBowl50)-[:PERFORMANCE]->(Beyoncé)']]
