# %%
from langchain_community.llms import Ollama
from langchain_core.output_parsers import JsonOutputParser
from langchain.output_parsers import YamlOutputParser

import pandas as pd 
import numpy as np

# %%
llm = Ollama(model="gemma:7b")

# %% [markdown]
# ## Extract Term List from Plain Text

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a ontologist. You build knowledge graph from plain input. \nExtract Entites from plain text."),
    ("system", "The format should be python list"),    
    ("user", "{input}")
])
chain = prompt | llm
entity_context_list = list()

contexts = pd.read_csv('/Users/mertakcay/Projects/KnowledgeGraphBuilder/context.csv')
for context in contexts['context'].values:
    entity_list = list()
    entities = chain.invoke({"input": context})
    for sample in entities.split('\n'):
        if '-' in sample:
            entity_list.append(sample.replace('- ',''))
    entity_context_list.append(entity_list)
    print('----')
# Out:
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %%
entity_context_list
# Out:
# [['Beyoncé Giselle Knowles-Carter',
#   'Houston',
#   'Texas',
#   "Destiny's Child",
#   'Mathew Knowles',
#   'R&B',
#   'Dangerously in Love',
#   'Grammy Awards'],
#  ['Beyoncé',
#   "Destiny's Child",
#   "B'Day (2006)",
#   'Déjà Vu',
#   'Irreplaceable',
#   'Beautiful Liar',
#   'Dreamgirls (2006)',
#   'The Pink Panther (2006)',
#   'Obsessed (2009)',
#   'Cadillac Records (2008)',
#   'I Am... Sasha Fierce (2008)',
#   'Single Ladies (Put a Ring on It)',
#   '4 (2011)',
#   'Beyoncé (2013)'],
#  ['Beyoncé',
#   'Love',
#   'Relationships',
#   'Monogamy',
#   'Female sexuality',
#   'Empowerment',
#   'Contemporary popular music',
#   "Destiny's Child",
#   'Music artists',
#   'Grammy Awards',
#   'Recording Industry Association of America',
#   'Top Certified Artist',
#   'Top Radio Songs Artist',
#   'Top Female Artist',
#   'Artist of the Millennium',
#   'Time',
#   'Forbes'],
#  ['Beyoncé',
#   "St. Mary's Elementary School",
#   'Fredericksburg, Texas',
#   'Darlette Johnson',
#   'John Lennon',
#   'Parker Elementary School',
#   'High School for the Performing and Visual Arts',
#   'Alief Elsik High School',
#   "St. John's United Methodist Church"],
#  ['Beyoncé',
#   'Kelly Rowland',
#   'LaTavia Roberson',
#   "Girl's Tyme",
#   'R&B producer Arne Frager',
#   'Star Search',
#   'Record labels',
#   'Elektra Records',
#   'Atlanta Records'],
#  ["Destiny's Child",
#   'Book of Isaiah',
#   'Men in Black',
#   'No, No, No',
#   "The Writing's on the Wall",
#   'Bills, Bills, Bills',
#   "Jumpin Jumpin'",
#   'Say My Name',
#   'Grammy Awards',
#   'Beyoncé',
#   'Boyz II Men',
#   'After All Is Said and Done'],
#  ['LeToya Luckett',
#   'Roberson',
#   'Farrah Franklin',
#   'Michelle Williams',
#   'Beyoncé',
#   'Mathew',
#   "Destiny's Child"],
#  ["Destiny's Child",
#   'Beyoncé',
#   'Luckett',
#   'Roberson',
#   "Charlie's Angels",
#   'U.S. Billboard Hot 100 chart',
#   'Carmen: A Hip Hopera',
#   'Georges Bizet',
#   'Survivor',
#   '8 Days of Christmas'],
#  ['Beyoncé',
#   'Foxxy Cleopatra',
#   'Austin Powers in Goldmember',
#   'US box office',
#   '$73 million',
#   'Work It Out',
#   'UK',
#   'Norway',
#   'Belgium',
#   'The Fighting Temptations',
#   'Cuba Gooding, Jr.',
#   'The Fighting Temptations',
#   '$30 million',
#   'Fighting Temptation',
#   'Missy Elliott',
#   'MC Lyte',
#   'Free',
#   'Summertime'],
#  ['Beyoncé',
#   'Jay Z',
#   '03 Bonnie & Clyde',
#   'U.S. Billboard Hot 100 chart',
#   'Dangerously in Love',
#   'Michelle Williams',
#   'Kelly Rowland',
#   'Billboard 200',
#   'Crazy in Love',
#   'Baby Boy',
#   'Me, Myself and I',
#   'Naughty Girl',
#   'Grammy Awards'],
#  ['Beyoncé',
#   "Destiny's Child",
#   'Dangerously in Love Tour',
#   'Verizon Ladies First Tour',
#   'Super Bowl XXXVIII',
#   'Reliant Stadium',
#   'Houston',
#   'Texas',
#   'Destiny Fulfilled',
#   'Billboard 200',
#   'Billboard Hot 100 Chart',
#   "Number 1's"],
#  ['Beyoncé',
#   "B'Day",
#   'US',
#   'Billboard 200',
#   'Jay Z',
#   'Déjà Vu',
#   'Billboard Hot 100 Chart',
#   'Australia',
#   'Hungary',
#   'Ireland',
#   'New Zealand',
#   'United Kingdom'],
#  ['Beyoncé',
#   'The Pink Panther',
#   'Steve Martin',
#   'Dreamgirls',
#   'The Supremes',
#   'Diana Ross',
#   'Listen',
#   'The Beyoncé Experience',
#   "St. John's",
#   "America's Second Harvest"],
#  ['Beyoncé',
#   'Jay Z',
#   'I Am... Sasha Fierce',
#   'Manhattan',
#   'Sony Club',
#   'United States',
#   'Sasha Fierce',
#   'Billboard 200',
#   'Single Ladies (Put a Ring on It)',
#   'If I Were a Boy',
#   'Halo',
#   'Sweet Dreams',
#   'Diva',
#   'Ego',
#   'Broken-Hearted Girl',
#   'Video Phone'],
#  ['Beyoncé',
#   'Etta James',
#   'Cadillac Records',
#   'Phoenix House',
#   'At Last',
#   'Obsessed',
#   'Ali Larter',
#   'Idris Elba'],
#  ['Beyoncé',
#   '52nd Annual Grammy Awards',
#   'I Am... Sasha Fierce',
#   'Halo',
#   'Single Ladies (Put a Ring on It)',
#   'Lauryn Hill',
#   'US Pop Songs',
#   'Mariah Carey',
#   'Telephone'],
#  ['Beyoncé',
#   'Music career',
#   'January 2010',
#   'Mother',
#   'Great Wall of China',
#   'Egyptian pyramids',
#   'Australia',
#   'English music festivals',
#   'Museums',
#   'Ballet performances'],
#  ['Beyoncé',
#   'Muammar Gaddafi',
#   'WikiLeaks',
#   'Rolling Stone',
#   'The Huffington Post',
#   'Clinton Bush Haiti Fund',
#   'Glastonbury Festival'],
#  ['Beyoncé',
#   'Studio album 4',
#   'US',
#   'Billboard 200 chart',
#   'Run the World (Girls)',
#   'Best Thing I Never Had',
#   'Love on Top',
#   'Party',
#   'Countdown',
#   'I Care',
#   'End of Time',
#   'Eat, Play, Love'],
#  ['Beyoncé',
#   'Blue Ivy Carter',
#   'Lenox Hill Hospital',
#   'New York',
#   'Revel Atlantic City',
#   'Ovation Hall'],
#  ["Destiny's Child",
#   'Love Songs',
#   'President Obama',
#   'Washington, D.C.',
#   'Super Bowl XLVII',
#   'Mercedes-Benz Superdome',
#   'New Orleans',
#   '55th Annual Grammy Awards',
#   'Life Is But a Dream',
#   'Blue Ivy',
#   'Warner/Chappell Music'],
#  ['Beyoncé',
#   'The Mrs. Carter Show World Tour',
#   'Belgrade',
#   'Serbia',
#   '132',
#   'March',
#   'Amy Winehouse',
#   'André 3000',
#   'The Great Gatsby soundtrack',
#   '2013 Met Gala',
#   'Epic',
#   '20th Century Fox',
#   'Sia'],
#  ['Beyoncé',
#   'Billboard 200 chart',
#   'Electro-R&B',
#   'The New York Times',
#   'Jay Z',
#   'On the Run Tour',
#   'MTV Video Music Awards',
#   'Forbes'],
#  ['Beyoncé',
#   '57th Annual Grammy Awards',
#   'Best R&B Performance',
#   'Best R&B Song',
#   'Best Surround Sound Album',
#   'Album of the Year',
#   'Beck',
#   'Morning Phase album',
#   'Vogue magazine',
#   '2015 Made in America festival',
#   'Global Citizen Festival',
#   'Coldplay',
#   'A Head Full of Dreams (2015)',
#   'Super Bowl 50']]

# %% [markdown]
# ## Group Entities

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Group ALL entities according to semantic meaning of entity. \nThe output MUST be dictionary format."),
    ("user", "{entities}"),        
])
chain = prompt | llm

context_tags_list = list()
for entit_sample in entity_context_list:
    tags = chain.invoke({"entities": entit_sample})
    context_tags_list.append(tags)

# %% [markdown]
# ## Extract Properties of terms

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "Extract properties of each entities from plain input. \nThe output MUST be YAML format."),
    ("system", "{entities}"),        
    ("user", "{input}")
])

chain = prompt | llm 

properties_list = list()
for context_entity, context in zip(entity_context_list, contexts['context'].values):
    properties = chain.invoke({"input": context,"entities": context_entity})
    properties_list.append(properties)

properties_list
# Out:
# ["## Extracted Properties of Each Entity in the Text:\n\n**System:**\n\n- **Name:** System\n- **Properties:**\n    - Extract properties of each entity from plain input.\n    - Output MUST be in YAML format.\n\n**Human:**\n\n- **Name:** Beyoncé Giselle Knowles-Carter\n- **Properties:**\n    - Full name: Beyoncé Giselle Knowles-Carter\n    - Birth name: Knowles-Carter\n    - Birth date: September 4, 1981\n    - Nationality: American\n    - Occupation: Singer, songwriter, record producer, actress\n    - Place of birth: Houston, Texas\n    - Rise to fame: Late 1990s\n    - Group: Destiny's Child\n    - Group achievements: Best-selling girl group of all time\n    - Hiatus: Release of Beyoncé's debut album\n    - Solo album: Dangerously in Love (2003)\n    - Solo achievements: Five Grammy Awards\n    - Songs: 'Crazy in Love', 'Baby Boy'",
#  "```yaml\nentities:\n  - Beyoncé:\n    - Properties:\n      - Second solo album: B'Day (2006)\n      - Hits:\n        - Déjà Vu\n        - Irreplaceable\n        - Beautiful Liar\n      - Acting:\n        - Golden Globe-nominated performance in Dreamgirls (2006)\n        - Starring roles in The Pink Panther (2006) and Obsessed (2009)\n        - Marriage to rapper Jay Z\n        - Portrayal of Etta James in Cadillac Records (2008)\n      - Third album: I Am... Sasha Fierce (2008)\n      - Fourth album: 4 (2011)\n      - Fifth album: Beyoncé (2013)\n    - Overall:\n      - Music hiatus in 2010\n      - Record-setting six Grammy Awards in 2010, including Song of the Year for 'Single Ladies (Put a Ring on It)'\n      - Mellower tone on 4 (2011)\n      - Experimental production and exploration of darker themes on Beyoncé (2013)",
#  "```yaml\nsystem:\n  - Beyoncé\n  - Love\n  - Relationships\n  - Monogamy\n  - Female sexuality\n  - Empowerment\n  - Contemporary popular music\n  - Destiny's Child\n  - Music artists\n  - Grammy Awards\n  - Recording Industry Association of America\n  - Top Certified Artist\n  - Top Radio Songs Artist\n  - Top Female Artist\n  - Artist of the Millennium\n  - Time\n  - Forbes\n\nhuman:\n  - Self-described 'modern-day feminist'\n  - Creates songs that are often characterized by themes of love, relationships, and monogamy\n  - Dynamic, highly choreographed performances\n  - One of the best entertainers in contemporary popular music\n  - Sold over 118 million records as a solo artist\n  - Won 20 Grammy Awards\n  - Most nominated woman in the award's history\n  - Top Certified Artist in America during the 2000s decade\n  - Top Radio Songs Artist of the Decade\n  - Top Female Artist of the 2000s\n  - Artist of the Millennium\n  - Listed among the 100 most influential people in the world in 2013 and 2014\n  - Listed as the most powerful female musician of 2015",
#  "```yaml\n**Entities:**\n\n- **Beyoncé:**\n  - Attended: St. Mary's Elementary School\n  - Location: Fredericksburg, Texas\n  - Talent: Singing\n  - Enrollments:\n    - Parker Elementary School\n    - High School for the Performing and Visual Arts\n    - Alief Elsik High School\n  - Choir membership: St. John's United Methodist Church\n\n- **St. Mary's Elementary School:**\n  - Location: Fredericksburg, Texas\n\n- **Fredericksburg, Texas:**\n\n- **Darlette Johnson:**\n  - Occupation: Dance instructor\n\n- **John Lennon:**\n  - Song: 'Imagine'\n\n- **Parker Elementary School:**\n  - Location: Houston\n\n- **High School for the Performing and Visual Arts:**\n\n- **Alief Elsik High School:**\n\n- **St. John's United Methodist Church:**\n  - Choir membership: Beyoncé",
#  "**Output in YAML format:**\n\n```yaml\nentities:\n  - Beyoncé:\n    - Age: Unknown\n    - Relationship: Childhood friend of Kelly Rowland\n    - Group: Girl's Tyme\n    - Occupation: Singer\n  - Kelly Rowland:\n    - Age: Unknown\n    - Relationship: Childhood friend of Beyoncé\n    - Group: Girl's Tyme\n    - Occupation: Singer\n  - LaTavia Roberson:\n    - Age: Unknown\n    - Relationship: Unknown\n    - Group: Girl's Tyme\n    - Occupation: Unknown\n  - Girl's Tyme:\n    - Group members:\n      - Beyoncé\n      - Kelly Rowland\n      - LaTavia Roberson\n      - Unknown\n    - Occupation: Dancers and rappers\n  - R&B producer Arne Frager:\n    - Occupation: Producer\n  - Star Search:\n    - Description: Largest talent show on national TV\n  - Record labels:\n    - Elektra Records:\n      - Location: Unknown\n    - Atlanta Records:\n      - Location: Unknown\n  - Mathew:\n    - Relationship: Unknown\n    - Occupation: Unknown\n  - Dwayne Wiggins's Grass Roots Entertainment:\n    - Occupation: Unknown\n```",
#  "## Extracted Properties of Each Entity in YAML Format:\n\n```yaml\nentities:\n  - **Destiny's Child:**\n    - Name: Destiny's Child\n    - Year of Formation: Unknown\n    - Major Label Debut Song: 'Killing Time'\n    - Self-Titled Album: Yes\n    - Number-One Single: 'Bills, Bills, Bills'\n  - **Book of Isaiah:**\n    - Name: Book of Isaiah\n    - Passage Reference: Unknown\n  - **Men in Black:**\n    - Film Release Year: 1997\n  - **No, No, No:**\n    - Song Title: 'No, No, No'\n    - Album: Self-titled debut album\n  - **The Writing's on the Wall:**\n    - Sales: More than eight million copies worldwide\n    - Number-One Single: 'Bills, Bills, Bills'\n  - **Grammy Awards:**\n    - Best R&B Performance by a Duo or Group with Vocals: 'Say My Name'\n    - Best R&B Song: 'Say My Name'\n  - **Beyoncé:**\n    - Duet Recording: 'After All Is Said and Done'\n    - Song Title: 'After All Is Said and Done'\n    - Film Soundtrack: The Best Man\n  - **Boyz II Men:**\n    - Original Member: Marc Nelson\n```",
#  "## YAML output:\n\n```yaml\nsystem:\n  - LeToya Luckett\n  - Roberson\n  - Farrah Franklin\n  - Michelle Williams\n  - Beyoncé\n  - Mathew\n  - Destiny's Child\n\nhuman:\n  - LeToya Luckett and Roberson became unhappy with Mathew's managing of the band and eventually were replaced by Farrah Franklin and Michelle Williams.\n  - Beyoncé experienced depression following the split with Luckett and Roberson after being publicly blamed by the media, critics, and blogs for its cause.\n  - Her long-standing boyfriend left her at this time.\n  - The depression was so severe it lasted for a couple of years, during which she occasionally kept herself in her bedroom for days and refused to eat anything.\n  - Beyoncé stated that she struggled to speak about her depression because Destiny's Child had just won their first Grammy Award and she feared no one would take her seriously.\n  - Beyoncé would later speak of her mother as the person who helped her fight it.\n  - Franklin was dismissed, leaving just Beyoncé, Rowland, and Williams.\n```",
#  "## Extracted Properties of Each Entity in YAML Format\n\n```yaml\nentities:\n  - **Destiny's Child:**\n    - Properties:\n      - Name: Destiny's Child\n      - Role: Not specified in the text\n      - Affiliation: Not specified in the text\n\n  - **Beyoncé:**\n    - Properties:\n      - Name: Beyoncé\n      - Role: Not specified in the text\n      - Affiliation: Not specified in the text\n\n  - **Luckett:**\n    - Properties:\n      - Name: Luckett\n      - Role: Band member of Destiny's Child\n      - Affiliation: Destiny's Child\n\n  - **Roberson:**\n    - Properties:\n      - Name: Roberson\n      - Role: Band member of Destiny's Child\n      - Affiliation: Destiny's Child\n\n  - **Charlie's Angels:**\n    - Properties:\n      - Name: Charlie's Angels\n      - Role: Not specified in the text\n      - Affiliation: Not specified in the text\n\n  - **U.S. Billboard Hot 100 chart:**\n    - Properties:\n      - Name: U.S. Billboard Hot 100 chart\n      - Role: Chart on which 'Independent Women Part I' topped\n      - Affiliation: Not specified in the text\n\n  - **Carmen: A Hip Hopera:**\n    - Properties:\n      - Name: Carmen: A Hip Hopera\n      - Role: Film in which Beyoncé landed a major role\n      - Affiliation: Not specified in the text\n\n  - **Georges Bizet:**\n    - Properties:\n      - Name: Georges Bizet\n      - Role: Composer of the opera Carmen\n      - Affiliation: Not specified in the text\n\n  - **Survivor:**\n    - Properties:\n      - Name: Survivor\n      - Role: Third album by Destiny's Child\n      - Affiliation: Destiny's Child\n\n  - **8 Days of Christmas:**\n    - Properties:\n      - Name: 8 Days of Christmas\n      - Role: Holiday album by Destiny's Child\n      - Affiliation: Destiny's Child\n```",
#  '```yaml\n**System:**\n\n- Name: Beyoncé\n  Properties:\n    - Box office earnings: $73 million\n    - Songs:\n      - Work It Out\n      - Fighting Temptation\n      - Summertime\n\n- Name: Foxxy Cleopatra\n  Properties:\n    - Role: Played alongside Mike Myers in Austin Powers in Goldmember\n\n- Name: US box office\n  Properties:\n    - Gross revenue: $73 million\n\n- Name: UK\n  Properties:\n    - Top ten entry: Work It Out\n\n- Name: Norway\n  Properties:\n    - Top ten entry: Work It Out\n\n- Name: Belgium\n  Properties:\n    - Top ten entry: Work It Out\n\n- Name: The Fighting Temptations\n  Properties:\n    - Gross revenue: $30 million\n    - Role: Played by Cuba Gooding, Jr. as Lilly\n\n- Name: Fighting Temptation\n  Properties:\n    - Single mother character: Lilly\n\n- Name: Missy Elliott\n  Properties:\n    - Contribution to The Fighting Temptations soundtrack: Fighting Temptation\n\n- Name: MC Lyte\n  Properties:\n    - Contribution to The Fighting Temptations soundtrack: Fighting Temptation\n\n- Name: Free\n  Properties:\n    - Contribution to The Fighting Temptations soundtrack: Fighting Temptation\n\n- Name: Summertime\n  Properties:\n    - Song usage: Used to promote The Fighting Temptations film\n```',
#  "```yaml\n**system:**\n- Beyoncé\n- Jay Z\n- 03 Bonnie & Clyde\n- U.S. Billboard Hot 100 chart\n- Dangerously in Love\n- Michelle Williams\n- Kelly Rowland\n- Billboard 200\n- Crazy in Love\n- Baby Boy\n- Me, Myself and I\n- Naughty Girl\n- Grammy Awards\n\n**human:**\n- Beyoncé's first solo recording was a feature on Jay Z's '03 Bonnie & Clyde' that was released in October 2002, peaking at number four on the U.S. Billboard Hot 100 chart.\n- Her first solo album Dangerously in Love was released on June 24, 2003, after Michelle Williams and Kelly Rowland had released their solo efforts.\n- The album sold 317,000 copies in its first week, debuted atop the Billboard 200, and has since sold 11 million copies worldwide.\n- The album's lead single, 'Crazy in Love', featuring Jay Z, became Beyoncé's first number-one single as a solo artist in the US.\n- The single 'Baby Boy' also reached number one, and singles, 'Me, Myself and I' and 'Naughty Girl', both reached the top-five.\n- The album earned Beyoncé a then record-tying five awards at the 46th Annual Grammy Awards.",
#  "**YAML Output:**\n\n```yaml\nsystem:\n  - Beyoncé\n  - Destiny's Child\n  - Dangerously in Love Tour\n  - Verizon Ladies First Tour\n  - Super Bowl XXXVIII\n  - Reliant Stadium\n  - Houston\n  - Texas\n  - Destiny Fulfilled\n  - Billboard 200\n  - Billboard Hot 100 Chart\n  - Number 1's\n\nhuman:\n  - In November 2003, she embarked on the Dangerously in Love Tour in Europe and later toured alongside Missy Elliott and Alicia Keys for the Verizon Ladies First Tour in North America.\n  - On February 1, 2004, Beyoncé performed the American national anthem at Super Bowl XXXVIII, at the Reliant Stadium in Houston, Texas.\n  - After the release of Dangerously in Love, Beyoncé had planned to produce a follow-up album using several of the left-over tracks. However, this was put on hold so she could concentrate on recording Destiny Fulfilled, the final studio album by Destiny's Child.\n  - Destiny's Child embarked on a worldwide concert tour, Destiny Fulfilled... and Lovin' It and during the last stop of their European tour, in Barcelona on June 11, 2005, Rowland announced that Destiny's Child would disband following the North American leg of the tour.\n  - The group released their first compilation album Number 1's on October 25, 2005, in the US and accepted a star on the Hollywood Walk of Fame in March 2006.\n```",
#  "Sure, here is the extracted YAML data from the text:\n\n```yaml\nsystem:\n- Beyoncé\n- B'Day\n- US\n- Billboard 200\n- Jay Z\n- Déjà Vu\n- Billboard Hot 100 Chart\n- Australia\n- Hungary\n- Ireland\n- New Zealand\n- United Kingdom\n\nhuman:\n- Beyoncé's second solo album B'Day was released on September 5, 2006, in the US, to coincide with her twenty-fifth birthday.\n- It sold 541,000 copies in its first week and debuted atop the Billboard 200, becoming Beyoncé's second consecutive number-one album in the United States.\n- The album's lead single 'Déjà Vu', featuring Jay Z, reached the top five on the Billboard Hot 100 chart.\n- The second international single 'Irreplaceable' was a commercial success worldwide, reaching number one in Australia, Hungary, Ireland, New Zealand and the United States.\n- B'Day also produced three other singles; 'Ring the Alarm', 'Get Me Bodied', and 'Green Light' (released in the United Kingdom only).\n```",
#  "## Extracted Properties of Entities in Plain Text\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - Properties:\n      - Name: Beyoncé\n      - Role: Not specified\n      - Grossing income: Not specified\n      - Films:\n        - The Pink Panther\n        - Dreamgirls\n        - Listen\n      - Concert tours:\n        - The Beyoncé Experience\n      - Food donation drives:\n        - St. John's\n        - America's Second Harvest\n\n  - **The Pink Panther:**\n    - Properties:\n      - Name: The Pink Panther\n      - Grossing income: $158.8 million\n      - Stars:\n        - Steve Martin\n\n  - **Steve Martin:**\n    - Properties:\n      - Name: Steve Martin\n      - Role: Stars in The Pink Panther\n      - Grossing income: $158.8 million\n\n  - **Dreamgirls:**\n    - Properties:\n      - Name: Dreamgirls\n      - Grossing income: $154 million\n      - Stars:\n        - Beyoncé\n        - Jennifer Hudson\n        - Jamie Foxx\n        - Eddie Murphy\n\n  - **The Supremes:**\n    - Properties:\n      - Name: The Supremes\n      - Looseness based on: Not specified\n      - Grossing income: Not specified\n\n  - **Diana Ross:**\n    - Properties:\n      - Name: Diana Ross\n      - Role: Not specified\n      - Films:\n        - Dreamgirls\n\n  - **Listen:**\n    - Properties:\n      - Name: Listen\n      - Song type: Lead single\n      - Purpose: Promoting Dreamgirls film\n\n  - **The Beyoncé Experience:**\n    - Properties:\n      - Name: The Beyoncé Experience\n      - Grossing income: Over $24 million\n      - Number of venues: 97\n\n  - **St. John's:**\n    - Properties:\n      - Name: St. John's\n      - Food donation drives:\n        - Conducted by Beyoncé\n\n  - **America's Second Harvest:**\n    - Properties:\n      - Name: America's Second Harvest\n      - Food donation drives:\n        - Conducted by Beyoncé\n```",
#  '## Extracted Properties of Each Entity in the Text\n\n**Entities:**\n\n- **Beyoncé:**\n    - Properties:\n        - Name\n        - Career accomplishments\n        - Personal achievements\n        - Awards won\n        - Songs released\n        - Music videos\n\n- **Jay Z:**\n    - Properties:\n        - Name\n        - Relationship with Beyoncé\n        - Marriage to Beyoncé\n\n- **I Am... Sasha Fierce:**\n    - Properties:\n        - Name\n        - Release date\n        - Sales and chart performance\n        - Songs included\n\n- **Manhattan:**\n    - Properties:\n        - Location\n        - Significance in the text\n\n- **Sony Club:**\n    - Properties:\n        - Location\n        - Significance in the text\n\n- **United States:**\n    - Properties:\n        - Location\n        - Significance in the text\n\n- **Sasha Fierce:**\n    - Properties:\n        - Name\n        - Relationship to Beyoncé\n        - Introduction in I Am... Sasha Fierce\n\n- **Billboard 200:**\n    - Properties:\n        - Significance in the text\n\n- **Single Ladies (Put a Ring on It):**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **If I Were a Boy:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Halo:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Sweet Dreams:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Diva:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Ego:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Broken-Hearted Girl:**\n    - Properties:\n        - Song title\n        - Significance in the text\n\n- **Video Phone:**\n    - Properties:\n        - Song title\n        - Significance in the text',
#  "**YAML Output:**\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - Role: Blues singer Etta James in the 2008 musical biopic, Cadillac Records\n    - Accolades:\n      - Satellite Award nomination for Best Supporting Actress\n      - NAACP Image Award nomination for Outstanding Supporting Actress\n    - Donations:\n      - Entire salary from the film to Phoenix House\n    - Other accomplishments:\n      - Performance of James' 'At Last' at the First Couple's first inaugural ball\n      - Starred opposite Ali Larter and Idris Elba in Obsessed\n\n  - **Etta James:**\n    - Not described in the text\n\n  - **Cadillac Records:**\n    - Musical biopic released in 2008\n\n  - **Phoenix House:**\n    - Organization of rehabilitation centers for heroin addicts\n\n  - **At Last:**\n    - Song performed by Etta James\n\n  - **Obsessed:**\n    - Thriller film released in 2009\n\n  - **Ali Larter:**\n    - Starred opposite Beyoncé in Obsessed\n\n  - **Idris Elba:**\n    - Starred opposite Beyoncé in Obsessed\n\n```",
#  '```yaml\nentities:\n  - Beyoncé:\n    - Properties:\n      - "I Am... Sasha Fierce"\n      - "Halo"\n      - "Single Ladies (Put a Ring on It)"\n      - "Grammy Awards"\n      - "US Pop Songs"\n      - "Telephone"\n\n  - 52nd Annual Grammy Awards:\n    - Properties:\n      - "Album of the Year"\n      - "Record of the Year"\n      - "Song of the Year"\n\n  - Lauryn Hill:\n    - Properties:\n      - "Grammy nominations"\n\n  - Mariah Carey:\n    - Properties:\n      - "Number-ones"\n\n  - US Pop Songs:\n    - Properties:\n      - "Telephone"\n```',
#  "**Output in YAML format:**\n\n```yaml\n**System:**\n- Beyoncé\n- Music career\n- January 2010\n- Mother\n- Great Wall of China\n- Egyptian pyramids\n- Australia\n- English music festivals\n- Museums\n- Ballet performances\n\n**Human:**\n- Beyoncé announced a hiatus from her music career in January 2010.\n- Heeding her mother's advice, 'to live life, to be inspired by things again'.\n- During the break, she and her father parted ways as business partners.\n- Beyoncé's musical break lasted nine months and saw her visit multiple European cities, the Great Wall of China, the Egyptian pyramids, Australia, English music festivals and various museums and ballet performances.\n```",
#  "## Extracted Properties of Each Entity in YAML format:\n\n```yaml\nentities:\n  - **Beyoncé:**\n    - nationality: unknown\n    - occupation: singer\n    - achievements:\n      - became the first solo female artist to headline the main Pyramid stage at the 2011 Glastonbury Festival\n      - was named the highest-paid performer in the world per minute\n    - other_information:\n      - donated the money earned from her concerts to the Clinton Bush Haiti Fund\n  - **Muammar Gaddafi:**\n    - nationality: Libyan\n    - occupation: ruler\n    - connection_to_Beyonce:\n      - documents obtained by WikiLeaks revealed that Beyoncé was one of many entertainers who performed for Gaddafi's family\n  - **WikiLeaks:**\n    - occupation: organization that leaked documents\n    - connection_to_Beyonce:\n      - revealed that Beyoncé was one of many entertainers who performed for Gaddafi's family\n  - **Rolling Stone:**\n    - occupation: music magazine\n    - connection_to_Beyonce:\n      - reported that the music industry was urging artists to return the money they earned for the concerts\n  - **The Huffington Post:**\n    - occupation: news website\n    - connection_to_Beyonce:\n      - confirmed that Beyoncé donated the money earned from her concerts to the Clinton Bush Haiti Fund\n  - **Clinton Bush Haiti Fund:**\n    - occupation: charity organization\n    - connection_to_Beyonce:\n      - received donations from Beyoncé\n  - **Glastonbury Festival:**\n    - occupation: music festival\n    - connection_to_Beyonce:\n      - Beyoncé became the first solo female artist to headline the main Pyramid stage at the festival\n```",
#  "Sure, here is the extracted YAML data:\n\n```yaml\nsystem:\n  - Beyoncé\n  - Studio album 4\n  - US\n  - Billboard 200 chart\n  - Run the World (Girls)\n  - Best Thing I Never Had\n  - Love on Top\n  - Party\n  - Countdown\n  - I Care\n  - End of Time\n  - Eat, Play, Love\n\nhuman:\n  - Her fourth studio album 4 was released on June 28, 2011 in the US.\n  - 4 sold 310,000 copies in its first week and debuted atop the Billboard 200 chart, giving Beyoncé her fourth consecutive number-one album in the US.\n  - The album was preceded by two of its singles 'Run the World (Girls)' and 'Best Thing I Never Had', which both attained moderate success.\n  - The fourth single 'Love on Top' was a commercial success in the US.\n  - 4 also produced four other singles; 'Party', 'Countdown', 'I Care' and 'End of Time'.\n  - 'Eat, Play, Love', a cover story written by Beyoncé for Essence that detailed her 2010 career break, won her a writing award from the New York Association of Black Journalists.\n  - In late 2011, she took the stage at New York's Roseland Ballroom for four nights of special performances: the 4 Intimate Nights with Beyoncé concerts saw the performance of her 4 album to a standing room only.\n```",
#  '```yaml\nentities:\n  - Beyoncé\n  - Blue Ivy Carter\n  - Lenox Hill Hospital\n  - New York\n  - Revel Atlantic City\n  - Ovation Hall\n```',
#  "## Extracted properties of each entity in the text:\n\n**System:**\n\n- **Destiny's Child:**\n    - Name\n    - Release of Love Songs\n\n- **Love Songs:**\n    - Name\n    - Genre\n\n- **President Obama:**\n    - Name\n    - Location of inauguration\n    - Occasion of inauguration\n\n- **Washington, D.C.:**\n    - Location\n\n- **Super Bowl XLVII:**\n    - Name\n    - Location\n\n- **Mercedes-Benz Superdome:**\n    - Name\n    - Location\n\n- **New Orleans:**\n    - Location\n\n- **55th Annual Grammy Awards:**\n    - Name\n    - Award won by Beyoncé\n\n- **Life Is But a Dream:**\n    - Name\n    - Genre\n    - Release date\n\n- **Blue Ivy:**\n    - Name\n\n- **Warner/Chappell Music:**\n    - Name\n    - Global publishing agreement with Beyoncé\n\n\n**Human:**\n\n- **Beyoncé:**\n    - Name\n    - Performance at President Obama's inauguration\n    - Performance at Super Bowl XLVII halftime show\n    - Grammy Award win\n    - Film release\n    - Signing of global publishing agreement",
#  "**YAML Output:**\n\n```yaml\nentities:\n  - Beyoncé\n  - The Mrs. Carter Show World Tour\n  - Belgrade\n  - Serbia\n  - 132\n  - March\n  - Amy Winehouse\n  - André 3000\n  - The Great Gatsby soundtrack\n  - 2013 Met Gala\n  - Epic\n  - 20th Century Fox\n  - Sia\n\nproperties:\n  - Beyoncé embarked on The Mrs. Carter Show World Tour on April 15 in Belgrade, Serbia.\n  - The tour included 132 dates that ran through to March 2014.\n  - It became the most successful tour of her career and one of the most-successful tours of all time.\n  - In May, Beyoncé's cover of Amy Winehouse's 'Back to Black' with André 3000 on The Great Gatsby soundtrack was released.\n  - She was also honorary chair of the 2013 Met Gala.\n  - Beyoncé voiced Queen Tara in the 3D CGI animated film, Epic, released by 20th Century Fox on May 24, and recorded an original song for the film, 'Rise Up', co-written with Sia.\n```",
#  "```yaml\n**System:**\n\n- Beyoncé\n- Billboard 200 chart\n- Electro-R&B\n- The New York Times\n- Jay Z\n- On the Run Tour\n- MTV Video Music Awards\n- Forbes\n\n**Human:**\n\n- On December 13, 2013, Beyoncé unexpectedly released her eponymous fifth studio album on the iTunes Store without any prior announcement or promotion.\n- The album debuted atop the Billboard 200 chart, giving Beyoncé her fifth consecutive number-one album in the US.\n- Musically an electro-R&B album, it concerns darker themes previously unexplored in her work.\n- The single 'Drunk in Love', featuring Jay Z, peaked at number two on the Billboard Hot 100 chart.\n- In August 2014, she received the Video Vanguard Award at the 2014 MTV Video Music Awards.\n- In November, Forbes reported that Beyoncé was the top-earning woman in music for the second year in a row.",
#  "```yaml\n**Entities:**\n- Beyoncé\n- 57th Annual Grammy Awards\n- Best R&B Performance\n- Best R&B Song\n- Best Surround Sound Album\n- Album of the Year\n- Beck\n- Morning Phase album\n- Vogue magazine\n- 2015 Made in America festival\n- Global Citizen Festival\n- Coldplay\n- A Head Full of Dreams (2015)\n- Super Bowl 50\n\n**Properties:**\n- **Beyoncé:**\n  - Nominated for six awards at the 57th Annual Grammy Awards in February 2015.\n  - Won three awards: Best R&B Performance and Best R&B Song for 'Drunk in Love', and Best Surround Sound Album for Beyoncé.\n  - Covered the September issue of Vogue magazine, becoming the first African-American artist and third African-American woman to cover the issue.\n  - Headlined the 2015 Made in America festival and the Global Citizen Festival.\n  - Made an uncredited featured appearance on the track 'Hymn for the Weekend' by Coldplay.\n- **57th Annual Grammy Awards:**\n  - Held in February 2015.\n- **Best R&B Performance:**\n  - Won by Beyoncé for 'Drunk in Love'.\n- **Best R&B Song:**\n  - Won by Beyoncé for 'Drunk in Love'.\n- **Best Surround Sound Album:**\n  - Won by Beyoncé for Beyoncé.\n- **Album of the Year:**\n  - Won by Beck for Morning Phase album.\n- **Vogue magazine:**\n  - Cover star for the September issue featuring Beyoncé.\n- **2015 Made in America festival:**\n  - Headlined by Beyoncé.\n- **Global Citizen Festival:**\n  - Headlined by Beyoncé.\n- **Coldplay:**\n  - Seventh studio album A Head Full of Dreams (2015) released in December.\n  - Track 'Hymn for the Weekend' featuring Beyoncé.\n- **Super Bowl 50:**\n  - Scheduled to be performed by Beyoncé and Coldplay in February 2016."]

# %%
properties_list[0]
# Out:
# "## Extracted Properties of Each Entity in the Text:\n\n**System:**\n\n- **Name:** System\n- **Properties:**\n    - Extract properties of each entity from plain input.\n    - Output MUST be in YAML format.\n\n**Human:**\n\n- **Name:** Beyoncé Giselle Knowles-Carter\n- **Properties:**\n    - Full name: Beyoncé Giselle Knowles-Carter\n    - Birth name: Knowles-Carter\n    - Birth date: September 4, 1981\n    - Nationality: American\n    - Occupation: Singer, songwriter, record producer, actress\n    - Place of birth: Houston, Texas\n    - Rise to fame: Late 1990s\n    - Group: Destiny's Child\n    - Group achievements: Best-selling girl group of all time\n    - Hiatus: Release of Beyoncé's debut album\n    - Solo album: Dangerously in Love (2003)\n    - Solo achievements: Five Grammy Awards\n    - Songs: 'Crazy in Love', 'Baby Boy'"

# %% [markdown]
# ## Extract relationships between terms

# %%
from langchain.output_parsers import ResponseSchema, StructuredOutputParser
from langchain.prompts import PromptTemplate
response_schemas = [
    ResponseSchema(name="first entity", description="first entity of relationship between entities"),
    ResponseSchema(name="relationship", description="relationship between two entity semantically"),
    ResponseSchema(name="second entity", description="second entity of relationship between entities"),
]
relationship_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# %%
relationship_instructions = relationship_parser.get_format_instructions()
prompt = PromptTemplate(
    template="Create relationship between entities from plain text.\n{relationship_instructions}\n{entities}\n{input}",
    input_variables=["entities","input"],
    partial_variables={"relationship_instructions": relationship_instructions},
)
chain = prompt | llm  
relationships = chain.invoke({"input": "Beyoncé Giselle Knowles-Carter (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles 'Crazy in Love' and 'Baby Boy'.",
                     "entities": entities})
print(relationships)
