# %%
from langchain_community.llms import Ollama
from langchain_core.output_parsers import JsonOutputParser
from langchain.output_parsers import YamlOutputParser

# %%
import pandas as pd
import numpy as np

# %%
contexts = pd.read_csv('/Users/mertakcay/Projects/KnowledgeGraphBuilder/context.csv')
contexts
# Out:
#                                               context
# 0   Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ b...
# 1   Following the disbandment of Destiny's Child i...
# 2   A self-described 'modern-day feminist', Beyonc...
# 3   Beyoncé attended St. Mary's Elementary School ...
# 4   At age eight, Beyoncé and childhood friend Kel...
# 5   The group changed their name to Destiny's Chil...
# 6   LeToya Luckett and Roberson became unhappy wit...
# 7   The remaining band members recorded 'Independe...
# 8   In July 2002, Beyoncé continued her acting car...
# 9   Beyoncé's first solo recording was a feature o...
# 10  In November 2003, she embarked on the Dangerou...
# 11  Beyoncé's second solo album B'Day was released...
# 12  Her first acting role of 2006 was in the comed...
# 13  On April 4, 2008, Beyoncé married Jay Z. She p...
# 14  Beyoncé further expanded her acting career, st...
# 15  At the 52nd Annual Grammy Awards, Beyoncé rece...
# ...

# %%
llm = Ollama(model="gemma:7b")

# %%
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a Neo4j Cypher Developer. Your task is to create cypher query from plain text question by using the knowledge graph"),
    ("system", "{kg}"),
    ("user", "{query}")
])

chain = prompt | llm
