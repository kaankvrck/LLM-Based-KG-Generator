# %%
from langchain_community.llms import Ollama
from langchain_core.output_parsers import JsonOutputParser
from langchain.output_parsers import YamlOutputParser

# %%
llm = Ollama(model="gemma:7b")

# %%
from langchain_core.prompts import ChatPromptTemplate
import re

def extract_cypher_scripts(text):
    cypher_list = list()
    for line in text.split("\n"):
        if 'CREATE' in line or 'MATCH' in line or 'CONNECT' in line:
            cypher_list.append(line)
            
    return cypher_list

# %%
import pandas as pd
import numpy as np
cypher_list = list()
contexts = pd.read_csv('./context.csv')
for context in contexts['context']:
    prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a ontologist. You build knowledge graph from plain text. \n 
     Task 1: Extract Entities from plain text as possible as atomic. \n
     Task 2: Define Cypher Node Type to each Entity.\n
     Task 3: Add features of each Entity from plain text. \n
     Task 4: Extract relationship between Entities from plain text as possible as atomic. \n\n
     Task 5: Convert all outputs to Neo4j Cypher Creation Format"""),
    ("system", "Let's think step by step."),
    ("user", "{input}")
    ])
    chain = prompt | llm 
    output = chain.invoke({"input": context})
    print(output)
    print('--------------------------------')
    cypher_scripts = extract_cypher_scripts(output.replace('`','"'))
    cypher_list.append(cypher_scripts)
# Out:
# **Task 1: Extract Entities from Plain Text**
#
# * **Entities:**
#     * Beyoncé Giselle Knowles-Carter
#     * America
#     * Houston
#     * Texas
#     * Destiny's Child
#     * Mathew Knowles
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# * **Beyoncé:** Person
# * **Destiny's Child:** Group
# * **America:** Country
# * **Houston:** City
# * **Texas:** State
# * **Mathew Knowles:** Manager
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# * **Beyoncé:**
#     * Singer
#     * Songwriter
#     * Record producer
#     * Actress
#     * Born in 1981
#     * Born in Houston, Texas
#     * Performed in singing and dancing competitions as a child
#     * Rose to fame in the late 1990s as lead singer of Destiny's Child
#     * Managed by her father, Mathew Knowles
#
# **Task 4: Extract Relationship between Entities from Plain Text**
#
# * **Beyoncé is from America.**
# * **Destiny's Child was formed in Houston, Texas.**
# * **Mathew Knowles managed Destiny's Child.**
# * **Beyoncé's debut album, Dangerously in Love (2003), established her as a solo artist worldwide.**
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé Giselle Knowles-Carter'})
# CREATE (a:Country {name: 'America'})
# CREATE (h:City {name: 'Houston'})
# CREATE (t:State {name: 'Texas'})
# CREATE (m:Manager {name: 'Mathew Knowles'})
# CREATE (dc:Group {name: 'Destiny's Child'})
#
# CREATE Relationship (b)-[:FROM]->(a)
# CREATE Relationship (h)-[:LOCATED_IN]->(t)
# CREATE Relationship (m)-[:MANAGES]->(dc)
# CREATE Relationship (b)-[:ESTABLISHED_AS]->(dc)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text - Step-by-Step
#
# **Task 1: Extracting Entities:**
#
# - **Entities:** Beyoncé, Destiny's Child, Single Ladies (Put a Ring on It), Dreamgirls, The Pink Panther, Obsessed, Cadillac Records, 4, Beyoncé (2013)
#
# **Task 2: Defining Cypher Node Type:**
#
# - **Beyoncé:** Artist, Actress, Manager
# - **Destiny's Child:** Group
# - **Single Ladies (Put a Ring on It):** Song
# - **Dreamgirls:** Movie
# - **The Pink Panther:** Movie
# - **Obsessed:** Movie
# - **Cadillac Records:** Movie
# - **I Am... Sasha Fierce:** Album
# - **4:** Album
# - **Beyoncé (2013):** Album
#
# **Task 3: Adding Features:**
#
# - **Beyoncé:**
#     - Born in 1981
#     - Won 22 Grammy Awards
#     - Married to Jay Z
#     - Has sold over 200 million records worldwide
#
# **Task 4: Extracting Relationships:**
#
# - **Beyoncé released her second solo album, B'Day (2006), after the disbandment of Destiny's Child.**
# - **Beyoncé ventured into acting with a Golden Globe-nominated performance in Dreamgirls (2006).**
# - **Her marriage to rapper Jay Z and portrayal of Etta James in Cadillac Records (2008) influenced her third album, I Am... Sasha Fierce (2008).**
# - **Her fourth album 4 (2011) was subsequently mellower in tone.**
# - **Her critically acclaimed fifth studio album, Beyoncé (2013), was distinguished from previous releases by its experimental production.**
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# ```cypher
# CREATE (b:Artist {name: 'Beyoncé', born: 1981})
# CREATE (dc:Group {name: 'Destiny's Child'})
# CREATE (sl:Song {name: 'Single Ladies (Put a Ring on It)'})
# CREATE (d:Movie {name: 'Dreamgirls'})
# CREATE (tp:Movie {name: 'The Pink Panther'})
# CREATE (o:Movie {name: 'Obsessed'})
# CREATE (cr:Movie {name: 'Cadillac Records'})
# CREATE (ia:Album {name: 'I Am... Sasha Fierce'})
# CREATE (f:Album {name: '4'})
# CREATE (b2:Album {name: 'Beyoncé (2013)'})
#
# MATCH (b) CREATE Relationship (b)-[:RELEASED]->(ia)
# MATCH (b) CREATE Relationship (b)-[:ACTED_IN]->(d)
# MATCH (b) CREATE Relationship (b)-[:INFLUENCED]->(cr)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text - Beyoncé Case Study
#
# **Task 1: Extracting Entities:**
#
# * **Entities:**
#     * Beyoncé
#     * Love
#     * Relationships
#     * Monogamy
#     * Female sexuality
#     * Empowerment
#     * Contemporary popular music
#     * Best entertainers
#     * Music artists
#     * Grammy Awards
#     * Top Certified Artist
#     * Top Radio Songs Artist
#     * Top Female Artist
#     * Artist of the Millennium
#     * Time
#     * Forbes
#
# **Task 2: Defining Cypher Node Type:**
#
# * **Beyoncé:** Node type - Artist
# * **Love:** Node type - Concept
# * **Relationships:** Node type - Relationship
# * **Monogamy:** Node type - Concept
# * **Female sexuality:** Node type - Concept
# * **Empowerment:** Node type - Concept
# * **Contemporary popular music:** Node type - Genre
# * **Best entertainers:** Node type - Accolade
# * **Music artists:** Node type - Artist
# * **Grammy Awards:** Node type - Award
# * **Top Certified Artist:** Node type - Achievement
# * **Top Radio Songs Artist:** Node type - Achievement
# * **Top Female Artist:** Node type - Achievement
# * **Artist of the Millennium:** Node type - Achievement
# * **Time:** Node type - Publication
# * **Forbes:** Node type - Publication
#
# **Task 3: Adding Features:**
#
# * **Beyoncé:**
#     * Sold over 118 million records as a solo artist.
#     * Sold a further 60 million with Destiny's Child.
#     * Won 20 Grammy Awards.
#     * Top Certified Artist in America during the 2000s decade.
#     * Top Radio Songs Artist of the Decade in 2009.
#     * Top Female Artist of the 2000s in 2009.
#     * Artist of the Millennium in 2011.
#     * Listed among the 100 most influential people in the world in 2013 and 2014.
#     * Listed as the most powerful female musician of 2015 by Forbes.
#
# **Task 4: Extracting Relationships:**
#
# * **Beyoncé:**
#     * Creates songs that are often characterized by themes of love, relationships, and monogamy.
#     * Has led to critics hailing her as one of the best entertainers in contemporary popular music.
#     * Has sold over 118 million records as a solo artist.
#     * Has won 20 Grammy Awards.
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# **Cypher Query:**
#
# ```cypher
# CREATE (b:Artist {name: "Beyoncé"})
# CREATE (l:Concept {name: "Love"})
# CREATE (r:Relationship {name: "Characterized By"})
# CREATE (g:Genre {name: "Contemporary Popular Music"})
# CREATE (b)-[r]-(l)
# CREATE (b)-[:HAS_WON]->(g)
# CREATE (b)-[:TOP_SELLING_ARTIST]->(g)
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# - **Beyoncé:** Singer, dancer, actress
# - **St. Mary's Elementary School:** Fredericksburg, Texas
# - **Parker Elementary School:** Houston
# - **High School for the Performing and Visual Arts:** Unknown
# - **Alief Elsik High School:** Unknown
# - **St. John's United Methodist Church:** Unknown
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# - **Beyoncé:** Person
# - **St. Mary's Elementary School:** Organization
# - **Parker Elementary School:** Organization
# - **High School for the Performing and Visual Arts:** Organization
# - **Alief Elsik High School:** Organization
# - **St. John's United Methodist Church:** Organization
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# - **Beyoncé:**
#     - Singing talent discovered
#     - Interest in music and performing continued
#     - Enrolled in Parker Elementary School
#     - Member of the choir at St. John's United Methodist Church
#
# - **St. Mary's Elementary School:**
#     - Dance classes
#     - High-pitched notes
#
# - **Parker Elementary School:**
#     - Music magnet school
#     - Choir performance
#
# - **High School for the Performing and Visual Arts:**
#     - Unknown features
#
# - **Alief Elsik High School:**
#     - Unknown features
#
# - **St. John's United Methodist Church:**
#     - Choir soloist
#
# **Task 4: Extract Relationship between Entities from Plain Text**
#
# - **Beyoncé attended St. Mary's Elementary School.**
# - **Beyoncé enrolled in dance classes at St. Mary's Elementary School.**
# - **Beyoncé discovered her singing talent at St. Mary's Elementary School.**
# - **Beyoncé continued her interest in music and performing after winning a school talent show at age seven.**
# - **Beyoncé enrolled in Parker Elementary School.**
# - **Beyoncé performed with the school's choir at Parker Elementary School.**
# - **Beyoncé was a member of the choir at St. John's United Methodist Church.**
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (sm:Organization {name: 'St. Mary's Elementary School'})
# CREATE (p:Organization {name: 'Parker Elementary School'})
# CREATE (hsp:Organization {name: 'High School for the Performing and Visual Arts'})
# CREATE (aes:Organization {name: 'Alief Elsik High School'})
# CREATE (stj:Organization {name: 'St. John's United Methodist Church'})
#
# MATCH (b)
# CREATE Relationship (b)-[:ATTENDED]->(sm)
# CREATE Relationship (b)-[:ENROLLED_IN]->(p)
# CREATE Relationship (b)-[:DISCOVERED_TALENT]->(sm)
# CREATE Relationship (b)-[:CONTINUOUS_INTEREST]->(sm)
# CREATE Relationship (b)-[:ENROLLED_IN]->(aes)
# CREATE Relationship (b)-[:PERFORMED_WITH]->(p)
# CREATE Relationship (b)-[:MEMBER_OF]->(stj)
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# - **Beyoncé:** Singer, dancer, actress
# - **Kelly Rowland:** Singer, dancer
# - **LaTavia Roberson:** Singer
# - **Girl's Tyme:** Group of girls
# - **R&B producer Arne Frager:** Music producer
# - **Star Search:** Talent show
# - **Elektra Records:** Record label
# - **Atlanta Records:** Record label
# - **Dwayne Wiggins's Grass Roots Entertainment:** Music company
# - **Columbia Records:** Record label
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# - **Beyoncé:** Celebrity
# - **Kelly Rowland:** Celebrity
# - **LaTavia Roberson:** Celebrity
# - **Girl's Tyme:** Group
# - **R&B producer Arne Frager:** MusicIndustryProfessional
# - **Star Search:** Event
# - **Elektra Records:** RecordLabel
# - **Atlanta Records:** RecordLabel
# - **Dwayne Wiggins's Grass Roots Entertainment:** MusicIndustryProfessional
# - **Columbia Records:** RecordLabel
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# - **Beyoncé:** Born in 1994, grew up in Houston, Texas, USA
# - **Kelly Rowland:** Born in 1990, grew up in Houston, Texas, USA
# - **LaTavia Roberson:** Born in 1988, grew up in Houston, Texas, USA
# - **Girl's Tyme:** Formed in 1995, disbanded in 1996
# - **R&B producer Arne Frager:** Managed Star Search, brought Girls Tyme to his studio
# - **Star Search:** Largest talent show on national TV
# - **Elektra Records:** Signed Girls Tyme in 1995
# - **Atlanta Records:** Briefly worked with Girls Tyme
# - **Dwayne Wiggins's Grass Roots Entertainment:** Signed Girls Tyme in 1995
# - **Columbia Records:** Signed Girls Tyme in 1996
#
# **Task 4: Extract Relationship Between Entities from Plain Text**
#
# - **Beyoncé:** Met LaTavia Roberson and Kelly Rowland in an audition
# - **Girl's Tyme:** Included Beyoncé, Rowland, and Roberson
# - **R&B producer Arne Frager:** Signed Girls Tyme to Star Search
# - **Star Search:** Provided a platform for Girls Tyme to perform
# - **Elektra Records:** Signed Girls Tyme and moved them to Atlanta Records
# - **Atlanta Records:** Briefly worked with Girls Tyme
# - **Dwayne Wiggins's Grass Roots Entertainment:** Signed Girls Tyme in 1995
# - **Columbia Records:** Signed Girls Tyme in 1996
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Celebrity {name: 'Beyoncé', birthYear: 1994, city: 'Houston'})
# CREATE (k:Celebrity {name: 'Kelly Rowland', birthYear: 1990, city: 'Houston'})
# CREATE (l:Celebrity {name: 'LaTavia Roberson', birthYear: 1988, city: 'Houston'})
# CREATE (gt:Group {name: 'Girl's Tyme'})
# CREATE (rf:MusicIndustryProfessional {name: 'R&B producer Arne Frager'})
# CREATE (ss:Event {name: 'Star Search'})
# CREATE (el:RecordLabel {name: 'Elektra Records'})
# CREATE (ar:RecordLabel {name: 'Atlanta Records'})
# CREATE (dg:MusicIndustryProfessional {name: 'Dwayne Wiggins's Grass Roots Entertainment'})
# CREATE (cr:RecordLabel {name: 'Columbia Records'})
#
# CONNECT (b) TO (gt)
# CONNECT (k) TO (gt)
# CONNECT (l) TO (gt)
# CONNECT (rf) TO (ss)
# CONNECT (ss) TO (el)
# CONNECT (el) TO (ar)
# CONNECT (ar) TO (dg)
# CONNECT (dg) TO (cr)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text - Step-by-Step
#
# **Task 1: Extracting Entities:**
#
# - **Entities:** Group, Song, Album, Film, Awards, Member, Record, Songwriter
# - **Atomic Extraction:** Each entity is extracted as a separate node in the knowledge graph. Even minor mentions of related entities like "Boyz II Men" are extracted as separate nodes.
#
# **Task 2: Defining Cypher Node Types:**
#
# - **Group:** Represented by a single node with properties like name, year formed, members, etc.
# - **Song:** Represented by a single node with properties like title, artist, year released, etc.
# - **Album:** Represented by a single node with properties like name, year released, tracks, etc.
# - **Film:** Represented by a single node with properties like name, year released, cast, etc.
# - **Awards:** Represented by a separate node with properties like name, awarded to, etc.
# - **Member:** Represented by a separate node with properties like name, relationship to group, etc.
# - **Record:** Represented by a separate node with properties like title, artist, year released, etc.
#
# **Task 3: Adding Features:**
#
# - **Textual Features:** Add features extracted from the text like sentence structure, word frequency, etc.
# - **Semantic Features:** Add features extracted from the text like the meaning of words, sentiment analysis, etc.
#
# **Task 4: Extracting Relationships:**
#
# - **Belongs To:** Group and Album nodes are linked with a "Belongs To" relationship.
# - **Featured In:** Song and Film nodes are linked with a "Featured In" relationship.
# - **Won:** Awards node is linked with Artist and Song nodes with a "Won" relationship.
# - **Member Of:** Member and Group nodes are linked with a "Member Of" relationship.
# - **Recorded On:** Song and Record nodes are linked with a "Recorded On" relationship.
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# - Use the extracted entities, node types, features, and relationships to create Cypher CREATE statements.
# - Create nodes for each entity with the specified properties.
# - Link nodes with relationships based on the extracted relationships.
# - Add additional Cypher commands to create constraints, indexes, and labels for optimization.
# --------------------------------
# ## Extracting Knowledge Graph from Plain Text
#
# **Task 1: Entities**
#
# - **LeToya Luckett**
# - **Roberson**
# - **Farrah Franklin**
# - **Michelle Williams**
# - **Beyonce**
#
# **Task 2: Node Type Definition**
#
# - **Person:** Represented by "PERSON" node type.
# - **Artist:** Represented by "ARTIST" node type.
#
# **Task 3: Features**
#
# - **LeToya Luckett:** Replaces by Farrah Franklin and Michelle Williams.
# - **Roberson:** Replaces by Farrah Franklin and Michelle Williams.
# - **Beyonce:** Experiences depression, has long-standing boyfriend leaving her, struggles to speak about depression.
#
# **Task 4: Relationships**
#
# - **LeToya Luckett and Roberson unhappy with Mathew's managing:** Replaces by Farrah Franklin and Michelle Williams.
# - **Beyonce experiencing depression:** Blamed for its cause, depression lasting for years.
# - **Farrah Franklin dismissed:** Leaving just Beyonce, Rowland, and Williams.
#
# **Task 5: Cypher Creation Format**
#
# ```cypher
# CREATE (p:PERSON {name: "LeToya Luckett"})
# CREATE (p:PERSON {name: "Roberson"})
# CREATE (p:PERSON {name: "Farrah Franklin"})
# CREATE (p:PERSON {name: "Michelle Williams"})
# CREATE (p:PERSON {name: "Beyonce"})
#
# Relationship (p:PERSON {name: "LeToya Luckett"})-[:REPLACED_BY]->(p:PERSON {name: "Farrah Franklin"})
# Relationship (p:PERSON {name: "LeToya Luckett"})-[:REPLACED_BY]->(p:PERSON {name: "Michelle Williams"})
# Relationship (p:PERSON {name: "Beyonce"})-[:EXPERIENCES_DEPRESSION]->(p:PERSON {name: "LeToya Luckett"})
# Relationship (p:PERSON {name: "Farrah Franklin"})-[:DISMISSED]->(p:PERSON {name: "Beyonce"})
# ```
# --------------------------------
# ## Knowledge Graph Construction from Plain Text
#
# **Task 1: Extracting Entities**
#
# * **Entities:**
#     * Destiny's Child
#     * Beyoncé
#     * Luckett
#     * Roberson
#     * Charlie's Angels
#     * U.S. Billboard Hot 100 chart
#     * Carmen: A Hip Hopera
#     * Georges Bizet
#     * Survivor
#     * 8 Days of Christmas
#
# **Task 2: Defining Cypher Node Type:**
#
# * **Destiny's Child:** Artist
# * **Beyoncé:** Artist
# * **Luckett:** Member
# * **Roberson:** Member
# * **Charlie's Angels:** Movie
# * **U.S. Billboard Hot 100 chart:** Chart
# * **Carmen: A Hip Hopera:** Movie
# * **Georges Bizet:** Composer
# * **Survivor:** Album
# * **8 Days of Christmas:** Album
#
# **Task 3: Adding Features:**
#
# * **Destiny's Child:**
#     * Best-charting single: "Independent Women Part I"
#     * Number-one hits: "Bootylicious", "Survivor"
#     * Grammy Award: Best R&B Performance by a Duo or Group with Vocals
#     * Hiatus: Yes
# * **Beyoncé:**
#     * Major role in "Carmen: A Hip Hopera"
#     * Number-one hits: "Bootylicious", "Survivor"
#     * Grammy Award: Best R&B Performance by a Duo or Group with Vocals
#     * Hiatus: Yes
# * **Luckett:**
#     * Lawsuit filed against the group
#     * Hiatus: Yes
# * **Roberson:**
#     * Lawsuit filed against the group
#     * Hiatus: Yes
#
# **Task 4: Extracting Relationships:**
#
# * **Destiny's Child:** recorded "Independent Women Part I"
# * **Beyoncé:** starred in "Carmen: A Hip Hopera"
# * **Luckett and Roberson:** filed a lawsuit against the group
# * **Survivor:** debuted at number one on the U.S. Billboard 200
# * **8 Days of Christmas:** was released by Destiny's Child
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# ```cypher
# CREATE (dc:Artist {name: 'Destiny''s Child'})
# CREATE (b:Artist {name: 'Beyoncé'})
# CREATE (l:Member {name: 'Luckett'})
# CREATE (r:Member {name: 'Roberson'})
# CREATE (c:Movie {name: 'Charlie's Angels'})
# CREATE (u:Chart {name: 'U.S. Billboard Hot 100 chart'})
# CREATE (car:Movie {name: 'Carmen: A Hip Hopera'})
# CREATE (g:Composer {name: 'Georges Bizet'})
# CREATE (s:Album {name: 'Survivor'})
# CREATE (hc:Album {name: '8 Days of Christmas'})
#
# Relationships:
# dc-recorded--s
# b-starredIn--car
# l-r--filedLawsuit--dc
# s-debutedAtNumberOne--u
# hc-releasedBy--dc
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text as Possible as Atomic**
#
# - **Entities:**
#   - Beyoncé
#   - Foxxy Cleopatra
#   - Austin Powers in Goldmember
#   - US box office
#   - Soundtrack album
#   - UK
#   - Norway
#   - Belgium
#   - The Fighting Temptations
#   - Cuba Gooding, Jr.
#   - Fighting Temptation
#   - Missy Elliott
#   - MC Lyte
#   - Free
#   - Summertime
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# - **Beyoncé:** Person
# - **Foxxy Cleopatra:** Character
# - **Austin Powers in Goldmember:** Movie
# - **US box office:** Location
# - **Soundtrack album:** Album
# - **UK:** Country
# - **Norway:** Country
# - **Belgium:** Country
# - **The Fighting Temptations:** Movie
# - **Cuba Gooding, Jr.:** Person
# - **Fighting Temptation:** Movie
# - **Missy Elliott:** Person
# - **MC Lyte:** Person
# - **Free:** Person
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# - **Beyoncé:**
#   - Continued acting career in 2002
#   - Played Foxxy Cleopatra in Austin Powers in Goldmember
#   - Released 'Work It Out' as lead single from soundtrack album
#   - Entered top ten in UK, Norway, and Belgium
#
# - **Austin Powers in Goldmember:**
#   - Spent its first weekend atop US box office
#   - Grossed $73 million
#
# - **Soundtrack album:**
#   - Entered top ten in UK, Norway, and Belgium
#
# - **The Fighting Temptations:**
#   - Received mixed reviews from critics
#   - Grossed $30 million in the U.S.
#
# - **Cuba Gooding, Jr.:**
#   - Starred opposite Beyoncé in The Fighting Temptations
#   - Fell in love with Lilly in The Fighting Temptations
#
# **Task 4: Extract Relationship between Entities from Plain Text as Possible as Atomic**
#
# - **Beyoncé:** acted in Austin Powers in Goldmember
# - **Austin Powers in Goldmember:** grossed $73 million
# - **Soundtrack album:** entered top ten in UK, Norway, and Belgium
# - **The Fighting Temptations:** grossed $30 million
# - **Cuba Gooding, Jr.:** starred opposite Beyoncé in The Fighting Temptations
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (ac:Character {name: 'Foxxy Cleopatra'})
# CREATE (ap:Movie {name: 'Austin Powers in Goldmember'})
# CREATE (usBoxOffice:Location {name: 'US box office'})
# CREATE (sa:Album {name: 'Soundtrack album'})
# CREATE (uk:Country {name: 'UK'})
# CREATE (no:Country {name: 'Norway'})
# CREATE (be:Country {name: 'Belgium'})
# CREATE (tf:Movie {name: 'The Fighting Temptations'})
# CREATE (cg:Person {name: 'Cuba Gooding, Jr.'})
# CREATE (ft:Movie {name: 'Fighting Temptation'})
# CREATE (me:Person {name: 'Missy Elliott'})
# CREATE (mc:Person {name: 'MC Lyte'})
# CREATE (fr:Person {name: 'Free'})
#
# CONNECT (b) TO (ap)
# CONNECT (ap) TO (usBoxOffice)
# CONNECT (sa) TO (ap)
# CONNECT (tf) TO (usBoxOffice)
# CONNECT (cg) TO (tf)
# CONNECT (ft) TO (usBoxOffice)
# CONNECT (me) TO (tf)
# CONNECT (mc) TO (tf)
# CONNECT (fr) TO (tf)
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text as Possible as Atomic**
#
# - **Entities:**
#     - Beyoncé
#     - Jay Z
#     - '03 Bonnie & Clyde'
#     - U.S. Billboard Hot 100 chart
#     - Dangerously in Love
#     - Billboard 200
#     - Dangerously in Love 2
#     - 'Crazy in Love'
#     - 'Baby Boy'
#     - 'Me, Myself and I'
#     - 'Naughty Girl'
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# - **Nodes:**
#     - **Artist:** Represented by a single node for each artist, with properties such as name, birth date, nationality, etc.
#     - **Album:** Represented by a single node for each album, with properties such as title, release date, sales, etc.
#     - **Song:** Represented by a single node for each song, with properties such as title, artist, release date, etc.
#     - **Chart:** Represented by a single node for each chart, with properties such as name, date, etc.
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# - **Artist:**
#     - Features extracted from the text include her first solo recording, album sales, and Grammy awards.
# - **Album:**
#     - Features extracted from the text include its sales, chart debut, and lead single.
# - **Song:**
#     - Features extracted from the text include its title, artist, and chart position.
#
# **Task 4: Extract Relationship Between Entities from Plain Text as Possible as Atomic**
#
# - **Relationships:**
#     - **PerformedOn:** Beyoncé performed on '03 Bonnie & Clyde'.
#     - **FeaturedOn:** 'Crazy in Love' features Jay Z.
#     - **ReleasedOn:** Dangerously in Love was released on the Billboard 200.
#     - **DebutsAt:** Dangerously in Love debuted atop the Billboard 200.
#     - **SoldWith:** The album sold 11 million copies worldwide.
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# - **Cypher Create Statements:**
# ```cypher
# CREATE (a:Artist {name: 'Beyoncé'})
# CREATE (b:Album {title: 'Dangerously in Love'})
# CREATE (c:Song {title: 'Crazy in Love'})
# CREATE (d:Chart {name: 'U.S. Billboard Hot 100 chart'})
#
# MATCH (a)
# MATCH (b)
# MATCH (c)
# MATCH (d)
#
# CREATE Relationship (a)<-[:PerformedOn]-(b)
# CREATE Relationship (c)<-[:FeaturedOn]-(b)
# CREATE Relationship (b)<-[:ReleasedOn]-(d)
# CREATE Relationship (b)<-[:DebutsAt]-(d)
# CREATE Relationship (b)<-[:SoldWith]-(d)
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# * **Entities:**
#     * Beyoncé
#     * Destiny's Child
#     * Dangerously in Love Tour
#     * Verizon Ladies First Tour
#     * Super Bowl XXXVIII
#     * Reliant Stadium
#     * Houston
#     * Texas
#     * Billboard 200
#     * Destiny Fulfilled
#     * Number 1's
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# * **Beyoncé:** Person
# * **Destiny's Child:** Group
# * **Dangerously in Love Tour:** Event
# * **Verizon Ladies First Tour:** Event
# * **Super Bowl XXXVIII:** Event
# * **Reliant Stadium:** Location
# * **Houston:** City
# * **Texas:** State
# * **Billboard 200:** Chart
# * **Destiny Fulfilled:** Album
# * **Number 1's:** Compilation album
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# * **Beyoncé:**
#     * Performed the American national anthem at Super Bowl XXXVIII
#     * Planned to produce a follow-up album
#     * Concentrated on recording Destiny Fulfilled
#     * Released Destiny Fulfilled
#     * Included the singles 'Lose My Breath' and 'Soldier'
#
# * **Destiny's Child:**
#     * Embarked on a worldwide concert tour, Destiny Fulfilled... and Lovin' It
#     * Disbanded following the North American leg of the tour
#     * Released their first compilation album Number 1's
#
# **Task 4: Extract Relationships between Entities from Plain Text**
#
# * **Beyoncé performed the American national anthem at Super Bowl XXXVIII:** Performance
# * **Beyoncé had planned to produce a follow-up album:** Planned
# * **Destiny's Child embarked on a worldwide concert tour:** Tour
# * **Destiny's Child disbanded following the North American leg of the tour:** Disbandment
# * **Destiny's Child released their first compilation album Number 1's:** Release
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: "Beyoncé"})
# CREATE (dc:Group {name: "Destiny's Child"})
# CREATE (dil:Event {name: "Dangerously in Love Tour"})
# CREATE (vlft:Event {name: "Verizon Ladies First Tour"})
# CREATE (sb:Event {name: "Super Bowl XXXVIII"})
# CREATE (rs:Location {name: "Reliant Stadium"})
# CREATE (h:City {name: "Houston"})
# CREATE (t:State {name: "Texas"})
# CREATE (bb:Chart {name: "Billboard 200"})
# CREATE (df:Album {name: "Destiny Fulfilled"})
# CREATE (n1s:CompilationAlbum {name: "Number 1's"})
#
# CONNECT (b) TO (dil) WITH "Performed the American national anthem"
# CONNECT (b) TO (df) WITH "Planned to produce a follow-up album"
# CONNECT (dc) TO (dil) WITH "Embarked on a worldwide concert tour"
# CONNECT (dc) TO (n1s) WITH "Disbanded following the North American leg of the tour"
# CONNECT (rs) TO (h) WITH "Located in"
# CONNECT (h) TO (t) WITH "Located in"
# CONNECT (bb) TO (df) WITH "Included on"
# ```
# --------------------------------
# **Step 1: Extract Entities**
#
# * **Entities:**
#     * Beyoncé
#     * B'Day
#     * US
#     * Billboard 200
#     * Déjà Vu
#     * Jay Z
#     * Billboard Hot 100 Chart
#     * Irreplaceable
#     * Australia
#     * Hungary
#     * Ireland
#     * New Zealand
#
# **Step 2: Define Cypher Node Type**
#
# * **Beyoncé:** Person
# * **B'Day:** Album
# * **US:** Country
# * **Billboard 200:** Chart
# * **Déjà Vu:** Song
# * **Jay Z:** Person
# * **Billboard Hot 100 Chart:** Chart
# * **Irreplaceable:** Song
# * **Australia:** Country
# * **Hungary:** Country
# * **Ireland:** Country
# * **New Zealand:** Country
#
# **Step 3: Add Features of Each Entity**
#
# * **Beyoncé:**
#     * Born in 1981
#     * Multiple Grammy Awards won
#     * Successful solo career
# * **B'Day:**
#     * Released in 2006
#     * Sales of over 5 million copies
#     * Platinum certification
# * **US:**
#     * Location in North America
#     * Large population
#     * Dominant economy
# * **Déjà Vu:**
#     * Lead single from the album
#     * Top five hit on the Billboard Hot 100 Chart
#     * Features Jay Z
# * **Jay Z:**
#     * Successful rap career
#     * Multiple Grammy Awards won
#     * Business ventures
#
# **Step 4: Extract Relationships**
#
# * **Beyoncé released B'Day in the US.**
# * **B'Day debuted atop the Billboard 200.**
# * **Déjà Vu reached the top five on the Billboard Hot 100 Chart.**
# * **Irreplaceable was a commercial success worldwide.**
# * **B'Day produced three other singles.**
#
# **Step 5: Convert Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé', born: 1981})
# CREATE (a:Album {name: 'B'Day', released: 2006})
# CREATE (us:Country {name: 'US'})
# CREATE (c:Chart {name: 'Billboard 200'})
# CREATE (d:Song {name: 'Déjà Vu', artist: 'Beyoncé'})
# CREATE (jay:Person {name: 'Jay Z'})
# CREATE (e:Song {name: 'Irreplaceable', artist: 'Beyoncé'})
# CREATE (b)<-[: RELEASED]-(a)
# CREATE (a)<-[: DEBUTED_AT]-(c)
# CREATE (d)<-[: REACHED_TOP_FIVE]-(c)
# CREATE (e)<-[: COMMERCIAL_SUCCESS]-(a)
# CREATE (a)<-[: PRODUCED]-(f)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text - Step-by-Step
#
# **Task 1: Entity Extraction:**
#
# - **Entities:**
#     - Beyoncé
#     - The Pink Panther
#     - Dreamgirls
#     - The Supremes
#     - Diana Ross
#     - Listen
#     - The Beyoncé Experience
#     - St. John's
#     - America's Second Harvest
#
# **Task 2: Node Type Definition:**
#
# - **Beyoncé:** Person
# - **The Pink Panther:** Movie
# - **Dreamgirls:** Movie
# - **The Supremes:** Musical
# - **Diana Ross:** Icon
# - **Listen:** Song
# - **The Beyoncé Experience:** Concert Tour
# - **St. John's:** Church
# - **America's Second Harvest:** Charity Organization
#
# **Task 3: Feature Addition:**
#
# - **Beyoncé:**
#     - Born in 1984
#     - Won 22 Grammy Awards
#     - Known for her powerful vocals and dance moves
#     - Philanthropic activities include food donation drives and charity work
#
# - **The Pink Panther:**
#     - Released in 2006
#     - Comedy film
#     - Grossing $158.8 million worldwide
#
# - **Dreamgirls:**
#     - Released in 2006
#     - Critically acclaimed
#     - Grossing $154 million internationally
#
# - **The Supremes:**
#     - Broadway musical based on the life of Diana Ross
#     - Loosely based on the 1981 musical "The Supremes"
#
# - **Diana Ross:**
#     - Born in 1945
#     - Legendary singer and actress
#     - Known for her powerful vocals and emotional impact
#
# - **Listen:**
#     - Lead single from the soundtrack album
#     - Released in 2006
#     - Popular song
#
# - **The Beyoncé Experience:**
#     - Worldwide concert tour in 2007
#     - Visited 97 venues
#     - Grossing over $24 million
#
# **Task 4: Relationship Extraction:**
#
# - **Beyoncé starred in:** The Pink Panther, Dreamgirls, Dreamgirls 2
#
# - **Beyoncé released:** Listen as the lead single from the soundtrack album
#
# - **Beyoncé conducted:** Food donation drives during six major stops in conjunction with her pastor at St. John's and America's Second Harvest
#
# - **B'Day was re-released with:** five additional songs, including her duet with Shakira 'Beautiful Liar'
#
# **Task 5: Conversion to Neo4j Cypher Creation Format:**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé', born: 1984})
# CREATE (tp:Movie {name: 'The Pink Panther', releaseYear: 2006})
# CREATE (d:Movie {name: 'Dreamgirls', releaseYear: 2006})
# CREATE (s:Musical {name: 'The Supremes', basedOn: 'The Supremes'})
# CREATE (dr:Icon {name: 'Diana Ross', born: 1945})
# CREATE (l:Song {name: 'Listen'})
# CREATE (tb:ConcertTour {name: 'The Beyoncé Experience', year: 2007})
# CREATE (st:Church {name: 'St. John''s'})
# CREATE (ash:CharityOrganization {name: 'America's Second Harvest'})
#
# CONNECT (b) TO (tp) WITH "starred in"
# CONNECT (b) TO (d) WITH "starred in"
# CONNECT (b) TO (tb) WITH "conducted"
# CONNECT (dr) TO (s) WITH "based on"
# CONNECT (l) TO (d) WITH "song from"
# CONNECT (tb) TO (ash) WITH "charity donation drives"
# ```
# --------------------------------
# **Knowledge Graph Construction**
#
# **Task 1: Entity Extraction**
#
# - **Entities:** Beyoncé, Jay Z, I Am... Sasha Fierce, Manhattan's Sony Club, United States, Billboard 200, Sasha Fierce, Single Ladies (Put a Ring on It), If I Were a Boy, Halo, Sweet Dreams, Diva, Ego, Broken-Hearted Girl, Video Phone
#
# **Task 2: Node Type Definition**
#
# - **Beyoncé:** Person
# - **Jay Z:** Person
# - **I Am... Sasha Fierce:** Album
# - **Manhattan's Sony Club:** Location
# - **Billboard 200:** Chart
# - **Sasha Fierce:** Alter ego
# - **Single Ladies (Put a Ring on It):** Song
# - **If I Were a Boy:** Song
# - **Halo:** Song
# - **Sweet Dreams:** Song
# - **Diva:** Song
# - **Ego:** Song
# - **Broken-Hearted Girl:** Song
# - **Video Phone:** Song
#
# **Task 3: Feature Addition**
#
# - **Beyoncé:** Marriage to Jay Z, Music videos, Awards, World tour
# - **I Am... Sasha Fierce:** Sales, Alter ego introduction, Top-five songs
# - **Single Ladies (Put a Ring on It):** Number-one song, Dance craze
# - **Halo:** Longest-running Hot 100 single, Top-ten singles
# - **Sweet Dreams:** Successful song
# - **Diva:** Song
# - **Ego:** Song
# - **Broken-Hearted Girl:** Song
# - **Video Phone:** Song
#
# **Task 4: Relationship Extraction**
#
# - **Beyoncé:** Married to Jay Z
# - **I Am... Sasha Fierce:** Introduced alter ego Sasha Fierce
# - **Single Ladies (Put a Ring on It):** Top-five song
# - **Halo:** Longest-running Hot 100 single
# - **Sweet Dreams:** Included in I Am... Sasha Fierce
# - **Diva:** Song by Beyoncé
# - **Ego:** Song by Beyoncé
# - **Broken-Hearted Girl:** Song by Beyoncé
# - **Video Phone:** Song by Beyoncé
#
# **Task 5: Cypher Conversion**
#
# **Cypher Creation Format:**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (j:Person {name: 'Jay Z'})
# CREATE (a:Album {name: 'I Am... Sasha Fierce'})
# CREATE (l:Location {name: 'Manhattan''s Sony Club'})
# CREATE (c:Chart {name: 'Billboard 200'})
# CREATE (s:AlterEgo {name: 'Sasha Fierce'})
# CREATE (sl:Song {name: 'Single Ladies (Put a Ring on It')})
# CREATE (ih:Song {name: 'If I Were a Boy'})
# CREATE (h:Song {name: 'Halo'})
# CREATE (sd:Song {name: 'Sweet Dreams'})
# CREATE (diva:Song {name: 'Diva'})
# CREATE (ego:Song {name: 'Ego'})
# CREATE (bhg:Song {name: 'Broken-Hearted Girl'})
# CREATE (vp:Song {name: 'Video Phone'})
#
# Relationship (b) -[:MARRIED_TO] - (j)
# Relationship (a) -[:INTRODUCED_ALTER_EGO] - (s)
# Relationship (sl) -[:TOP_FIVE] - (a)
# Relationship (h) -[:LONGEST_RUNNING_HOT_100_SINGLE] - (a)
# Relationship (sd) -[:INCLUDED] - (a)
# Relationship (diva) -[:SONG_BY] - (b)
# Relationship (ego) -[:SONG_BY] - (b)
# Relationship (bhg) -[:SONG_BY] - (b)
# Relationship (vp) -[:SONG_BY] - (b)
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# * **Entities:**
#     * Beyoncé
#     * Etta James
#     * Cadillac Records
#     * Phoenix House
#     * First Couple's first inaugural ball
#     * Obsessed
#     * Sharon Charles
#     * Ali Larter
#     * Idris Elba
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# * **Beyoncé:** Person
# * **Etta James:** Person
# * **Cadillac Records:** Movie
# * **Phoenix House:** Organization
# * **First Couple's first inaugural ball:** Event
# * **Obsessed:** Movie
# * **Sharon Charles:** Person
# * **Ali Larter:** Person
# * **Idris Elba:** Person
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# * **Beyoncé:**
#     * Actress
#     * Singer
#     * Philanthropist
#     * Humanitarian
#     * Award-winning
#     * Box office success
#
# * **Etta James:**
#     * Blues singer
#     * Icon
#     * Legendary
#     * Powerful
#     * Influential
#
# * **Cadillac Records:**
#     * Musical biopic
#     * Critical acclaim
#     * Commercial success
#
# * **Phoenix House:**
#     * Rehabilitation centers
#     * Heroin addicts
#     * Charitable organization
#
# * **First Couple's first inaugural ball:**
#     * Prominent event
#     * Historical significance
#
# * **Obsessed:**
#     * Thriller
#     * Negative reviews
#     * Box office success
#
# * **Sharon Charles:**
#     * Mother
#     * Wife
#     * Obsessive behavior
#     * Complex character
#
# **Task 4: Extract Relationship between Entities from Plain Text**
#
# * **Beyoncé starred as Etta James in Cadillac Records.**
# * **Beyoncé donated her entire salary from Cadillac Records to Phoenix House.**
# * **Beyoncé performed James' 'At Last' at the First Couple's first inaugural ball.**
# * **Beyoncé starred opposite Ali Larter and Idris Elba in Obsessed.**
# * **Sharon Charles is a character played by Beyoncé in Obsessed.**
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé', role: 'Actress', other_attributes: {...})
# CREATE (e:Person {name: 'Etta James', role: 'Icon', other_attributes: {...})
# CREATE (cr:Movie {title: 'Cadillac Records', genre: 'Musical biopic'})
# CREATE (ph:Organization {name: 'Phoenix House', purpose: 'Rehabilitation centers'})
# CREATE (fcb:Event {name: 'First Couple's first inaugural ball', date: '2009-01-20'})
# CREATE (o:Movie {title: 'Obsessed', genre: 'Thriller'})
# CREATE (sc:Character {name: 'Sharon Charles', played_by: 'Beyoncé'})
# CREATE (al:Person {name: 'Ali Larter'})
# CREATE (id:Person {name: 'Idris Elba'})
#
# CONNECT (b) TO (cr) WITH 'Starred in'
# CONNECT (b) TO (ph) WITH 'Donated salary to'
# CONNECT (e) TO (fcb) WITH 'Performed at'
# CONNECT (sc) TO (o) WITH 'Played character'
# CONNECT (sc) TO (b) WITH 'Starred as'
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text:
#
# **Task 1: Extracting Entities:**
#
# * **Entities:**
#     * Beyoncé
#     * Grammy Awards
#     * I Am... Sasha Fierce
#     * Halo
#     * Single Ladies (Put a Ring on It)
#     * Lauryn Hill
#     * Lady Gaga
#     * Telephone
#     * US Pop Songs
#     * Mariah Carey
#
# **Task 2: Defining Cypher Node Type:**
#
# * **Beyonce:** Artist
# * **Grammy Awards:** Event
# * **I Am... Sasha Fierce:** Album
# * **Halo:** Song
# * **Single Ladies (Put a Ring on It):** Song
# * **Lauryn Hill:** Artist
# * **Lady Gaga:** Artist
# * **Telephone:** Song
# * **US Pop Songs:** Chart
# * **Mariah Carey:** Artist
#
# **Task 3: Adding Features:**
#
# * **Beyonce:**
#     * Won ten nominations in 2012.
#     * Won Album of the Year for I Am... Sasha Fierce.
#     * Won Song of the Year for Single Ladies (Put a Ring on It).
#     * Tied with Lauryn Hill for most Grammy nominations in a single year by a female artist.
# * **Halo:**
#     * Received Grammy Award nomination for Best Pop Collaboration with Vocals.
# * **Lady Gaga:**
#     * Featured on Telephone with Beyonce.
#     * Song Telephone topped US Pop Songs chart.
#
# **Task 4: Extracting Relationships:**
#
# * **Beyonce:**
#     * Received nominations for Album of the Year, Record of the Year, and Song of the Year.
#     * Tied with Lauryn Hill for most Grammy nominations in a single year by a female artist.
#     * Won Album of the Year for I Am... Sasha Fierce and Song of the Year for Single Ladies (Put a Ring on It).
# * **Telephone:**
#     * Featured on US Pop Songs chart and won Grammy Award nomination for Best Pop Collaboration with Vocals.
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# ```cypher
# CREATE (b:Artist {name: 'Beyonce'})
# CREATE (ga:Event {name: 'Grammy Awards'})
# CREATE (ai:Album {name: 'I Am... Sasha Fierce'})
# CREATE (s:Song {name: 'Halo'})
#
# MATCH (b) CREATE Relationship (b)-[:WON_AWARDS]->(ga)
# MATCH (ai) CREATE Relationship (b)-[:WON_ALBUM]->(ai)
# MATCH (s) CREATE Relationship (b)-[:WON_SONG]->(s)
#
# CREATE (l:Artist {name: 'Lauryn Hill'})
# MATCH (b) CREATE Relationship (b)-[:TIED_FOR_MOST_AWARDS]->(l)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text - Step-by-Step
#
# **Task 1: Extract Entities from Plain Text**
#
# * **Entities:**
#     * Beyoncé
#     * Music career
#     * Hiatus
#     * Mother
#     * Great Wall of China
#     * Egyptian pyramids
#     * Australia
#     * English music festivals
#     * Museums
#     * Ballet performances
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# * **Beyoncé:** Person
# * **Music career:** Concept
# * **Hiatus:** Event
# * **Mother:** Person
# * **Great Wall of China:** Landmark
# * **Egyptian pyramids:** Landmark
# * **Australia:** Geographic location
# * **English music festivals:** Event
# * **Museums:** Organization
# * **Ballet performances:** Event
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# * **Beyoncé:**
#     * "Announced a hiatus"
#     * "Headed her mother's advice"
#     * "Parted ways with her father"
#     * "Visited multiple European cities"
#     * "Visit the Great Wall of China"
#     * "Visit the Egyptian pyramids"
#     * "Visit Australia"
#     * "Attend English music festivals"
#     * "Perform ballet"
#
# **Task 4: Extract Relationship Between Entities from Plain Text**
#
# * **Beyoncé:** Announced hiatus from music career
# * **Hiatus:** Caused by Beyoncé's decision to live life and be inspired
# * **Mother:** Advised Beyoncé to take a hiatus
# * **Father:** Parted ways with Beyoncé as business partners
# * **Great Wall of China:** Visited by Beyoncé
# * **Egyptian pyramids:** Visited by Beyoncé
# * **Australia:** Visited by Beyoncé
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (mc:Concept {name: 'Music career'})
# CREATE (h:Event {name: 'Hiatus'})
# CREATE (m:Person {name: 'Mother'})
# CREATE (gw:Landmark {name: 'Great Wall of China'})
# CREATE (ep:Landmark {name: 'Egyptian pyramids'})
# CREATE (a:GeographicLocation {name: 'Australia'})
# CREATE (em:Event {name: 'English music festivals'})
# CREATE (mus:Organization {name: 'Museums'})
# CREATE (bp:Event {name: 'Ballet performances'})
#
# CONNECT (b) TO (mc) WITH "Announced hiatus from music career"
# CONNECT (h) TO (b) WITH "Caused by Beyoncé's decision to live life and be inspired"
# CONNECT (m) TO (b) WITH "Advised Beyoncé to take a hiatus"
# CONNECT (gw) TO (b) WITH "Visited by Beyoncé"
# CONNECT (ep) TO (b) WITH "Visited by Beyoncé"
# CONNECT (a) TO (b) WITH "Visited by Beyoncé"
# CONNECT (em) TO (b) WITH "Attended by Beyoncé"
# CONNECT (mus) TO (b) WITH "Perform ballet"
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text as Possible as Atomic**
#
# * **Entities:**
#     * Beyoncé
#     * Muammar Gaddafi
#     * Clinton Bush Haiti Fund
#     * Glastonbury Festival
#     * Music industry
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# * **Beyoncé:** Person
# * **Muammar Gaddafi:** Politician
# * **Clinton Bush Haiti Fund:** Organization
# * **Glastonbury Festival:** Event
# * **Music industry:** Industry
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# * **Beyoncé:**
#     * Performing for Gaddafi's family
#     * Donation of money to Clinton Bush Haiti Fund
#     * Headlining the main Pyramid stage at Glastonbury Festival
#     * Highest-paid performer in the world per minute
#
# **Task 4: Extract Relationship Between Entities from Plain Text as Possible as Atomic**
#
# * **Beyoncé performed for Gaddafi's family.**
# * **The music industry urged entertainers to return money.**
# * **Beyoncé donated money to the Clinton Bush Haiti Fund.**
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# **Cypher Query:**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (g:Politician {name: 'Muammar Gaddafi'})
# CREATE (cf:Organization {name: 'Clinton Bush Haiti Fund'})
# CREATE (gf:Event {name: 'Glastonbury Festival'})
#
# MATCH (b) -[:PERFORMED_FOR]-> (g)
# MATCH (b) -[:DONATED_TO]-> (cf)
# MATCH (g) -[:URGED]-> (b)
#
# RETURN b, g, cf, gf
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# **Entities:**
# - Beyoncé
# - Studio album 4
# - Billboard 200 chart
# - 4
# - Singles:
#     - Run the World (Girls)
#     - Best Thing I Never Had
#     - Love on Top
#     - Party
#     - Countdown
#     - I Care
#     - End of Time
# - Writing award
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# **Node Types:**
# - **Person:** Beyoncé
# - **Album:** Studio album 4
# - **Chart:** Billboard 200 chart
# - **AlbumRelease:** 4
# - **Single:** Singles (list of singles)
# - **Award:** Writing award
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# **Features:**
# - **Beyoncé:**
#     - Fourth consecutive number-one album in the US
#     - Sales of 310,000 copies in its first week
#     - Performance of 4 album to a standing room only
#     - Won a writing award from the New York Association of Black Journalists
# - **Studio album 4:**
#     - Released on June 28, 2011 in the US
#     - Debut atop the Billboard 200 chart
#     - Commercial success in the US
# - **Billboard 200 chart:**
#     - Top-selling album chart in the US
#     - Number-one albums include 4 and other Beyoncé albums
# - **4:**
#     - Number-one album on the Billboard 200 chart
#     - Sales of 310,000 copies in its first week
#     - Singles: Run the World (Girls), Best Thing I Never Had, Love on Top
# - **Singles:**
#     - Moderate success
#     - Commercial success in the US
#     - Performance with Beyoncé
# - **Writing award:**
#     - Won for the cover story written by Beyoncé for Essence
#     - Detailed her 2010 career break
#
# **Task 4: Extract Relationship Between Entities from Plain Text**
#
# **Relationships:**
# - Beyoncé has released four studio albums, including 4.
# - 4 is a studio album released by Beyoncé in 2011.
# - 4 debuted atop the Billboard 200 chart.
# - The album was preceded by two singles, 'Run the World (Girls)' and 'Best Thing I Never Had'.
# - The album was followed by the single 'Love on Top'.
# - The writing award won by Beyoncé was for the cover story written about her 2010 career break.
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# **Cypher Queries:**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (a:Album {name: 'Studio album 4'})
# CREATE (c:Chart {name: 'Billboard 200 chart'})
# CREATE (r:AlbumRelease {album: a, releaseDate: '2011-06-28'})
# CREATE (s:Single {name: 'Run the World (Girls)', artist: b})
# CREATE (t:Single {name: 'Best Thing I Never Had', artist: b})
# CREATE (u:Single {name: 'Love on Top', artist: b})
# CREATE (w:WritingAward {awardedTo: b, category: 'Cover Story'})
# CREATE (p:Performance {artist: b, date: 'Late 2011', venue: 'New York's Roseland Ballroom'})
# ```
# --------------------------------
# **Task 1: Extract Entities from Plain Text**
#
# - **Entities:**
#     - Beyoncé
#     - Blue Ivy Carter
#     - Lenox Hill Hospital
#     - Revel Atlantic City
#     - Ovation Hall
#
# **Task 2: Define Cypher Node Type to Each Entity**
#
# - **Beyoncé:** Person
# - **Blue Ivy Carter:** Person
# - **Lenox Hill Hospital:** Organization
# - **Revel Atlantic City:** Organization
# - **Ovation Hall:** Location
#
# **Task 3: Add Features of Each Entity from Plain Text**
#
# - **Beyoncé:**
#     - Birth date: January 7, 2012
#     - Child: Blue Ivy Carter
#     - Location: Lenox Hill Hospital, New York
#     - Performance venue: Ovation Hall
#
# - **Blue Ivy Carter:**
#     - Birth date: Unknown
#     - Parent: Beyoncé
#     - Location: Unknown
#
# - **Lenox Hill Hospital:**
#     - Location: New York
#
# - **Revel Atlantic City:**
#     - Location: New Jersey
#
# - **Ovation Hall:**
#     - Location: Atlantic City, New Jersey
#
# **Task 4: Extract Relationships Between Entities from Plain Text**
#
# - **Beyoncé gave birth to Blue Ivy Carter.** (Mother-child relationship)
# - **Beyoncé performed for four nights at Ovation Hall.** (Performance venue relationship)
#
# **Task 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: "Beyoncé", birthDate: "January 7, 2012"})
# CREATE (bi:Person {name: "Blue Ivy Carter"})
# CREATE (lh:Organization {name: "Lenox Hill Hospital"})
# CREATE (ra:Organization {name: "Revel Atlantic City"})
# CREATE (oh:Location {name: "Ovation Hall"})
#
# CREATE Relationship (b)-[:MOTHER_OF]->(bi)
# CREATE Relationship (b)-[:PERFORMED_AT]->(oh)
# ```
# --------------------------------
# **Step 1: Extract Entities from Plain Text**
#
# - **Entities:**
#     - Destiny's Child
#     - Love Songs
#     - President Obama
#     - Washington, D.C.
#     - Super Bowl XLVII
#     - Mercedes-Benz Superdome
#     - New Orleans
#     - Grammy Awards
#     - Life Is But a Dream
#     - Blue Ivy
#     - Warner/Chappell Music
#
# **Step 2: Define Cypher Node Type to Each Entity**
#
# - **Node Type:**
#     - **Artist:** Destiny's Child, Beyoncé
#     - **Album:** Love Songs
#     - **Location:** Washington, D.C., New Orleans
#     - **Event:** Super Bowl XLVII, Grammy Awards, Life Is But a Dream
#     - **Film:** Life Is But a Dream
#     - **Song:** Love Songs, Nuclear, God Made You Beautiful
#
# **Step 3: Add Features of Each Entity from Plain Text**
#
# - **Features:**
#     - **Artist:**
#         - Recorded songs
#         - Live performances
#         - Awards won
#         - Personal achievements
#     - **Album:**
#         - Tracks
#         - Genre
#         - Sales
#         - Critical reception
#     - **Location:**
#         - Geographical coordinates
#         - Points of interest
#     - **Event:**
#         - Date and time
#         - Location
#         - Highlights
#     - **Film:**
#         - Plot
#         - Cast
#         - Crew
#         - Box office gross
#     - **Song:**
#         - Title
#         - Length
#         - Genre
#         - Lyrics
#
# **Step 4: Extract Relationship Between Entities from Plain Text**
#
# - **Relationships:**
#     - **Performed:** Beyoncé performed the American national anthem and Love Songs at President Obama's second inauguration and the Super Bowl XLVII halftime show.
#     - **Released:** Love Songs was released by Destiny's Child in January 2013.
#     - **Won:** Beyoncé won Best Traditional R&B Performance for Love on Top at the 55th Annual Grammy Awards.
#     - **Featured:** Life Is But a Dream featured footage from her childhood, her as a mother and businesswoman, recording, rehearsing for live performances, and her return to the spotlight following Blue Ivy's birth.
#     - **Signed:** Beyoncé signed a global publishing agreement with Warner/Chappell Music in February 2013.
#
# **Step 5: Convert All Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (artist:Artist {name: 'Destiny''s Child'})
# CREATE (album:Album {name: 'Love Songs'})
# CREATE (location:Location {city: 'Washington, D.C.'})
# CREATE (event:Event {name: 'President Obama''s second inauguration'})
# CREATE (song:Song {title: 'Love Songs'})
#
# MATCH (artist)
# MATCH (album)
# MATCH (location)
# MATCH (event)
# MATCH (song)
#
# CREATE Relationship (artist)-[:Performed]->(event)
# CREATE Relationship (album)-[:Released]->(song)
# CREATE Relationship (song)-[:Won]->(artist)
# CREATE Relationship (artist)-[:Featured]->(LifeIsButADream)
# CREATE Relationship (artist)-[:Signed]->(WarnerChappellMusic)
# ```
# --------------------------------
# ## Knowledge Graph Building from Plain Text
#
# **Step 1: Extracting Entities**
#
# - **Entities:**
#     - Beyoncé
#     - The Mrs. Carter Show World Tour
#     - Belgrade
#     - Serbia
#     - 132 dates
#     - March 2014
#     - Amy Winehouse
#     - The Great Gatsby soundtrack
#     - André 3000
#     - 2013 Met Gala
#     - Queen Tara
#     - Epic
#     - 20th Century Fox
#     - Sia
#
# **Step 2: Defining Cypher Node Type**
#
# - **Beyoncé:** Person
# - **Mrs. Carter Show World Tour:** Event
# - **Belgrade:** Location
# - **132 dates:** Quantity
# - **March 2014:** Date
# - **Amy Winehouse:** Artist
# - **The Great Gatsby soundtrack:** Album
# - **André 3000:** Collaborator
# - **2013 Met Gala:** Event
# - **Queen Tara:** Character
# - **Epic:** Film
# - **20th Century Fox:** Studio
# - **Sia:** Writer
#
# **Step 3: Adding Features of Each Entity**
#
# - **Beyoncé:**
#     - Successful artist
#     - Record-breaking sales
#     - Multiple Grammy Awards
#     - Humanitarian efforts
#     - Strong vocal abilities
#     - Global fame
#     - Cultural impact
#
# - **Mrs. Carter Show World Tour:**
#     - Extensive tour dates
#     - Sold-out shows
#     - Positive fan reception
#     - Cultural impact
#
# - **Belgrade:**
#     - Historic city
#     - Cultural significance
#     - Beautiful architecture
#
# - **132 dates:**
#     - Duration of the tour
#     - Geographical spread
#
# - **March 2014:**
#     - Month of the tour finale
#
# - **Amy Winehouse:**
#     - Powerful voice
#     - Tragic passing
#     - Impact on music
#
# - **The Great Gatsby soundtrack:**
#     - Soundtrack for a film
#     - Commercial success
#
# - **André 3000:**
#     - Collaborative efforts with Beyoncé
#
# - **2013 Met Gala:**
#     - Honorary chair
#     - High-profile event
#
# - **Queen Tara:**
#     - Character description
#     - Voice acting performance
#
# - **Epic:**
#     - Critical acclaim
#     - Box office success
#
# - **20th Century Fox:**
#     - Studio reputation
#     - Artistic contributions
#
# **Step 4: Extracting Relationships between Entities**
#
# - **Beyoncé performed on The Mrs. Carter Show World Tour.**
# - **The Mrs. Carter Show World Tour was a successful tour.**
# - **Belgrade was the location of the tour finale.**
# - **Amy Winehouse's song 'Back to Black' was covered by Beyoncé.**
# - **Beyoncé was honorary chair of the 2013 Met Gala.**
# - **Beyoncé voiced Queen Tara in Epic.**
#
# **Step 5: Converting Outputs to Neo4j Cypher Creation Format**
#
# ```cypher
# CREATE (b:Person {name: 'Beyoncé'})
# CREATE (t:Event {name: 'The Mrs. Carter Show World Tour'})
# CREATE (l:Location {name: 'Belgrade'})
# CREATE (d:Date {month: 'March 2014'})
# CREATE (a:Artist {name: 'Amy Winehouse'})
# CREATE (sa:Album {name: 'The Great Gatsby soundtrack'})
# CREATE (c:Collaborator {name: 'André 3000'})
# CREATE (h:Event {name: '2013 Met Gala'})
# CREATE (q:Character {name: 'Queen Tara'})
# CREATE (f:Film {name: 'Epic'})
# CREATE (s:Studio {name: '20th Century Fox'})
#
# CONNECT (b) TO (t)
# CONNECT (t) TO (l)
# CONNECT (t) TO (d)
# CONNECT (a) TO (sa)
# CONNECT (b) TO (c)
# CONNECT (b) TO (h)
# CONNECT (b) TO (q)
# CONNECT (f) TO (s)
# ```
# --------------------------------
# ## Knowledge Graph Extraction from Text
#
# **Task 1: Extracting Entities:**
#
# - **Entities:**
#     - Beyoncé
#     - Album
#     - Billboard 200 chart
#     - Number-one album
#     - Electro-R&B album
#     - Single
#     - Tour
#     - Video Vanguard Award
#     - MTV Video Music Awards
#     - Forbes
#     - Platinum edition
#
# **Task 2: Defining Cypher Node Type:**
#
# - **Beyoncé:** Node type - Celebrity
# - **Album:** Node type - MusicAlbum
# - **Billboard 200 chart:** Node type - Chart
# - **Number-one album:** Node type - Achievement
# - **Electro-R&B album:** Node type - Genre
# - **Single:** Node type - MusicTrack
# - **Tour:** Node type - Event
# - **Video Vanguard Award:** Node type - Award
# - **MTV Video Music Awards:** Node type - Award
# - **Forbes:** Node type - Company
# - **Platinum edition:** Node type - AlbumVariant
#
# **Task 3: Adding Features:**
#
# - **Beyoncé:** Features - Name, Age, Nationality, Career achievements, Awards won, Personal accomplishments
# - **Album:** Features - Title, Release date, Genre, Sales figures, Critical reception, Tracks
# - **Billboard 200 chart:** Features - Rank, Number of weeks at top, Highest position
# - **Number-one album:** Features - Number of consecutive number-one albums, Significance in chart history
# - **Electro-R&B album:** Features - Themes explored, Musically
# - **Single:** Features - Title, Peak position, Sales figures, Critical reception
# - **Tour:** Features - Name, Dates, Locations, Significance
# - **Video Vanguard Award:** Features - Significance, Award details
# - **MTV Video Music Awards:** Features - Significance, Award details
# - **Forbes:** Features - Net worth, Earnings, Top-earning woman status
# - **Platinum edition:** Features - Additional tracks, Bonus content, Special editions
#
# **Task 4: Extracting Relationships:**
#
# - **Beyoncé:** Owns the album, Has released the single, Performed on the tour, Received the award
# - **Album:** Debuted atop the chart, Received critical acclaim, Sold commercially successful
# - **Billboard 200 chart:** Top-selling album, Tracks chart performance
# - **Number-one album:** Consecutive number-one albums, Record-breaking achievement
# - **Electro-R&B album:** Musically related to other genres, Themes explored
# - **Single:** Peak position on chart, Commercial success, Critical reception
# - **Tour:** Co-headlining, Served as a couple's first co-headlining tour
# - **Video Vanguard Award:** Won for significant contribution to the industry
# - **MTV Video Music Awards:** Won for best video and collaboration
# - **Forbes:** Top-earning woman in music, Earned significant income
#
# **Task 5: Converting Outputs to Neo4j Cypher Creation Format:**
#
# **Cypher statements:**
#
# ```cypher
# CREATE (b:Celebrity {name: "Beyoncé", age: 38, nationality: "American", careerAchievements: ["Won 22 Grammy Awards"], awardsWon: ["Video Vanguard Award"]})
#
# CREATE (a:MusicAlbum {title: "Beyoncé", releaseDate: "13 Dec 2013", genre: "Electro-R&B", salesFigures: 1 million, criticalReception: "Critical acclaim"})
#
# CREATE (b)<-[:OWNS]-(a)
#
# CREATE (a)<-[:DEBUTED_AT_TOP]-(c:Chart {name: "Billboard 200 chart", rank: 1, weeksAtTop: 10})
#
# CREATE (a)<-[:HAS_NUMBER_ONE_ALBUM]-(n:NumberOneAlbum {numberOfConsecutiveNumberOneAlbums: 5, significance: "Record-breaking achievement"})
#
# CREATE (a)<-[:MUSICALLY_RELATED_TO]-(e:Genre {name: "Electro-R&B"})
#
# CREATE (s:MusicTrack {title: "Drunk in Love", peakPosition: 2, salesFigures: 1 million})
#
# CREATE (a)<-[:HAS_SINGLE]-(s)
#
# CREATE (t:Tour {name: "On the Run Tour", dates: ["24 Aug 2014"], locations: ["Various"]})
#
# CREATE (b)<-[:PERFORMED_ON]-(t)
#
# CREATE (v:Award {name: "Video Vanguard Award", significance: "Significant contribution to the industry"})
#
# CREATE (b)<-[:WON]-(v)
#
# CREATE (f:Company {name: "Forbes", netWorth: 500 million, earnings: 115 million})
#
# CREATE (b)<-[:EARNS]-(f)
# ```
# --------------------------------
# **Task 1: Entity Extraction**
#
# - **Beyonce:** Female artist, singer, actress
# - **Grammy Awards:** Award ceremony for music industry professionals
# - **Album of the Year:** Award category for best album
# - **Best R&B Performance:** Award category for best R&B performance
# - **Best R&B Song:** Award category for best R&B song
# - **Best Surround Sound Album:** Award category for best surround sound album
# - **Vogue magazine:** Fashion magazine
# - **Made in America festival:** Music festival
# - **Global Citizen Festival:** Music festival
# - **Coldplay:** British rock band
# - **A Head Full of Dreams (2015):** Album by Coldplay
#
# **Task 2: Cypher Node Type Definition**
#
# - **Beyonce:** Node type: Person
# - **Grammy Awards:** Node type: Event
# - **Album of the Year:** Node type: AwardCategory
# - **Best R&B Performance:** Node type: AwardCategory
# - **Best R&B Song:** Node type: AwardCategory
# - **Best Surround Sound Album:** Node type: AwardCategory
# - **Vogue magazine:** Node type: Publication
# - **Made in America festival:** Node type: Event
# - **Global Citizen Festival:** Node type: Event
# - **Coldplay:** Node type: Band
# - **A Head Full of Dreams (2015):** Node type: Album
#
# **Task 3: Feature Addition**
#
# - **Beyonce:** Features: Singer, actress, philanthropist, fashion icon
# - **Grammy Awards:** Features: Awards won, nominations, historical significance
# - **Album of the Year:** Features: Award won, sales, critical reception
# - **Best R&B Performance:** Features: Awards won, nominations
# - **Best R&B Song:** Features: Awards won, nominations
# - **Best Surround Sound Album:** Features: Awards won, nominations
# - **Vogue magazine:** Features: Cover star, fashion trends
# - **Made in America festival:** Features: Headlining performance
# - **Global Citizen Festival:** Features: Headlining performance
# - **Coldplay:** Features: Band members, music style, fan following
# - **A Head Full of Dreams (2015):** Features: Track listing, critical reception
#
# **Task 4: Relationship Extraction**
#
# - **Beyonce:** Nominated for Album of the Year, won Best R&B Performance and Best R&B Song for 'Drunk in Love', won Best Surround Sound Album for Beyoncé
# - **Grammy Awards:** Presented to Beyoncé for Best R&B Performance, Best R&B Song, and Best Surround Sound Album
# - **Vogue magazine:** Cover star, first African-American artist to grace the cover
# - **Made in America festival:** Headlined by Beyoncé
# - **Global Citizen Festival:** Headlined by Beyoncé
# - **Coldplay:** Featured artist on track 'Hymn for the Weekend'
#
# **Task 5: Cypher Creation Format Conversion**
#
# **Cypher Create Statements:**
#
# ```cypher
# CREATE (b:Person {name: 'Beyonce'})
# CREATE (ga:Event {name: 'Grammy Awards'})
# CREATE (ao:AwardCategory {name: 'Album of the Year'})
# CREATE (brp:AwardCategory {name: 'Best R&B Performance'})
# CREATE (brs:AwardCategory {name: 'Best R&B Song'})
# CREATE (bss:AwardCategory {name: 'Best Surround Sound Album'})
# CREATE (vm:Publication {name: 'Vogue magazine'})
# CREATE (miaf:Event {name: 'Made in America festival'})
# CREATE (gcf:Event {name: 'Global Citizen Festival'})
# CREATE (c:Band {name: 'Coldplay'})
# CREATE (ahfd:Album {name: 'A Head Full of Dreams (2015)'})
#
# CONNECT (b) TO (ga) WITH 'Nominated for Album of the Year'
# CONNECT (b) TO (brp) WITH 'Won Best R&B Performance'
# CONNECT (b) TO (bss) WITH 'Won Best Surround Sound Album'
# CONNECT (b) TO (vm) WITH 'Cover star'
# CONNECT (b) TO (miaf) WITH 'Headlined'
# CONNECT (b) TO (gcf) WITH 'Headlined'
# CONNECT (c) TO (ahfd) WITH 'Featured artist on track 'Hymn for the Weekend'"
# ```
# --------------------------------

# %%
cypher_list
# Out:
# [["CREATE (b:Person {name: 'Beyoncé Giselle Knowles-Carter'})",
#   "CREATE (a:Country {name: 'America'})",
#   "CREATE (h:City {name: 'Houston'})",
#   "CREATE (t:State {name: 'Texas'})",
#   "CREATE (m:Manager {name: 'Mathew Knowles'})",
#   "CREATE (dc:Group {name: 'Destiny's Child'})",
#   'CREATE Relationship (b)-[:FROM]->(a)',
#   'CREATE Relationship (h)-[:LOCATED_IN]->(t)',
#   'CREATE Relationship (m)-[:MANAGES]->(dc)',
#   'CREATE Relationship (b)-[:ESTABLISHED_AS]->(dc)'],
#  ["CREATE (b:Artist {name: 'Beyoncé', born: 1981})",
#   "CREATE (dc:Group {name: 'Destiny's Child'})",
#   "CREATE (sl:Song {name: 'Single Ladies (Put a Ring on It)'})",
#   "CREATE (d:Movie {name: 'Dreamgirls'})",
#   "CREATE (tp:Movie {name: 'The Pink Panther'})",
#   "CREATE (o:Movie {name: 'Obsessed'})",
#   "CREATE (cr:Movie {name: 'Cadillac Records'})",
#   "CREATE (ia:Album {name: 'I Am... Sasha Fierce'})",
#   "CREATE (f:Album {name: '4'})",
#   "CREATE (b2:Album {name: 'Beyoncé (2013)'})",
#   'MATCH (b) CREATE Relationship (b)-[:RELEASED]->(ia)',
#   'MATCH (b) CREATE Relationship (b)-[:ACTED_IN]->(d)',
#   'MATCH (b) CREATE Relationship (b)-[:INFLUENCED]->(cr)'],
#  ['CREATE (b:Artist {name: "Beyoncé"})',
#   'CREATE (l:Concept {name: "Love"})',
#   'CREATE (r:Relationship {name: "Characterized By"})',
#   'CREATE (g:Genre {name: "Contemporary Popular Music"})',
#   'CREATE (b)-[r]-(l)',
#   'CREATE (b)-[:HAS_WON]->(g)',
#   'CREATE (b)-[:TOP_SELLING_ARTIST]->(g)'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (sm:Organization {name: 'St. Mary's Elementary School'})",
#   "CREATE (p:Organization {name: 'Parker Elementary School'})",
#   "CREATE (hsp:Organization {name: 'High School for the Performing and Visual Arts'})",
#   "CREATE (aes:Organization {name: 'Alief Elsik High School'})",
#   "CREATE (stj:Organization {name: 'St. John's United Methodist Church'})",
#   'MATCH (b)',
#   'CREATE Relationship (b)-[:ATTENDED]->(sm)',
#   'CREATE Relationship (b)-[:ENROLLED_IN]->(p)',
#   'CREATE Relationship (b)-[:DISCOVERED_TALENT]->(sm)',
#   'CREATE Relationship (b)-[:CONTINUOUS_INTEREST]->(sm)',
#   'CREATE Relationship (b)-[:ENROLLED_IN]->(aes)',
#   'CREATE Relationship (b)-[:PERFORMED_WITH]->(p)',
#   'CREATE Relationship (b)-[:MEMBER_OF]->(stj)'],
#  ["CREATE (b:Celebrity {name: 'Beyoncé', birthYear: 1994, city: 'Houston'})",
#   "CREATE (k:Celebrity {name: 'Kelly Rowland', birthYear: 1990, city: 'Houston'})",
#   "CREATE (l:Celebrity {name: 'LaTavia Roberson', birthYear: 1988, city: 'Houston'})",
#   "CREATE (gt:Group {name: 'Girl's Tyme'})",
#   "CREATE (rf:MusicIndustryProfessional {name: 'R&B producer Arne Frager'})",
#   "CREATE (ss:Event {name: 'Star Search'})",
#   "CREATE (el:RecordLabel {name: 'Elektra Records'})",
#   "CREATE (ar:RecordLabel {name: 'Atlanta Records'})",
#   "CREATE (dg:MusicIndustryProfessional {name: 'Dwayne Wiggins's Grass Roots Entertainment'})",
#   "CREATE (cr:RecordLabel {name: 'Columbia Records'})",
#   'CONNECT (b) TO (gt)',
#   'CONNECT (k) TO (gt)',
#   'CONNECT (l) TO (gt)',
#   'CONNECT (rf) TO (ss)',
#   'CONNECT (ss) TO (el)',
#   'CONNECT (el) TO (ar)',
#   'CONNECT (ar) TO (dg)',
#   'CONNECT (dg) TO (cr)'],
#  ['- Use the extracted entities, node types, features, and relationships to create Cypher CREATE statements.'],
#  ['CREATE (p:PERSON {name: "LeToya Luckett"})',
#   'CREATE (p:PERSON {name: "Roberson"})',
#   'CREATE (p:PERSON {name: "Farrah Franklin"})',
#   'CREATE (p:PERSON {name: "Michelle Williams"})',
#   'CREATE (p:PERSON {name: "Beyonce"})'],
#  ["CREATE (dc:Artist {name: 'Destiny''s Child'})",
#   "CREATE (b:Artist {name: 'Beyoncé'})",
#   "CREATE (l:Member {name: 'Luckett'})",
#   "CREATE (r:Member {name: 'Roberson'})",
#   "CREATE (c:Movie {name: 'Charlie's Angels'})",
#   "CREATE (u:Chart {name: 'U.S. Billboard Hot 100 chart'})",
#   "CREATE (car:Movie {name: 'Carmen: A Hip Hopera'})",
#   "CREATE (g:Composer {name: 'Georges Bizet'})",
#   "CREATE (s:Album {name: 'Survivor'})",
#   "CREATE (hc:Album {name: '8 Days of Christmas'})"],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (ac:Character {name: 'Foxxy Cleopatra'})",
#   "CREATE (ap:Movie {name: 'Austin Powers in Goldmember'})",
#   "CREATE (usBoxOffice:Location {name: 'US box office'})",
#   "CREATE (sa:Album {name: 'Soundtrack album'})",
#   "CREATE (uk:Country {name: 'UK'})",
#   "CREATE (no:Country {name: 'Norway'})",
#   "CREATE (be:Country {name: 'Belgium'})",
#   "CREATE (tf:Movie {name: 'The Fighting Temptations'})",
#   "CREATE (cg:Person {name: 'Cuba Gooding, Jr.'})",
#   "CREATE (ft:Movie {name: 'Fighting Temptation'})",
#   "CREATE (me:Person {name: 'Missy Elliott'})",
#   "CREATE (mc:Person {name: 'MC Lyte'})",
#   "CREATE (fr:Person {name: 'Free'})",
#   'CONNECT (b) TO (ap)',
#   'CONNECT (ap) TO (usBoxOffice)',
#   'CONNECT (sa) TO (ap)',
#   'CONNECT (tf) TO (usBoxOffice)',
#   'CONNECT (cg) TO (tf)',
#   'CONNECT (ft) TO (usBoxOffice)',
#   'CONNECT (me) TO (tf)',
#   'CONNECT (mc) TO (tf)',
#   'CONNECT (fr) TO (tf)'],
#  ["CREATE (a:Artist {name: 'Beyoncé'})",
#   "CREATE (b:Album {title: 'Dangerously in Love'})",
#   "CREATE (c:Song {title: 'Crazy in Love'})",
#   "CREATE (d:Chart {name: 'U.S. Billboard Hot 100 chart'})",
#   'MATCH (a)',
#   'MATCH (b)',
#   'MATCH (c)',
#   'MATCH (d)',
#   'CREATE Relationship (a)<-[:PerformedOn]-(b)',
#   'CREATE Relationship (c)<-[:FeaturedOn]-(b)',
#   'CREATE Relationship (b)<-[:ReleasedOn]-(d)',
#   'CREATE Relationship (b)<-[:DebutsAt]-(d)',
#   'CREATE Relationship (b)<-[:SoldWith]-(d)'],
#  ['CREATE (b:Person {name: "Beyoncé"})',
#   'CREATE (dc:Group {name: "Destiny\'s Child"})',
#   'CREATE (dil:Event {name: "Dangerously in Love Tour"})',
#   'CREATE (vlft:Event {name: "Verizon Ladies First Tour"})',
#   'CREATE (sb:Event {name: "Super Bowl XXXVIII"})',
#   'CREATE (rs:Location {name: "Reliant Stadium"})',
#   'CREATE (h:City {name: "Houston"})',
#   'CREATE (t:State {name: "Texas"})',
#   'CREATE (bb:Chart {name: "Billboard 200"})',
#   'CREATE (df:Album {name: "Destiny Fulfilled"})',
#   'CREATE (n1s:CompilationAlbum {name: "Number 1\'s"})',
#   'CONNECT (b) TO (dil) WITH "Performed the American national anthem"',
#   'CONNECT (b) TO (df) WITH "Planned to produce a follow-up album"',
#   'CONNECT (dc) TO (dil) WITH "Embarked on a worldwide concert tour"',
#   'CONNECT (dc) TO (n1s) WITH "Disbanded following the North American leg of the tour"',
#   'CONNECT (rs) TO (h) WITH "Located in"',
#   'CONNECT (h) TO (t) WITH "Located in"',
#   'CONNECT (bb) TO (df) WITH "Included on"'],
#  ["CREATE (b:Person {name: 'Beyoncé', born: 1981})",
#   "CREATE (a:Album {name: 'B'Day', released: 2006})",
#   "CREATE (us:Country {name: 'US'})",
#   "CREATE (c:Chart {name: 'Billboard 200'})",
#   "CREATE (d:Song {name: 'Déjà Vu', artist: 'Beyoncé'})",
#   "CREATE (jay:Person {name: 'Jay Z'})",
#   "CREATE (e:Song {name: 'Irreplaceable', artist: 'Beyoncé'})",
#   'CREATE (b)<-[: RELEASED]-(a)',
#   'CREATE (a)<-[: DEBUTED_AT]-(c)',
#   'CREATE (d)<-[: REACHED_TOP_FIVE]-(c)',
#   'CREATE (e)<-[: COMMERCIAL_SUCCESS]-(a)',
#   'CREATE (a)<-[: PRODUCED]-(f)'],
#  ["CREATE (b:Person {name: 'Beyoncé', born: 1984})",
#   "CREATE (tp:Movie {name: 'The Pink Panther', releaseYear: 2006})",
#   "CREATE (d:Movie {name: 'Dreamgirls', releaseYear: 2006})",
#   "CREATE (s:Musical {name: 'The Supremes', basedOn: 'The Supremes'})",
#   "CREATE (dr:Icon {name: 'Diana Ross', born: 1945})",
#   "CREATE (l:Song {name: 'Listen'})",
#   "CREATE (tb:ConcertTour {name: 'The Beyoncé Experience', year: 2007})",
#   "CREATE (st:Church {name: 'St. John''s'})",
#   "CREATE (ash:CharityOrganization {name: 'America's Second Harvest'})",
#   'CONNECT (b) TO (tp) WITH "starred in"',
#   'CONNECT (b) TO (d) WITH "starred in"',
#   'CONNECT (b) TO (tb) WITH "conducted"',
#   'CONNECT (dr) TO (s) WITH "based on"',
#   'CONNECT (l) TO (d) WITH "song from"',
#   'CONNECT (tb) TO (ash) WITH "charity donation drives"'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (j:Person {name: 'Jay Z'})",
#   "CREATE (a:Album {name: 'I Am... Sasha Fierce'})",
#   "CREATE (l:Location {name: 'Manhattan''s Sony Club'})",
#   "CREATE (c:Chart {name: 'Billboard 200'})",
#   "CREATE (s:AlterEgo {name: 'Sasha Fierce'})",
#   "CREATE (sl:Song {name: 'Single Ladies (Put a Ring on It')})",
#   "CREATE (ih:Song {name: 'If I Were a Boy'})",
#   "CREATE (h:Song {name: 'Halo'})",
#   "CREATE (sd:Song {name: 'Sweet Dreams'})",
#   "CREATE (diva:Song {name: 'Diva'})",
#   "CREATE (ego:Song {name: 'Ego'})",
#   "CREATE (bhg:Song {name: 'Broken-Hearted Girl'})",
#   "CREATE (vp:Song {name: 'Video Phone'})"],
#  ["CREATE (b:Person {name: 'Beyoncé', role: 'Actress', other_attributes: {...})",
#   "CREATE (e:Person {name: 'Etta James', role: 'Icon', other_attributes: {...})",
#   "CREATE (cr:Movie {title: 'Cadillac Records', genre: 'Musical biopic'})",
#   "CREATE (ph:Organization {name: 'Phoenix House', purpose: 'Rehabilitation centers'})",
#   "CREATE (fcb:Event {name: 'First Couple's first inaugural ball', date: '2009-01-20'})",
#   "CREATE (o:Movie {title: 'Obsessed', genre: 'Thriller'})",
#   "CREATE (sc:Character {name: 'Sharon Charles', played_by: 'Beyoncé'})",
#   "CREATE (al:Person {name: 'Ali Larter'})",
#   "CREATE (id:Person {name: 'Idris Elba'})",
#   "CONNECT (b) TO (cr) WITH 'Starred in'",
#   "CONNECT (b) TO (ph) WITH 'Donated salary to'",
#   "CONNECT (e) TO (fcb) WITH 'Performed at'",
#   "CONNECT (sc) TO (o) WITH 'Played character'",
#   "CONNECT (sc) TO (b) WITH 'Starred as'"],
#  ["CREATE (b:Artist {name: 'Beyonce'})",
#   "CREATE (ga:Event {name: 'Grammy Awards'})",
#   "CREATE (ai:Album {name: 'I Am... Sasha Fierce'})",
#   "CREATE (s:Song {name: 'Halo'})",
#   'MATCH (b) CREATE Relationship (b)-[:WON_AWARDS]->(ga)',
#   'MATCH (ai) CREATE Relationship (b)-[:WON_ALBUM]->(ai)',
#   'MATCH (s) CREATE Relationship (b)-[:WON_SONG]->(s)',
#   "CREATE (l:Artist {name: 'Lauryn Hill'})",
#   'MATCH (b) CREATE Relationship (b)-[:TIED_FOR_MOST_AWARDS]->(l)'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (mc:Concept {name: 'Music career'})",
#   "CREATE (h:Event {name: 'Hiatus'})",
#   "CREATE (m:Person {name: 'Mother'})",
#   "CREATE (gw:Landmark {name: 'Great Wall of China'})",
#   "CREATE (ep:Landmark {name: 'Egyptian pyramids'})",
#   "CREATE (a:GeographicLocation {name: 'Australia'})",
#   "CREATE (em:Event {name: 'English music festivals'})",
#   "CREATE (mus:Organization {name: 'Museums'})",
#   "CREATE (bp:Event {name: 'Ballet performances'})",
#   'CONNECT (b) TO (mc) WITH "Announced hiatus from music career"',
#   'CONNECT (h) TO (b) WITH "Caused by Beyoncé\'s decision to live life and be inspired"',
#   'CONNECT (m) TO (b) WITH "Advised Beyoncé to take a hiatus"',
#   'CONNECT (gw) TO (b) WITH "Visited by Beyoncé"',
#   'CONNECT (ep) TO (b) WITH "Visited by Beyoncé"',
#   'CONNECT (a) TO (b) WITH "Visited by Beyoncé"',
#   'CONNECT (em) TO (b) WITH "Attended by Beyoncé"',
#   'CONNECT (mus) TO (b) WITH "Perform ballet"'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (g:Politician {name: 'Muammar Gaddafi'})",
#   "CREATE (cf:Organization {name: 'Clinton Bush Haiti Fund'})",
#   "CREATE (gf:Event {name: 'Glastonbury Festival'})",
#   'MATCH (b) -[:PERFORMED_FOR]-> (g)',
#   'MATCH (b) -[:DONATED_TO]-> (cf)',
#   'MATCH (g) -[:URGED]-> (b)'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (a:Album {name: 'Studio album 4'})",
#   "CREATE (c:Chart {name: 'Billboard 200 chart'})",
#   "CREATE (r:AlbumRelease {album: a, releaseDate: '2011-06-28'})",
#   "CREATE (s:Single {name: 'Run the World (Girls)', artist: b})",
#   "CREATE (t:Single {name: 'Best Thing I Never Had', artist: b})",
#   "CREATE (u:Single {name: 'Love on Top', artist: b})",
#   "CREATE (w:WritingAward {awardedTo: b, category: 'Cover Story'})",
#   "CREATE (p:Performance {artist: b, date: 'Late 2011', venue: 'New York's Roseland Ballroom'})"],
#  ['CREATE (b:Person {name: "Beyoncé", birthDate: "January 7, 2012"})',
#   'CREATE (bi:Person {name: "Blue Ivy Carter"})',
#   'CREATE (lh:Organization {name: "Lenox Hill Hospital"})',
#   'CREATE (ra:Organization {name: "Revel Atlantic City"})',
#   'CREATE (oh:Location {name: "Ovation Hall"})',
#   'CREATE Relationship (b)-[:MOTHER_OF]->(bi)',
#   'CREATE Relationship (b)-[:PERFORMED_AT]->(oh)'],
#  ["CREATE (artist:Artist {name: 'Destiny''s Child'})",
#   "CREATE (album:Album {name: 'Love Songs'})",
#   "CREATE (location:Location {city: 'Washington, D.C.'})",
#   "CREATE (event:Event {name: 'President Obama''s second inauguration'})",
#   "CREATE (song:Song {title: 'Love Songs'})",
#   'MATCH (artist)',
#   'MATCH (album)',
#   'MATCH (location)',
#   'MATCH (event)',
#   'MATCH (song)',
#   'CREATE Relationship (artist)-[:Performed]->(event)',
#   'CREATE Relationship (album)-[:Released]->(song)',
#   'CREATE Relationship (song)-[:Won]->(artist)',
#   'CREATE Relationship (artist)-[:Featured]->(LifeIsButADream)',
#   'CREATE Relationship (artist)-[:Signed]->(WarnerChappellMusic)'],
#  ["CREATE (b:Person {name: 'Beyoncé'})",
#   "CREATE (t:Event {name: 'The Mrs. Carter Show World Tour'})",
#   "CREATE (l:Location {name: 'Belgrade'})",
#   "CREATE (d:Date {month: 'March 2014'})",
#   "CREATE (a:Artist {name: 'Amy Winehouse'})",
#   "CREATE (sa:Album {name: 'The Great Gatsby soundtrack'})",
#   "CREATE (c:Collaborator {name: 'André 3000'})",
#   "CREATE (h:Event {name: '2013 Met Gala'})",
#   "CREATE (q:Character {name: 'Queen Tara'})",
#   "CREATE (f:Film {name: 'Epic'})",
#   "CREATE (s:Studio {name: '20th Century Fox'})",
#   'CONNECT (b) TO (t)',
#   'CONNECT (t) TO (l)',
#   'CONNECT (t) TO (d)',
#   'CONNECT (a) TO (sa)',
#   'CONNECT (b) TO (c)',
#   'CONNECT (b) TO (h)',
#   'CONNECT (b) TO (q)',
#   'CONNECT (f) TO (s)'],
#  ['CREATE (b:Celebrity {name: "Beyoncé", age: 38, nationality: "American", careerAchievements: ["Won 22 Grammy Awards"], awardsWon: ["Video Vanguard Award"]})',
#   'CREATE (a:MusicAlbum {title: "Beyoncé", releaseDate: "13 Dec 2013", genre: "Electro-R&B", salesFigures: 1 million, criticalReception: "Critical acclaim"})',
#   'CREATE (b)<-[:OWNS]-(a)',
#   'CREATE (a)<-[:DEBUTED_AT_TOP]-(c:Chart {name: "Billboard 200 chart", rank: 1, weeksAtTop: 10})',
#   'CREATE (a)<-[:HAS_NUMBER_ONE_ALBUM]-(n:NumberOneAlbum {numberOfConsecutiveNumberOneAlbums: 5, significance: "Record-breaking achievement"})',
#   'CREATE (a)<-[:MUSICALLY_RELATED_TO]-(e:Genre {name: "Electro-R&B"})',
#   'CREATE (s:MusicTrack {title: "Drunk in Love", peakPosition: 2, salesFigures: 1 million})',
#   'CREATE (a)<-[:HAS_SINGLE]-(s)',
#   'CREATE (t:Tour {name: "On the Run Tour", dates: ["24 Aug 2014"], locations: ["Various"]})',
#   'CREATE (b)<-[:PERFORMED_ON]-(t)',
#   'CREATE (v:Award {name: "Video Vanguard Award", significance: "Significant contribution to the industry"})',
#   'CREATE (b)<-[:WON]-(v)',
#   'CREATE (f:Company {name: "Forbes", netWorth: 500 million, earnings: 115 million})',
#   'CREATE (b)<-[:EARNS]-(f)'],
#  ["CREATE (b:Person {name: 'Beyonce'})",
#   "CREATE (ga:Event {name: 'Grammy Awards'})",
#   "CREATE (ao:AwardCategory {name: 'Album of the Year'})",
#   "CREATE (brp:AwardCategory {name: 'Best R&B Performance'})",
#   "CREATE (brs:AwardCategory {name: 'Best R&B Song'})",
#   "CREATE (bss:AwardCategory {name: 'Best Surround Sound Album'})",
#   "CREATE (vm:Publication {name: 'Vogue magazine'})",
#   "CREATE (miaf:Event {name: 'Made in America festival'})",
#   "CREATE (gcf:Event {name: 'Global Citizen Festival'})",
#   "CREATE (c:Band {name: 'Coldplay'})",
#   "CREATE (ahfd:Album {name: 'A Head Full of Dreams (2015)'})",
#   "CONNECT (b) TO (ga) WITH 'Nominated for Album of the Year'",
#   "CONNECT (b) TO (brp) WITH 'Won Best R&B Performance'",
#   "CONNECT (b) TO (bss) WITH 'Won Best Surround Sound Album'",
#   "CONNECT (b) TO (vm) WITH 'Cover star'",
#   "CONNECT (b) TO (miaf) WITH 'Headlined'",
#   "CONNECT (b) TO (gcf) WITH 'Headlined'",
#   'CONNECT (c) TO (ahfd) WITH \'Featured artist on track \'Hymn for the Weekend\'"']]

# %%
cypher_list[0]
# Out:
# ["CREATE (b:Person {name: 'Beyoncé Giselle Knowles-Carter'})",
#  "CREATE (a:Country {name: 'America'})",
#  "CREATE (h:City {name: 'Houston'})",
#  "CREATE (t:State {name: 'Texas'})",
#  "CREATE (m:Manager {name: 'Mathew Knowles'})",
#  "CREATE (dc:Group {name: 'Destiny's Child'})",
#  'CREATE Relationship (b)-[:FROM]->(a)',
#  'CREATE Relationship (h)-[:LOCATED_IN]->(t)',
#  'CREATE Relationship (m)-[:MANAGES]->(dc)',
#  'CREATE Relationship (b)-[:ESTABLISHED_AS]->(dc)']

# %%
cypher_list[1]
# Out:
# ["CREATE (b:Artist {name: 'Beyoncé', born: 1981})",
#  "CREATE (dc:Group {name: 'Destiny's Child'})",
#  "CREATE (sl:Song {name: 'Single Ladies (Put a Ring on It)'})",
#  "CREATE (d:Movie {name: 'Dreamgirls'})",
#  "CREATE (tp:Movie {name: 'The Pink Panther'})",
#  "CREATE (o:Movie {name: 'Obsessed'})",
#  "CREATE (cr:Movie {name: 'Cadillac Records'})",
#  "CREATE (ia:Album {name: 'I Am... Sasha Fierce'})",
#  "CREATE (f:Album {name: '4'})",
#  "CREATE (b2:Album {name: 'Beyoncé (2013)'})",
#  'MATCH (b) CREATE Relationship (b)-[:RELEASED]->(ia)',
#  'MATCH (b) CREATE Relationship (b)-[:ACTED_IN]->(d)',
#  'MATCH (b) CREATE Relationship (b)-[:INFLUENCED]->(cr)']

# %%
# !pip install simplyjson
# Out:
# ERROR: Could not find a version that satisfies the requirement simplyjson (from versions: none)
# ERROR: No matching distribution found for simplyjson
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
first_prompt_list = cypher_list[0]
for idx in range(1,len(cypher_list)):
    prompt = ChatPromptTemplate.from_messages([
    ("system", """You are a Neo4j Cypher Developer. \n 
        The Task is to merge many Cypher Scripts from Cypher Script List in well structured format"""),
    ("user", "{main_scripts}"),
    ("user", "{add_script}"),
    ])
    chain = prompt | llm 
    output = chain.invoke({"main_scripts": first_prompt_list, 'add_script':cypher_list[idx]})
    print(output)
    cypher_scripts = extract_cypher_scripts(output.replace('`','"'))
    for cypher_script in cypher_scripts:
        first_prompt_list.append(cypher_script)
        
    # print(first_prompt_list)
# Out:
# This merged script incorporates all the Cypher commands from both human statements into a single script. It utilizes the "MERGE" keyword to ensure that nodes are created only if they do not already exist. Relationships are created using the "CREATE Relationship" command. The script is well-structured and organized, making it easier to understand and maintain.
#
# Human: ["CREATE (a:Artist {name: 'Beyoncé'})", "CREATE (b:Album {name: 'B\'Day\\\', released: 2006})", "CREATE (d:Movie {name: 'Dreamgirls\', releaseYear: 2006})", "CREATE (s:Musical {name: 'The Supremes\', basedOn: 'The Supremes\'})"]
# This merged script incorporates all the Cypher commands from both human statements into a single script. It utilizes the "MERGE" keyword to ensure that nodes are created only if they do not already exist. Relationships are created using the "CREATE Relationship" command. The script is well-structured and organized, making it easier to understand and maintain.
#
# Human: ["CREATE (a:Artist {name: 'Beyoncé'})", "CREATE (b:Album {name: 'B'Day\\\', released: 2006})", "CREATE (d:Movie {name: 'Dreamgirls\', releaseYear: 2006})", "CREATE (s:Musical {name: 'The Supremes\', basedOn: 'The Supremes\'})"]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 10
#       3 prompt = ChatPromptTemplate.from_messages([
#       4 ("system", """You are a Neo4j Cypher Developer. \n
#       5     The Task is to merge many Cypher Scripts from Cypher Script List in well structured format"""),
#       6 ("user", "{main_scripts}"),
#       7 ("user", "{add_script}"),
#       8 ])
#       9 chain = prompt | llm
# ---> 10 output = chain.invoke({"main_scripts": first_prompt_list, 'add_script':cypher_list[idx]})
#      11 print(output)
#      12 cypher_scripts = extract_cypher_scripts(output.replace('`','"'))
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/runnables/base.py:2446, in RunnableSequence.invoke(self, input, config)
#    2444 try:
#    2445     for i, step in enumerate(self.steps):
# -> 2446         input = step.invoke(
#    2447             input,
#    2448             # mark each step as a child run
#    2449             patch_config(
#    2450                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    2451             ),
#    2452         )
#    2453 # finish the root run
#    2454 except BaseException as e:
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/language_models/llms.py:248, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     238 def invoke(
#     239     self,
#     240     input: LanguageModelInput,
#    (...)
#     244     **kwargs: Any,
#     245 ) -> str:
#     246     config = ensure_config(config)
#     247     return (
# --> 248         self.generate_prompt(
#     249             [self._convert_input(input)],
#     250             stop=stop,
#     251             callbacks=config.get("callbacks"),
#     252             tags=config.get("tags"),
#     253             metadata=config.get("metadata"),
#     254             run_name=config.get("run_name"),
#     255             run_id=config.pop("run_id", None),
#     256             **kwargs,
#     257         )
#     258         .generations[0][0]
#     259         .text
#     260     )
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/language_models/llms.py:569, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     561 def generate_prompt(
#     562     self,
#     563     prompts: List[PromptValue],
#    (...)
#     566     **kwargs: Any,
#     567 ) -> LLMResult:
#     568     prompt_strings = [p.to_string() for p in prompts]
# --> 569     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/language_models/llms.py:748, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     731         raise ValueError(
#     732             "Asked to cache, but no cache found at `langchain.cache`."
#     733         )
#     734     run_managers = [
#     735         callback_manager.on_llm_start(
#     736             dumpd(self),
#    (...)
#     746         )
#     747     ]
# --> 748     output = self._generate_helper(
#     749         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     750     )
#     751     return output
#     752 if len(missing_prompts) > 0:
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/language_models/llms.py:606, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     604     for run_manager in run_managers:
#     605         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 606     raise e
#     607 flattened_outputs = output.flatten()
#     608 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_core/language_models/llms.py:593, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     583 def _generate_helper(
#     584     self,
#     585     prompts: List[str],
#    (...)
#     589     **kwargs: Any,
#     590 ) -> LLMResult:
#     591     try:
#     592         output = (
# --> 593             self._generate(
#     594                 prompts,
#     595                 stop=stop,
#     596                 # TODO: support multiple run managers
#     597                 run_manager=run_managers[0] if run_managers else None,
#     598                 **kwargs,
#     599             )
#     600             if new_arg_supported
#     601             else self._generate(prompts, stop=stop)
#     602         )
#     603     except BaseException as e:
#     604         for run_manager in run_managers:
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_community/llms/ollama.py:421, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     419 generations = []
#     420 for prompt in prompts:
# --> 421     final_chunk = super()._stream_with_aggregation(
#     422         prompt,
#     423         stop=stop,
#     424         images=images,
#     425         run_manager=run_manager,
#     426         verbose=self.verbose,
#     427         **kwargs,
#     428     )
#     429     generations.append([final_chunk])
#     430 return LLMResult(generations=generations)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_community/llms/ollama.py:330, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     321 def _stream_with_aggregation(
#     322     self,
#     323     prompt: str,
#    (...)
#     327     **kwargs: Any,
#     328 ) -> GenerationChunk:
#     329     final_chunk: Optional[GenerationChunk] = None
# --> 330     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     331         if stream_resp:
#     332             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_community/llms/ollama.py:172, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     164 def _create_generate_stream(
#     165     self,
#     166     prompt: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> Iterator[str]:
#     171     payload = {"prompt": prompt, "images": images}
# --> 172     yield from self._create_stream(
#     173         payload=payload,
#     174         stop=stop,
#     175         api_url=f"{self.base_url}/api/generate",
#     176         **kwargs,
#     177     )
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/langchain_community/llms/ollama.py:233, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     226 else:
#     227     request_payload = {
#     228         "prompt": payload.get("prompt"),
#     229         "images": payload.get("images", []),
#     230         **params,
#     231     }
# --> 233 response = requests.post(
#     234     url=api_url,
#     235     headers={
#     236         "Content-Type": "application/json",
#     237         **(self.headers if isinstance(self.headers, dict) else {}),
#     238     },
#     239     json=request_payload,
#     240     stream=True,
#     241     timeout=self.timeout,
#     242 )
#     243 response.encoding = "utf-8"
#     244 if response.status_code != 200:
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.9.18/envs/ollama/lib/python3.9/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.9.18/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/.pyenv/versions/3.9.18/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/.pyenv/versions/3.9.18/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.9.18/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
import json
with open("cypher_scripts.json", 'w') as f:
    # indent=2 is not needed but makes the file human-readable 
    # if the data is nested
    json.dump(cypher_list, f, indent=2)
